# %% [markdown]
# Calculate mult for 64-to-4
# inspired from scalability/scalability.ipynb

# %%
loadlevel = 0.5
numlink = 1066 
flowfile = "c2s_64_64_1_0_0_0"
bytespermult = 0
with open(f"/home/annzhou/DRing/src/emp/datacentre/flowfiles/{flowfile}",'r') as f:
    lines = f.readlines()
    for line in lines:
        tokens = line.split(',')
        bytespermult += int(tokens[2])
    
bytesperlink = 894784*1500*0.2 # 894784 packets per second, 1500B per packet, 200ms
totalbytes = bytesperlink*numlink # *2 for 2 directions, /2 for 2 hops per flow
usablebytes = totalbytes*loadlevel
mult = usablebytes/bytespermult
print(f"{flowfile}: {mult}")
# Out:
# c2s_64_64_1_0_0_0: 0.4547547394573216

# %% [markdown]
# Decide on what routing to use
# inspired from computerouting2/computerouting2.ipynb, testspatial

# %%
import sys
import os
import gurobipy as gp
from gurobipy import GRB

def compute(graphfile,numsw,netpathfile,serverfile,flowfile,numserver):
    # read netpathfile
    netpath = list()
    for i in range(numsw):
        netpath.append(list())
        for j in range(numsw):
            netpath[i].append(list())
    with open(netpathfile,'r') as f:
        lines = f.readlines()
        # produce
        fromsw = 0
        tosw = 0
        for line in lines:
            if "->" not in line:
                tokens = line.split()
                fromsw = int(tokens[0])
                tosw = int(tokens[1])
            else:
                path = [fromsw]
                tokens = line.split()
                for token in tokens:
                    hops = token.split("->")
                    path.append(int(hops[1]))
                netpath[fromsw][tosw].append(path)

        # check
        for line in lines:
            if "->" not in line:
                tokens = line.split()
                fromsw = int(tokens[0])
                tosw = int(tokens[1])
                numpaths = int(tokens[2])
                if len(netpath[fromsw][tosw])!=numpaths:
                    print(f"ERROR: netpath is wrong, fromsw={fromsw}, tosw={tosw}, numpaths from file={numpaths}, numpaths from array={len(netpath[fromsw][tosw])}")

    # read graphfile
    link = list()
    for i in range(numsw):
        link.append(list())
        for j in range(numsw):
            link[i].append(0)
    with open(graphfile,'r') as f:
        lines = f.readlines()
        for line in lines:
            tokens = line.split("->")
            fromsw = int(tokens[0])
            tosw = int(tokens[1])
            link[fromsw][tosw] = 1
            link[tosw][fromsw] = 1

    # read linkfailurefile (if needed)
    # if numfaillink > 0:
    #     with open(linkfailurefile,'r') as f:
    #         lines = f.readlines()
    #         for line in lines:
    #             tokens = line.split()
    #             fromsw = int(tokens[0])
    #             tosw = int(tokens[1])
    #             if link[fromsw][tosw] != 1:
    #                 print(f"ERROR: should have a link from {fromsw} to {tosw} but not")
    #             else:
    #                 link[fromsw][tosw] /= 2

    # read serverfile
    serverdict = dict()
    with open(serverfile,'r') as f:
        lines = f.readlines()
        for line in lines:
            tokens = line.split(',')
            serverdict[int(tokens[0])] = int(tokens[1])

    # read flowfile
    traffic = list()
    for i in range(numsw):
        traffic.append(list())
        for j in range(numsw):
            traffic[i].append(0)
    with open(flowfile,'r') as f:
        lines = f.readlines()
        for line in lines:
            tokens = line.split(",")
            fromsvr = int(tokens[0])
            tosvr = int(tokens[1])
            if fromsvr>=numserver or tosvr>=numserver: continue
            fromsw = serverdict[fromsvr]
            tosw = serverdict[tosvr]
            if fromsw == tosw: continue
            flowbytes = int(tokens[2])
            traffic[fromsw][tosw] += flowbytes


    # precompute
    flowsvialink = list()
    for i in range(numsw):
        flowsvialink.append(list())
        for j in range(numsw):
            flowsvialink[i].append(list())
    for fromsw in range(numsw):
        for tosw in range(numsw):
            if traffic[fromsw][tosw] > 0:
                for pid,path in enumerate(netpath[fromsw][tosw]):
                    fidpidstr = f"{fromsw},{tosw},{pid}"
                    prevhop = fromsw
                    for hop in path[1:]:
                        flowsvialink[prevhop][hop].append(fidpidstr)
                        prevhop = hop

    for fromsw in range(numsw):
        for tosw in range(numsw):
            traffic[fromsw][tosw] /= 100000


    # Create a new model
    model = gp.Model("mcf")

    # Add variables
    maxpid = 0
    for fromsw in range(numsw):
        for tosw in range(numsw):
            maxpid = max(maxpid,len(netpath[fromsw][tosw]))
    vararr = list()
    for fromsw in range(numsw):
        vararr.append(list())
        for tosw in range(numsw):
            vararr[fromsw].append(list())
            for pid in range(maxpid):
                vararr[fromsw][tosw].append(None)
    for fromsw in range(numsw):
        for tosw in range(numsw):
            if traffic[fromsw][tosw] > 0:
                for pid in range(len(netpath[fromsw][tosw])):
                    var = model.addVar(name=f"{fromsw}_{tosw}_{pid}")
                    vararr[fromsw][tosw][pid] = var
    k = model.addVar(name="k")

    # Set objective function
    model.setObjective(k, GRB.MAXIMIZE)

    # Add constraints
    # Constraint 0: for each fid: sum(pid) >= k * traffic[fid.from][fid.to]
    for fromsw in range(numsw):
        for tosw in range(numsw):
            if traffic[fromsw][tosw] > 0:
                varlist = list()
                for pid in range(len(netpath[fromsw][tosw])):
                    varlist.append(vararr[fromsw][tosw][pid])
                model.addConstr(sum(varlist)>=k*traffic[fromsw][tosw],f"c0_{fromsw}_{tosw}")

    # Constraint 1: for each link: sum(fid_pid) <= link[link.from][link.to]
    for linkfrom in range(numsw):
        for linkto in range(numsw):
            flowstrlist = flowsvialink[linkfrom][linkto]
            if len(flowstrlist) > 0:
                varlist = list()
                for flowstr in flowstrlist:
                    tokens = flowstr.split(',')
                    flowfrom = int(tokens[0])
                    flowto = int(tokens[1])
                    pid = int(tokens[2])
                    varlist.append(vararr[flowfrom][flowto][pid])
                model.addConstr(sum(varlist)<=link[linkfrom][linkto],f"c1_{linkfrom}_{linkto}")

    # Constraint 2: for each fid: for each pid: pid = prev_pid
    for fromsw in range(numsw):
        for tosw in range(numsw):
            if traffic[fromsw][tosw] > 0:
                for pid in range(1,len(netpath[fromsw][tosw])):
                    model.addConstr(vararr[fromsw][tosw][pid]-vararr[fromsw][tosw][pid-1]==0,f"c2_{fromsw}_{tosw}_{pid}")

    # Optimize model
    model.setParam('Method',-1)
    model.setParam('Crossover',0)
    model.optimize()
    # modelfile = "/home/annzhou/DRing/src/emp/datacentre/experiments/torbottleneck/model.lp"
    # model.write(modelfile)

    # Print results
    if model.status == GRB.OPTIMAL:
        # print(f"Optimal objective value: {model.objVal}")
        resultfile = "/home/annzhou/DRing/src/emp/datacentre/experiments/networkbottleneck/whatrouting.txt"
        with open(resultfile,'a') as f:
            f.write(f"{flowfile},{routingname},{k.x}\n")
            # for fromsw in range(numsw):
            #     for tosw in range(numsw):
            #         if traffic[interval][fromsw][tosw] > 0:
            #             for pid in range(len(netpath[fromsw][tosw])):
            #                 var = vararr[fromsw][tosw][pid]
            #                 f.write(f"{var.varName},{var.x}\n")
    else:
        print("No optimal solution found")
    return

# %%
fileprefix = "/home/annzhou/DRing/src/emp/datacentre"
graphfile = f"{fileprefix}/graphfiles/ring_supergraph/double_ring/instance1_80_64.edgelist"
numsw = 80
numserver = 2988
routingnamearr = ["ecmp","su2","su3"]
serverfile = f"{fileprefix}/serverfiles/dring_2988_80_64"
clist = [64,48,32,16,4]
multlist = [[0,45,100],[0,80,100],[1,80,100],[7,20,100],[115,20,100]]
tseedlist = range(5)

for ic,c in enumerate(clist):
    mult = multlist[ic][0]
    numerator = multlist[ic][1]
    denominator = multlist[ic][2]
    for tseed in tseedlist:
        flowfile = f"{fileprefix}/flowfiles/c2s_{c}_{c}_{mult}_{numerator}_{denominator}_{tseed}"
        for routingname in routingnamearr:
            netpathfile = f"{fileprefix}/netpathfiles/netpath_{routingname}_dring.txt"
            compute(graphfile,numsw,netpathfile,serverfile,flowfile,numserver)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-01-09
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 225792 rows, 223661 columns and 1298008 nonzeros
# Model fingerprint: 0xcc508b39
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 219472 rows and 219472 columns
# Presolve time: 2.84s
# Presolved: 6320 rows, 4189 columns, 308020 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.08s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 1.279e+06
#  Factor NZ  : 2.461e+06 (roughly 25 MB of memory)
#  Factor Ops : 2.849e+09 (less than 1 second per iteration)
#  Threads    : 18
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.89713550e-03  1.11931094e-03  3.17e+00 5.59e-05  6.36e-03     3s
#    1   1.14194647e-05  5.22883324e-01  1.91e+00 3.66e-02  2.89e-03     3s
#    2   6.15469873e-04  2.23409511e+00  2.49e-01 4.61e-05  6.96e-04     3s
#    3   2.77621231e-04  6.24123335e-01  2.00e-02 0.00e+00  1.09e-04     3s
#    4   2.07345328e-04  7.95628475e-02  0.00e+00 0.00e+00  1.08e-05     3s
#    5   2.11286052e-04  7.09268052e-04  0.00e+00 0.00e+00  6.78e-08     3s
#    6   4.74890377e-04  5.69166380e-04  0.00e+00 0.00e+00  1.28e-08     4s
#    7   4.95113717e-04  5.17122899e-04  0.00e+00 0.00e+00  2.99e-09     4s
#    8   4.96614352e-04  4.98273217e-04  0.00e+00 0.00e+00  2.26e-10     4s
#
# Barrier performed 8 iterations in 3.66 seconds (1.87 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4190    4.9706419e-04   0.000000e+00   0.000000e+00      4s
#
# Solved in 4190 iterations and 4.15 seconds (2.51 work units)
# Optimal objective  4.970641859e-04
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 247128 rows, 244997 columns and 1404688 nonzeros
# Model fingerprint: 0xbcc510be
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 238676 rows and 238676 columns
# Presolve time: 3.03s
# Presolved: 8452 rows, 6321 columns, 354956 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.09s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 1.345e+06
#  Factor NZ  : 2.511e+06 (roughly 30 MB of memory)
#  Factor Ops : 2.850e+09 (less than 1 second per iteration)
#  Threads    : 18
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.88981733e-03  6.24427020e-04  1.76e+01 3.38e-05  1.02e-02     3s
#    1   1.51160496e-05  2.06988604e+00  1.02e+01 1.94e-02  4.03e-03     4s
#    2   7.32291807e-04  3.33310624e+00  9.12e-01 0.00e+00  6.50e-04     4s
#    3   3.27135797e-04  1.16862577e+00  1.29e-01 0.00e+00  1.40e-04     4s
#    4   2.26672304e-04  1.27665690e-01  0.00e+00 0.00e+00  1.21e-05     4s
#    5   2.29739605e-04  7.77101757e-04  0.00e+00 0.00e+00  5.19e-08     4s
#    6   4.62122744e-04  6.28483353e-04  0.00e+00 0.00e+00  1.58e-08     4s
#    7   5.01746025e-04  5.63331246e-04  0.00e+00 0.00e+00  5.84e-09     4s
#    8   5.18366835e-04  5.42067011e-04  0.00e+00 0.00e+00  2.25e-09     4s
#    9   5.20666788e-04  5.27654851e-04  0.00e+00 0.00e+00  6.63e-10     4s
#   10   5.22048560e-04  5.22522324e-04  0.00e+00 1.88e-16  4.49e-11     4s
#   11   5.22163468e-04  5.22171726e-04  0.00e+00 1.37e-18  7.83e-13     4s
#
# Barrier solved model in 11 iterations and 3.98 seconds (1.97 work units)
# Optimal objective 5.22163468e-04
#
# Crossover log...
#
#        2 DPushes remaining with DInf 0.0000000e+00                 4s
#        0 DPushes remaining with DInf 0.0000000e+00                 4s
#
#     6096 PPushes remaining with PInf 0.0000000e+00                 4s
#        0 PPushes remaining with PInf 0.0000000e+00                 4s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.8636490e-17      4s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6101    5.2216634e-04   0.000000e+00   0.000000e+00      5s
#
# Solved in 6101 iterations and 4.85 seconds (2.37 work units)
# Optimal objective  5.221663426e-04
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 1552548 rows, 1550417 columns and 9235076 nonzeros
# Model fingerprint: 0x33bd06ba
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 220000 rows and 220000 columns (presolve time = 5s) ...
# Presolve removed 470000 rows and 470000 columns (presolve time = 10s) ...
# Presolve removed 710000 rows and 710000 columns (presolve time = 15s) ...
# Presolve removed 930000 rows and 930000 columns (presolve time = 20s) ...
# Presolve removed 1160000 rows and 1160000 columns (presolve time = 26s) ...
# Presolve removed 1370000 rows and 1370000 columns (presolve time = 30s) ...
# Presolve removed 1544096 rows and 1544096 columns (presolve time = 36s) ...
# Presolve removed 1544096 rows and 1544096 columns
# Presolve time: 36.59s
# Presolved: 8452 rows, 6321 columns, 1755448 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.26s
#
# Barrier statistics:
#  Dense cols : 1503
#  AA' NZ     : 3.296e+06
#  Factor NZ  : 7.499e+06 (roughly 70 MB of memory)
#  Factor Ops : 1.521e+10 (less than 1 second per iteration)
#  Threads    : 18
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.39508176e-03  5.21312763e-04  1.33e+01 5.63e-05  7.93e-03    39s
#    1   1.52509013e-05  1.71429228e+00  8.86e+00 2.30e-02  3.70e-03    39s
#    2   2.14999761e-04  2.81331860e+00  6.39e-01 9.22e-04  5.35e-04    39s
#    3   6.88439609e-05  6.29792946e-01  0.00e+00 2.46e-16  5.97e-05    39s
#    4   6.92504895e-05  1.30243341e-03  0.00e+00 6.57e-14  1.17e-07    39s
#    5   3.64109178e-04  6.69417079e-04  0.00e+00 1.08e-14  2.89e-08    40s
#    6   4.46498191e-04  4.96119514e-04  0.00e+00 4.71e-16  4.71e-09    40s
#    7   4.60252695e-04  4.68474607e-04  0.00e+00 3.61e-16  7.80e-10    40s
#    8   4.62099244e-04  4.63159644e-04  0.00e+00 1.98e-16  1.01e-10    40s
#    9   4.62242038e-04  4.62247409e-04  0.00e+00 1.46e-18  5.09e-13    40s
#
# Barrier solved model in 9 iterations and 40.22 seconds (20.46 work units)
# Optimal objective 4.62242038e-04
#
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00
#    8   5.17318156e-04  5.42645088e-04  0.00e+00 0.00e+00  2.40e-09     4s
#    9   5.18463713e-04  5.25218064e-04  0.00e+00 0.00e+00  6.40e-10     4s
#   10   5.20275017e-04  5.20478545e-04  0.00e+00 7.25e-19  1.93e-11     4s
#   11   5.20279162e-04  5.20279371e-04  0.00e+00 6.56e-19  1.98e-14     4s
#
# Barrier solved model in 11 iterations and 4.02 seconds (1.97 work units)
# Optimal objective 5.20279162e-04
#
# Crossover log...
#
#        1 DPushes remaining with DInf 0.0000000e+00                 4s
#        0 DPushes remaining with DInf 0.0000000e+00                 4s
#
#     6094 PPushes remaining with PInf 0.0000000e+00                 4s
#        0 PPushes remaining with PInf 0.0000000e+00                 4s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.8655338e-17      4s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6098    5.2027917e-04   0.000000e+00   0.000000e+00      5s
#
# Solved in 6098 iterations and 4.82 seconds (2.26 work units)
# Optimal objective  5.202791715e-04
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 1552548 rows, 1550417 columns and 9235076 nonzeros
# Model fingerprint: 0x86894fef
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 220000 rows and 220000 columns (presolve time = 5s) ...
# Presolve removed 470000 rows and 470000 columns (presolve time = 10s) ...
# Presolve removed 720000 rows and 720000 columns (presolve time = 15s) ...
# Presolve removed 960000 rows and 960000 columns (presolve time = 21s) ...
# Presolve removed 1160000 rows and 1160000 columns (presolve time = 26s) ...
# Presolve removed 1370000 rows and 1370000 columns (presolve time = 30s) ...
# Presolve removed 1544096 rows and 1544096 columns (presolve time = 36s) ...
# Presolve removed 1544096 rows and 1544096 columns
# Presolve time: 36.92s
# Presolved: 8452 rows, 6321 columns, 1755448 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.27s
#
# Barrier statistics:
#  Dense cols : 1503
#  AA' NZ     : 3.296e+06
#  Factor NZ  : 7.499e+06 (roughly 70 MB of memory)
#  Factor Ops : 1.521e+10 (less than 1 second per iteration)
#  Threads    : 18
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.54968974e-03  5.24325505e-04  1.37e+01 5.69e-05  8.17e-03    39s
#    1   1.54110311e-05  1.81089830e+00  9.17e+00 2.12e-02  3.66e-03    39s
#    2   8.50899369e-05  2.81706855e+00  2.12e-01 4.65e-16  3.71e-04    39s
#    3   5.13723818e-05  2.66818155e-01  8.05e-04 1.60e-16  2.77e-05    40s
#    4   4.69325470e-05  2.51658259e-01  0.00e+00 1.55e-16  2.39e-05    40s
#    5   4.75654693e-05  1.17032487e-03  0.00e+00 1.55e-17  1.06e-07    40s
#    6   2.60430941e-04  6.99442419e-04  0.00e+00 4.48e-18  4.16e-08    40s
#    7   4.30892336e-04  4.99215080e-04  0.00e+00 1.41e-19  6.48e-09    40s
#    8   4.54159902e-04  4.71350741e-04  0.00e+00 6.46e-20  1.63e-09    40s
#    9   4.58755530e-04  4.62074232e-04  0.00e+00 5.48e-16  3.15e-10    41s
#   10   4.59371003e-04  4.59609207e-04  0.00e+00 5.12e-19  2.26e-11    41s
#   11   4.59440251e-04  4.59440826e-04  0.00e+00 1.98e-18  5.46e-14    41s
#
# Barrier solved model in 11 iterations and 40.80 seconds (20.67 work units)
# Optimal objective 4.59440251e-04
#
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                41s
#
#     5508 PPushes remaining with PInf 0.0000000e+00                41s
#        0 PPushes remaining with PInf 0.0000000e+00                41s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.3877788e-16     41s
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6337    4.5944055e-04   0.000000e+00   0.000000e+00     46s
#
# Solved in 6337 iterations and 46.49 seconds (22.55 work units)
# Optimal objective  4.594405539e-04
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with
DPushes remaining with DInf 0.0000000e+00                 4s
#        0 DPushes remaining with DInf 0.0000000e+00                 4s
#
#     6094 PPushes remaining with PInf 0.0000000e+00                 4s
#        0 PPushes remaining with PInf 0.0000000e+00                 4s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.9490299e-17      4s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6098    5.2245495e-04   0.000000e+00   0.000000e+00      5s
#
# Solved in 6098 iterations and 4.84 seconds (2.32 work units)
# Optimal objective  5.224549487e-04
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 1552548 rows, 1550417 columns and 9235076 nonzeros
# Model fingerprint: 0xd07589c3
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 220000 rows and 220000 columns (presolve time = 5s) ...
# Presolve removed 470000 rows and 470000 columns (presolve time = 10s) ...
# Presolve removed 700000 rows and 700000 columns (presolve time = 15s) ...
# Presolve removed 930000 rows and 930000 columns (presolve time = 20s) ...
# Presolve removed 1160000 rows and 1160000 columns (presolve time = 26s) ...
# Presolve removed 1360000 rows and 1360000 columns (presolve time = 30s) ...
# Presolve removed 1544096 rows and 1544096 columns (presolve time = 36s) ...
# Presolve removed 1544096 rows and 1544096 columns
# Presolve time: 36.67s
# Presolved: 8452 rows, 6321 columns, 1755448 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.26s
#
# Barrier statistics:
#  Dense cols : 1503
#  AA' NZ     : 3.296e+06
#  Factor NZ  : 7.499e+06 (roughly 70 MB of memory)
#  Factor Ops : 1.521e+10 (less than 1 second per iteration)
#  Threads    : 18
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.36494295e-03  5.22896186e-04  1.32e+01 5.68e-05  7.88e-03    39s
#    1   1.61453786e-05  1.49963519e+00  8.81e+00 2.93e-02  4.08e-03    39s
#    2   6.16812263e-04  2.97734480e+00  1.51e+00 1.97e-03  9.19e-04    39s
#    3   1.13125000e-04  1.31786669e+00  0.00e+00 2.49e-13  1.25e-04    39s
#    4   1.13422366e-04  1.43122616e-03  0.00e+00 7.19e-17  1.25e-07    39s
#    5   4.00290362e-04  8.16500582e-04  0.00e+00 9.81e-18  3.95e-08    40s
#    6   4.47603001e-04  5.12322333e-04  0.00e+00 9.41e-19  6.14e-09    40s
#    7   4.60143119e-04  4.70222603e-04  0.00e+00 1.94e-19  9.56e-10    40s
#    8   4.61258439e-04  4.61612235e-04  0.00e+00 4.69e-19  3.35e-11    40s
#    9   4.61324051e-04  4.61341414e-04  0.00e+00 8.34e-19  1.65e-12    40s
#   10   4.61324996e-04  4.61325129e-04  0.00e+00 3.65e-16  1.25e-14    40s
#
# Barrier solved model in 10 iterations and 40.41 seconds (20.58 work units)
# Optimal objective 4.61324996e-04
#
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                41s
#
#     5506 PPushes remaining with PInf 0.0000000e+00                41s
#        0 PPushes remaining with PInf 0.0000000e+00                41s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 2.7030515e-17     41s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5509    4.6132511e-04   0.000000e+00   0.000000e+00     45s
#
# Solved in 5509 iterations and 45.19 seconds (22.30 work units)
# Optimal objective  4.613251126e-04
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 225792 rows, 223661 columns and 1298008 nonzeros
# Model fingerprint: 0x6754c31d
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 219472 rows and 219472 columns
# Presolve time: 2.93s
# Presolved: 6320 rows, 4189 columns, 308020 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.08s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 1.279e+06
#  Factor NZ  : 2.461e+06 (roughly 25 MB of memory)
#  Factor Ops : 2.849e+09 (less than 1 second per iteration)
#  Threads    : 18
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4

#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6098    5.2994095e-04   0.000000e+00   0.000000e+00      5s
#
# Solved in 6098 iterations and 4.89 seconds (2.39 work units)
# Optimal objective  5.299409468e-04
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 1552548 rows, 1550417 columns and 9235076 nonzeros
# Model fingerprint: 0xbd01e339
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 220000 rows and 220000 columns (presolve time = 5s) ...
# Presolve removed 470000 rows and 470000 columns (presolve time = 10s) ...
# Presolve removed 710000 rows and 710000 columns (presolve time = 15s) ...
# Presolve removed 940000 rows and 940000 columns (presolve time = 20s) ...
# Presolve removed 1160000 rows and 1160000 columns (presolve time = 26s) ...
# Presolve removed 1380000 rows and 1380000 columns (presolve time = 30s) ...
# Presolve removed 1544096 rows and 1544096 columns (presolve time = 36s) ...
# Presolve removed 1544096 rows and 1544096 columns
# Presolve time: 36.73s
# Presolved: 8452 rows, 6321 columns, 1755448 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.26s
#
# Barrier statistics:
#  Dense cols : 1503
#  AA' NZ     : 3.296e+06
#  Factor NZ  : 7.499e+06 (roughly 70 MB of memory)
#  Factor Ops : 1.521e+10 (less than 1 second per iteration)
#  Threads    : 18
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.16041583e-03  5.22905406e-04  1.26e+01 5.68e-05  7.56e-03    39s
#    1   1.51346051e-05  1.59065877e+00  8.42e+00 2.49e-02  3.59e-03    39s
#    2   4.55132145e-05  2.82581755e+00  1.85e-01 2.27e-13  3.66e-04    39s
#    3   2.95459918e-05  1.10286239e+00  4.49e-04 1.63e-13  1.15e-04    39s
#    4   2.18428583e-05  9.22116629e-02  0.00e+00 1.32e-13  8.75e-06    40s
#    5   2.26757924e-05  1.18763006e-03  0.00e+00 1.45e-14  1.10e-07    40s
#    6   3.71260680e-04  6.74854699e-04  0.00e+00 2.50e-15  2.88e-08    40s
#    7   4.43572267e-04  5.01321348e-04  0.00e+00 2.25e-16  5.48e-09    40s
#    8   4.61255198e-04  4.71667006e-04  0.00e+00 1.67e-16  9.87e-10    40s
#    9   4.63525272e-04  4.64969836e-04  0.00e+00 1.31e-16  1.37e-10    41s
#   10   4.63682469e-04  4.63714056e-04  0.00e+00 1.53e-16  3.00e-12    41s
#   11   4.63692683e-04  4.63692686e-04  3.36e-10 1.13e-16  2.34e-16    41s
#
# Barrier solved model in 11 iterations and 40.87 seconds (20.72 work units)
# Optimal objective 4.63692683e-04
#
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                41s
#
#     5506 PPushes remaining with PInf 0.0000000e+00                41s
#        0 PPushes remaining with PInf 0.0000000e+00                42s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.6310608e-17     42s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5509    4.6369269e-04   0.000000e+00   0.000000e+00     47s
#
# Solved in 5509 iterations and 46.87 seconds (22.44 work units)
# Optimal objective  4.636926852e-04
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 225792 rows, 223661 columns and 1298008 nonzeros
# Model fingerprint: 0x80afa5dc
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 219472 rows and 219472 columns
# Presolve time: 2.79s
# Presolved: 6320 rows, 4189 columns, 308020 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.08s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 1.279e+06
#  Factor NZ  : 2.461e+06 (roughly 25 MB of memory)
#  Factor Ops : 2.849e+09 (less than 1 second per iteration)
#  Threads    : 18
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4
-04
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 1552548 rows, 1550417 columns and 9235076 nonzeros
# Model fingerprint: 0xff9f72c4
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 220000 rows and 220000 columns (presolve time = 5s) ...
# Presolve removed 470000 rows and 470000 columns (presolve time = 10s) ...
# Presolve removed 700000 rows and 700000 columns (presolve time = 15s) ...
# Presolve removed 930000 rows and 930000 columns (presolve time = 20s) ...
# Presolve removed 1160000 rows and 1160000 columns (presolve time = 26s) ...
# Presolve removed 1370000 rows and 1370000 columns (presolve time = 30s) ...
# Presolve removed 1544096 rows and 1544096 columns (presolve time = 36s) ...
# Presolve removed 1544096 rows and 1544096 columns
# Presolve time: 36.74s
# Presolved: 8452 rows, 6321 columns, 1755448 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.27s
#
# Barrier statistics:
#  Dense cols : 1503
#  AA' NZ     : 3.296e+06
#  Factor NZ  : 7.499e+06 (roughly 70 MB of memory)
#  Factor Ops : 1.521e+10 (less than 1 second per iteration)
#  Threads    : 18
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.69755000e-03  5.19921682e-04  1.41e+01 5.63e-05  8.41e-03    39s
#    1   1.43070521e-05  1.71657280e+00  9.43e+00 2.42e-02  3.98e-03    39s
#    2   3.42964825e-04  2.94081571e+00  3.31e-01 0.00e+00  4.32e-04    39s
#    3   2.15521729e-04  7.51661799e-01  5.80e-02 0.00e+00  8.64e-05    40s
#    4   1.55808871e-04  4.13008009e-02  0.00e+00 0.00e+00  3.90e-06    40s
#    5   1.61778303e-04  6.62543707e-04  0.00e+00 0.00e+00  4.75e-08    40s
#    6   4.32807924e-04  5.01271056e-04  0.00e+00 0.00e+00  6.49e-09    40s
#    7   4.55126740e-04  4.72825231e-04  0.00e+00 0.00e+00  1.68e-09    40s
#    8   4.60060467e-04  4.63458387e-04  0.00e+00 0.00e+00  3.22e-10    41s
#    9   4.60539754e-04  4.60661642e-04  0.00e+00 0.00e+00  1.16e-11    41s
#   10   4.60587004e-04  4.60587197e-04  0.00e+00 2.43e-17  1.83e-14    41s
#
# Barrier solved model in 10 iterations and 41.04 seconds (20.60 work units)
# Optimal objective 4.60587004e-04
#
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                41s
#
#     5506 PPushes remaining with PInf 0.0000000e+00                41s
#        0 PPushes remaining with PInf 0.0000000e+00                42s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 8.7186795e-17     42s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5509    4.6058712e-04   0.000000e+00   0.000000e+00     46s
#
# Solved in 5509 iterations and 46.03 seconds (22.46 work units)
# Optimal objective  4.605871240e-04
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 173124 rows, 170993 columns and 992298 nonzeros
# Model fingerprint: 0xc17224de
# Coefficient statistics:
#   Matrix range     [6e-02, 7e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 167790 rows and 167790 columns
# Presolve time: 1.91s
# Presolved: 5334 rows, 3203 columns, 235530 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.20s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 1.102e+06
#  Factor NZ  : 2.299e+06 (roughly 23 MB of memory)
#  Factor Ops : 2.649e+09 (less than 1 second per iteration)
#  Threads    : 18
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7.52271353e-02  5.95740230e-05  6.40e+02 1.42e-04  2.55e-01     2s
#
# Barrier performed 0 iterations in 2.40 seconds (1.22 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3205    3.4746877e-04   0.000000e+00   0.000000e+00      3s
#
# Solved in 3205 iterations and 2.69 seconds (1.79 work units)
# Optimal objective  3.474687739e-04
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 189516 rows, 187385 columns and 1074258 nonzeros
# Model fingerprint: 0xcdf62c4c
# Coefficient statistics:
#   Matrix range     [6e-02, 7e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 182550 rows and 182550 columns
# Presolve time: 2.04s
# Presolved: 6966 rows, 4835 columns, 271578 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.32s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 1.175e+06
#  Factor NZ  : 2.360e+06 (roughly 25 MB of memory)
#  Factor Ops : 2.714e+09 (less than 1 second per iteration)
#  Threads    : 18
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.48817291e-01  3.14248641e-04  6.32e+02 3.43e-05  2.40e-01     3s
#    1   3.57715218e-04  1.44971143e+00  3.79e+02 2.00e-02  1.12e-01     3s
#    2   8.35410640e-03  2.26357022e+00  7.03e+01 1.33e-02  2.77e-02     3s
#    3   1.22891038e-03  4.35635823e+00  4.42e+00 5.58e-03  5.84e-03     3s
#    4   8.68516642e-05  4.98679566e+00  1.79e-03 9.76e-06  6.65e-04     3s
#    5   6.16794795e-05  1.15208487e+00  2.87e-04 1.73e-06  1.41e-04     3s
#    6   5.71052612e-05  5.14064812e-02  0.00e+00 2.00e-08  6.19e-06     3s
#    7   6.13884704e-05  1.21124790e-03  0.00e+00 3.20e-10  1.39e-07     3s
#    8   2.45425992e-04  7.95302262e-04  0.00e+00 0.00e+00  6.62e-08     3s
#    9   3.51872158e-04  5.30427412e-04  0.00e+00 0.00e+00  2.15e-08     3s
#   10   3.60976073e-04  4.27457169e-04  0.00e+00 0.00e+00  8.00e-09     3s
#   11   3.63551680e-04  3.76807019e-04  0.00e+00 0.00e+00  1.59e-09     3s
#   12   3.67942593e-04  3.69173658e-04  0.00e+00 2.30e-19  1.48e-10     3s
#   13   3.68022046e-04  3.68060879e-04  0.00e+00 5.69e-19  4.67e-12     3s
#   14   3.68038798e-04  3.68038836e-04  1.07e-09 9.09e-17  4.67e-15     3s
#
# Barrier solved model in 14 iterations and 3.20 seconds (1.67 work units)
# Optimal objective 3.68038798e-04
#
# Crossover log...
#
#        1 DPushes remaining with DInf 0.0000000e+00                 3s
#        0 DPushes remaining with DInf 0.0000000e+00                 3s
#
#     4626 PPushes remaining with PInf 0.0000000e+00                 3s
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4858    3.6803881e-04   0.000000e+00   0.000000e+00      4s
#
# Solved in 4858 iterations and 3.60 seconds (2.56 work units)
# Optimal objective  3.680388145e-04
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 1189710 rows, 1187579 columns and 7073790 nonzeros
# Model fingerprint: 0x067d2bca
# Coefficient statistics:
#   Matrix range     [6e-02, 7e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 230000 rows and 230000 columns (presolve time = 5s) ...
# Presolve removed 480000 rows and 480000 columns (presolve time = 10s) ...
# Presolve removed 700000 rows and 700000 columns (presolve time = 15s) ...
# Presolve removed 920000 rows and 920000 columns (presolve time = 20s) ...
# Presolve removed 1130000 rows and 1130000 columns (presolve time = 25s) ...
# Presolve removed 1182744 rows and 1182744 columns
# Presolve time: 27.96s
# Presolved: 6966 rows, 4835 columns, 1344467 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.19s
#
# Barrier statistics:
#  Dense cols : 1633
#  AA' NZ     : 2.781e+06
#  Factor NZ  : 7.504e+06 (roughly 70 MB of memory)
#  Factor Ops : 1.671e+10 (less than 1 second per iteration)
#  Threads    : 18
#
# ...
#   RHS range        [1e+00, 1e+00]
# Presolve removed 40029 rows and 38669 columns
# Presolve time: 0.30s
# Presolved: 1666 rows, 1040 columns, 24874 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.04s
#
# Barrier performed 0 iterations in 0.37 seconds (0.23 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      858    1.3232499e-04   0.000000e+00   0.000000e+00      0s
#
# Solved in 858 iterations and 0.42 seconds (0.25 work units)
# Optimal objective  1.323249921e-04
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 256476 rows, 254345 columns and 1514844 nonzeros
# Model fingerprint: 0xe42d0afe
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 253305 rows and 253305 columns
# Presolve time: 6.94s
# Presolved: 3171 rows, 1040 columns, 287955 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Presolve time: 7.03s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3322777e-04   0.000000e+00   0.000000e+00      7s
#
# Solved with barrier
#        0    1.3322777e-04   0.000000e+00   0.000000e+00      7s
#
# Solved in 0 iterations and 7.49 seconds (6.22 work units)
# Optimal objective  1.332277664e-04
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2238 rows, 1759 columns and 10099 nonzeros
# Model fingerprint: 0xbf2a8dff
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 2193 rows and 1732 columns
# Presolve time: 0.02s
# Presolved: 45 rows, 27 columns, 186 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.2292043e-05   7.096683e-02   0.000000e+00      0s
#       15    1.3567478e-05   0.000000e+00   0.000000e+00      0s
#
# Solved in 15 iterations and 0.03 seconds (0.01 work units)
# Optimal objective  1.356747784e-05
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2593 rows, 2041 columns and 11509 nonzeros
# Model fingerprint: 0x0374208e
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 2455 rows and 1977 columns
# Presolve time: 0.02s
# Presolved: 138 rows, 64 columns, 659 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.1143617e-03   1.662578e+02   0.000000e+00      0s
#       58    3.3854446e-05   0.000000e+00   0.000000e+00      0s
#
# Solved in 58 iterations and 0.03 seconds (0.01 work units)
# Optimal objective  3.385444622e-05
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 18920 rows, 17501 columns and 104241 nonzeros
# Model fingerprint: 0xa3420f32
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 18410 rows and 17437 columns
# Presolve time: 0.22s
# Presolved: 510 rows, 64 columns, 8965 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9062500e+27   4.099897e+31   6.250000e-02      0s
#       67    3.1699282e-05   0.000000e+00   0.000000e+00      0s
#
# Solved in 67 iterations and 0.25 seconds (0.14 work units)
# Optimal objective  3.169928150e-05
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2778 rows, 2293 columns and 13624 nonzeros
# Model fingerprint: 0x1e4b3352
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 2775 rows and 2290 columns
# Presolve time: 0.02s
# Presolved: 3 rows, 3 columns, 7 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.1239059e-05   7.879531e-04   0.000000e+00      0s
#        1    1.7673942e-05   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.03 seconds (0.01 work units)
# Optimal objective  1.767394216e-05
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 3174 rows, 2609 columns and 15204 nonzeros
# Model fingerprint: 0x85610a05
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 3083 rows and 2560 columns
# Presolve time: 0.03s
# Presolved: 91 rows, 49 columns, 273 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2976442e-03   5.523620e+02   0.000000e+00      0s
#        8    5.7421384e-05   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.03 seconds (0.02 work units)
# Optimal objective  5.742138396e-05
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 15662 rows, 14253 columns and 85040 nonzeros
# Model fingerprint: 0xb52e6d27
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 15294 rows and 14204 columns
# Presolve time: 0.18s
# Presolved: 368 rows, 49 columns, 2036 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9531250e+27   3.384483e+31   6.250000e-02      0s
#       54    4.6599554e-05   0.000000e+00   0.000000e+00      0s
#
# Solved in 54 iterations and 0.20 seconds (0.11 work units)
# Optimal objective  4.659955363e-05
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 1290 rows, 957 columns and 5200 nonzeros
# Model fingerprint: 0x49ba720d
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 1190 rows and 912 columns
# Presolve time: 0.01s
# Presolved: 100 rows, 45 columns, 408 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3406965e-05   2.764223e-01   0.000000e+00      0s
#       33    1.4809199e-05   0.000000e+00   0.000000e+00      0s
#
# Solved in 33 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.480919869e-05
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 1488 rows, 1121 columns and 6020 nonzeros
# Model fingerprint: 0xbfd0655b
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 1354 rows and 1056 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 65 columns, 564 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9531250e+27   5.389086e+32   6.250000e-02      0s
#       47    3.7419135e-05   0.000000e+00   0.000000e+00      0s
#
# Solved in 47 iterations and 0.02 seconds (0.01 work units)
# Optimal objective  3.741913472e-05
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 16981 rows, 15645 columns and 93144 nonzeros
# Model fingerprint: 0xae40a5ea
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 16489 rows and 15580 columns
# Presolve time: 0.17s
# Presolved: 492 rows, 65 columns, 8016 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9531250e+27   4.153050e+31   6.250000e-02      0s
#       84    3.5456547e-05   0.000000e+00   0.000000e+00      0s
#
# Solved in 84 iterations and 0.19 seconds (0.11 work units)
# Optimal objective  3.545654750e-05
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2734 rows, 2122 columns and 11969 nonzeros
# Model fingerprint: 0xbc59bff5
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 2710 rows and 2101 columns
# Presolve time: 0.02s
# Presolved: 24 rows, 21 columns, 73 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4053547e-05   5.624882e-03   0.000000e+00      0s
#        1    1.5831344e-05   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.03 seconds (0.01 work units)
# Optimal objective  1.583134446e-05
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 3102 rows, 2444 columns and 13579 nonzeros
# Model fingerprint: 0x346694e0
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 2920 rows and 2355 columns
# Presolve time: 0.02s
# Presolved: 182 rows, 89 columns, 749 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4900835e-03   3.776207e+02   0.000000e+00      0s
#       59    4.2438408e-05   0.000000e+00   0.000000e+00      0s
#
# Solved in 59 iterations and 0.03 seconds (0.01 work units)
# Optimal objective  4.243840817e-05
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 25006 rows, 23075 columns and 137333 nonzeros
# Model fingerprint: 0xa69a25fa
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 24240 rows and 22986 columns
# Presolve time: 0.27s
# Presolved: 766 rows, 89 columns, 14277 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9531250e+27   5.578335e+31   6.250000e-02      0s
#       96    4.4929737e-05   0.000000e+00   0.000000e+00      0s
#
# Solved in 96 iterations and 0.31 seconds (0.20 work units)
# Optimal objective  4.492973659e-05
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2930 rows, 2197 columns and 12676 nonzeros
# Model fingerprint: 0x85ebf62e
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 2887 rows and 2164 columns
# Presolve time: 0.02s
# Presolved: 43 rows, 33 columns, 139 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9274945e-05   3.723094e-02   0.000000e+00      0s
#        3    1.9950758e-05   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.03 seconds (0.01 work units)
# Optimal objective  1.995075768e-05
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 3339 rows, 2519 columns and 14286 nonzeros
# Model fingerprint: 0x6fb96701
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 3154 rows and 2438 columns
# Presolve time: 0.02s
# Presolved: 185 rows, 81 columns, 742 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9062500e+27   7.023172e+32   6.250000e-02      0s
#       63    5.0245882e-05   0.000000e+00   0.000000e+00      0s
#
# Solved in 63 iterations and 0.03 seconds (0.01 work units)
# Optimal objective  5.024588249e-05
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 22901 rows, 20995 columns and 125108 nonzeros
# Model fingerprint: 0x634c8b9e
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 22254 rows and 20914 columns
# Presolve time: 0.22s
# Presolved: 647 rows, 81 columns, 10034 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9062500e+27   5.430922e+31   6.250000e-02      0s
#       89    3.9227025e-05   0.000000e+00   0.000000e+00      0s
#
# Solved in 89 iterations and 0.26 seconds (0.16 work units)
# Optimal objective  3.922702491e-05

# %% [markdown]
# Generate conffiles

# %%
graphname = "dring"
multlist = [[0,45,100],[0,80,100],[1,80,100],[7,20,100],[115,20,100]]
clist = [64,48,32,16,4]
# s=4
tseedlist = range(5)
sseed = 1
homedir = "/home/annzhou"

conffile = f"{homedir}/DRing/src/emp/datacentre/experiments/networkbottleneck/networkbottleneck.conf"
makeleafspine = "MAKE"
makedring = "MAKE"
with open(conffile,'w') as f:
    for ic,c in enumerate(clist):
        s=c
        mult = multlist[ic][0]
        numerator = multlist[ic][1]
        denominator = multlist[ic][2]
        multstr = f"{mult}_{numerator}_{denominator}"
        for tseed in tseedlist:
            flowfilename = f"flowfiles/c2s_{c}_{s}_{multstr}_{tseed}"
            flowfile = f"{homedir}/DRing/src/emp/datacentre/{flowfilename}"

            routingdict = dict()
            with open(f"{homedir}/DRing/src/emp/datacentre/experiments/networkbottleneck/whatrouting.txt",'r') as fr:
                lines = fr.readlines()
                for line in lines:
                    tokens = line.split(',')
                    if tokens[0]==flowfile:
                        routingdict[tokens[1]] = float(tokens[2])
            if max(routingdict.values()) == routingdict["ecmp"]:
                routingname = "ecmp"
                rt1 = "ecmp"
                rt2 = 0
            elif max(routingdict.values()) == routingdict["su2"]:
                routingname = "su2"
                rt1 = "su"
                rt2 = 2
            elif max(routingdict.values()) == routingdict["su3"]:
                routingname = "su3"
                rt1 = "su"
                rt2 = 3
            
            lsqvarfile = f"qvarfiles/qvar_leafspine_0_0_ecmp_64"
            lsnetpathfile = f"netpathfiles/netpath_ecmp_leafspine.txt"
            dringqvarfile = f"qvarfiles/qvar_{graphname}_0_0_{routingname}_c2s_{c}_{s}_{tseed}_{multstr}_2_0_64"
            dringnetpathfile = f"netpathfiles/netpath_{routingname}_{graphname}.txt"
            dringgraphfile = f"graphfiles/ring_supergraph/double_ring/instance1_80_64.edgelist"
            dringserverfile = f"serverfiles/dring_2988_80_64"
        
            f.write(f"./run.sh LEAFSPINE {makeleafspine} 80 3072 64 leafspine_nb NEW_FILE null {mult} {numerator} {denominator} 0 0 0 0 0 0 ecmp 0 {flowfilename} null {sseed} {lsnetpathfile} {lsqvarfile} 64 50 150 200 0 0 > m_networkbottleneck_leafspine_{c}_{s}_{multstr}_{tseed}.log\n")
            f.write(f"./run.sh RRG {makedring} 80 2988 64 dring_nb NEW_FILE {dringgraphfile} {mult} {numerator} {denominator} 0 0 0 0 0 0 {rt1} {rt2} {flowfilename} {dringserverfile} {sseed} {dringnetpathfile} {dringqvarfile} 64 50 150 200 0 0 > m_networkbottleneck_dring_{c}_{s}_{multstr}_{tseed}.log\n")
            makeleafspine = "NOMAKE"
            makedring = "NOMAKE"

# %% [markdown]
# generate sumfile & picklefile

# %%
import pickle

homedir = "/u/az6922"
datadict = dict()
conffile = f"{homedir}/DRing/src/emp/datacentre/experiments/networkbottleneck/networkbottleneck.conf"
sumfile = f"{homedir}/DRing/src/emp/datacentre/experiments/networkbottleneck/networkbottleneck.txt"
with open(conffile,'r') as f:
    with open(sumfile,'a') as sumf:
        lines = f.readlines()
        for line in lines:
            tokens = line.split()
            logfile = tokens[32]
            sizelist = list()
            durationlist = list()
            startlist = list()
            with open(f"{homedir}/DRing/src/emp/datacentre/{logfile}",'r') as logf:
                print(logfile)
                loglines = logf.readlines()
                for logline in loglines:
                    logtokens = logline.split()
                    if logtokens[0] == "FCT":
                        durationlist.append(float(logtokens[2]))
                        sizelist.append(int(logtokens[1]))
                        startlist.append(float(logtokens[3]))
            datadict[logfile] = [durationlist,sizelist,startlist]
            durationlist.sort()
            sumf.write(f"{logfile}\t{sum(durationlist)/len(durationlist)}\t{durationlist[int(len(durationlist)*0.5)]}\t{durationlist[int(len(durationlist)*0.99)]}\t{durationlist[int(len(durationlist)*0.9999)]}\n")

with open(f'{homedir}/DRing/src/emp/datacentre/experiments/networkbottleneck/networkbottleneck.pickle', 'wb') as handle:
    pickle.dump(datadict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# plot

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

homedir = "/u/az6922"
multlist = [[0,45,100],[0,80,100],[1,80,100],[7,20,100],[115,20,100]]
clist = [64,48,32,16,4]
# s=4
tseedlist = range(5)
sumfile = f"{homedir}/DRing/src/emp/datacentre/experiments/networkbottleneck/networkbottleneck.txt"

index = 3

ylist_ls = list()
ylist_dring = list()
for ic,c in enumerate(clist):
    s=c
    mult = multlist[ic][0]
    numerator = multlist[ic][1]
    denominator = multlist[ic][2]
    multstr = f"{mult}_{numerator}_{denominator}"
    fct_over_tseed_ls = list()
    fct_over_tseed_dring = list()
    with open(sumfile,'r') as f:
        lines = f.readlines()
        for tseed in tseedlist:
            logfile = f"m_networkbottleneck_leafspine_{c}_{s}_{multstr}_{tseed}.log"
            for line in lines:
                tokens = line.split()
                if tokens[0] == logfile:
                    n99fct = float(tokens[index])
                    fct_over_tseed_ls.append(n99fct)
        ylist_ls.append(sum(fct_over_tseed_ls)/len(fct_over_tseed_ls))

        for tseed in tseedlist:
            logfile = f"m_networkbottleneck_dring_{c}_{s}_{multstr}_{tseed}.log"
            for line in lines:
                tokens = line.split()
                if tokens[0] == logfile:
                    n99fct = float(tokens[index])
                    fct_over_tseed_dring.append(n99fct)
        ylist_dring.append(sum(fct_over_tseed_dring)/len(fct_over_tseed_dring))
plt.plot(clist,ylist_ls,label="leafspine",marker='x')
plt.plot(clist,ylist_dring,label="dring",marker='.')
plt.legend()
plt.xlabel('load (%)')
plt.ylabel('99ile fct (ms)')
# plt.title(f'{trafficname}, 5 runs')
plt.ylim(0,100)
# plt.savefig(f"{homedir}/DRing/src/emp/datacentre/experiments/routing/{trafficname}.png", dpi=500)
plt.show()

# %% [markdown]
# delete log,run files

# %%
import os

homedir = "/u/az6922"
dringdir = f"{homedir}/DRing/src/emp/datacentre"
for filedir in os.listdir(dringdir):
    if os.path.isfile(os.path.join(dringdir, filedir)):
        tokens = filedir.split("_")
        if tokens[0]=="m" and tokens[1]=="networkbottleneck" and tokens[-1].split('.')[-1]=="log":
            print(filedir)
            os.remove(f"{homedir}/DRing/src/emp/datacentre/{filedir}")
        if (tokens[0]=="rrg" or tokens[0]=="leafspine") and tokens[1]=="log":
            print(filedir)
            os.remove(f"{homedir}/DRing/src/emp/datacentre/{filedir}")
        if (tokens[-1]=="run") and ((tokens[0]=="leafspine" and tokens[1]=="leafspine") or (tokens[0]=="rrg" and (tokens[1]=="rrg" or tokens[1]=="dring"))):
            print(filedir)
            os.remove(f"{homedir}/DRing/src/emp/datacentre/{filedir}")
