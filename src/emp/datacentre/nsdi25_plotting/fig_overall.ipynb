# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

homedir = "/home/annzhou"
dirprefix = f"{homedir}/DRing/src/emp/datacentre"
fseedarr = range(1,6)
itemnamearr = ["dring","leafspine","fhi","racke"]
trafficnamedatalist = list()
multlistdatadict = dict()
multnamedatadict = dict()
sumfiledatadict = dict()

# %%
trafficname = "unv1"
trafficnamedatalist.append(trafficname)

leafspinemultlistarr = [[0,2,25],[0,17,100],[0,1,4],[0,17,50]]
dringmultlistarr = [[0,2,25],[0,17,100],[0,1,4],[0,17,50],[0,21,50],[0,51,100],[0,59,100],[0,34,50],[0,38,50],[0,17,20]]
fhimultlistarr = [[0,2,25],[0,17,100],[0,1,4],[0,17,50],[0,21,50],[0,51,100]]
rackemultlistarr = [[0,2,25],[0,17,100],[0,1,4],[0,17,50],[0,21,50],[0,51,100],[0,59,100],[0,34,50],[0,38,50],[0,17,20]]
multlistdatadict[trafficname] = dict()
multlistdatadict[trafficname]["leafspine"] = leafspinemultlistarr
multlistdatadict[trafficname]["dring"] = dringmultlistarr
multlistdatadict[trafficname]["fhi"] = fhimultlistarr
multlistdatadict[trafficname]["racke"] = rackemultlistarr

leafspinemultnamearr = range(5,21,5)
dringmultnamearr = range(5,51,5)
fhimultnamearr = range(5,31,5)
rackemultnamearr = range(5,51,5)
multnamedatadict[trafficname] = dict()
multnamedatadict[trafficname]["leafspine"] = leafspinemultnamearr
multnamedatadict[trafficname]["dring"] = dringmultnamearr
multnamedatadict[trafficname]["fhi"] = fhimultnamearr
multnamedatadict[trafficname]["racke"] = rackemultnamearr

sumfile = f"{dirprefix}/experiments/routing/{trafficname}.txt"
lssumfile = f"{dirprefix}/experiments/routing/{trafficname}_v1.txt"
fhisumfile = f"{dirprefix}/experiments/routing_fhi/{trafficname}.txt"
rackesumfile = f"{dirprefix}/experiments/routing_racke/{trafficname}_0.txt"
sumfiledatadict[trafficname] = dict()
sumfiledatadict[trafficname]["leafspine"] = lssumfile
sumfiledatadict[trafficname]["dring"] = sumfile
sumfiledatadict[trafficname]["fhi"] = fhisumfile
sumfiledatadict[trafficname]["racke"] = rackesumfile

# %%
trafficname = "prv1"
trafficnamedatalist.append(trafficname)

leafspinemultlistarr = [[0,2,100],[0,5,100],[0,7,100],[0,10,100],[0,12,100],[0,15,100],[0,17,100],[0,20,100]]
dringmultlistarr = [[0,2,100],[0,5,100],[0,7,100],[0,10,100],[0,12,100],[0,15,100],[0,17,100],[0,20,100],[0,22,100],[0,25,100],[0,37,100],[0,49,100],[0,62,100],[0,74,100]]
fhimultlistarr = [[0,2,100],[0,5,100],[0,7,100],[0,10,100],[0,12,100],[0,15,100],[0,17,100],[0,20,100],[0,22,100],[0,25,100]]
rackemultlistarr = [[0,2,100],[0,5,100],[0,7,100],[0,10,100],[0,12,100],[0,15,100],[0,17,100],[0,20,100],[0,22,100],[0,25,100],[0,37,100],[0,49,100],[0,62,100],[0,74,100]]
multlistdatadict[trafficname] = dict()
multlistdatadict[trafficname]["leafspine"] = leafspinemultlistarr
multlistdatadict[trafficname]["dring"] = dringmultlistarr
multlistdatadict[trafficname]["fhi"] = fhimultlistarr
multlistdatadict[trafficname]["racke"] = rackemultlistarr

leafspinemultnamearr = range(2,17,2)
dringmultnamearr = list(range(2,19,2))+list(range(20,61,10))
fhimultnamearr = range(2,21,2)
rackemultnamearr = list(range(2,19,2))+list(range(20,61,10))
multnamedatadict[trafficname] = dict()
multnamedatadict[trafficname]["leafspine"] = leafspinemultnamearr
multnamedatadict[trafficname]["dring"] = dringmultnamearr
multnamedatadict[trafficname]["fhi"] = fhimultnamearr
multnamedatadict[trafficname]["racke"] = rackemultnamearr

sumfile = f"{homedir}/DRing/src/emp/datacentre/experiments/routing/{trafficname}.txt"
lssumfile = f"{homedir}/DRing/src/emp/datacentre/experiments/routing/{trafficname}_v1.txt"
fhisumfile = f"{homedir}/DRing/src/emp/datacentre/experiments/routing_fhi/{trafficname}.txt"
rackesumfile = f"{homedir}/DRing/src/emp/datacentre/experiments/routing_racke/{trafficname}_0.txt"
sumfiledatadict[trafficname] = dict()
sumfiledatadict[trafficname]["leafspine"] = lssumfile
sumfiledatadict[trafficname]["dring"] = sumfile
sumfiledatadict[trafficname]["fhi"] = fhisumfile
sumfiledatadict[trafficname]["racke"] = rackesumfile

# %%
trafficname = "cluster_a"
trafficnamedatalist.append(trafficname)

leafspinemultlistarr = [[4,8,100],[8,17,100],[12,25,100],[16,34,100],[20,42,100],[24,51,100],[28,59,100]]
dringmultlistarr = [[4,8,100],[8,17,100],[12,25,100],[16,34,100],[20,42,100],[24,51,100],[28,59,100],[32,67,100],[36,76,100]]
fhimultlistarr = [[4,8,100],[8,17,100],[12,25,100],[16,34,100],[20,42,100],[24,51,100],[28,59,100],[32,67,100]]
rackemultlistarr = [[4,8,100],[8,17,100],[12,25,100],[16,34,100],[20,42,100],[24,51,100],[28,59,100],[32,67,100],[36,76,100]]
multlistdatadict[trafficname] = dict()
multlistdatadict[trafficname]["leafspine"] = leafspinemultlistarr
multlistdatadict[trafficname]["dring"] = dringmultlistarr
multlistdatadict[trafficname]["fhi"] = fhimultlistarr
multlistdatadict[trafficname]["racke"] = rackemultlistarr

leafspinemultnamearr = range(10,71,10)
dringmultnamearr = range(10,91,10)
fhimultnamearr = range(10,81,10)
rackemultnamearr = range(10,91,10)
multnamedatadict[trafficname] = dict()
multnamedatadict[trafficname]["leafspine"] = leafspinemultnamearr
multnamedatadict[trafficname]["dring"] = dringmultnamearr
multnamedatadict[trafficname]["fhi"] = fhimultnamearr
multnamedatadict[trafficname]["racke"] = rackemultnamearr

sumfile = f"{homedir}/DRing/src/emp/datacentre/experiments/routing/{trafficname}.txt"
fhisumfile = f"{homedir}/DRing/src/emp/datacentre/experiments/routing_fhi/{trafficname}.txt"
rackesumfile = f"{homedir}/DRing/src/emp/datacentre/experiments/routing_racke/{trafficname}_0.txt"
sumfiledatadict[trafficname] = dict()
sumfiledatadict[trafficname]["leafspine"] = sumfile
sumfiledatadict[trafficname]["dring"] = sumfile
sumfiledatadict[trafficname]["fhi"] = fhisumfile
sumfiledatadict[trafficname]["racke"] = rackesumfile

# %%
trafficname = "cluster_b"
trafficnamedatalist.append(trafficname)

leafspinemultlistarr = [[0,27,100],[0,53,100],[0,80,100],[1,7,100],[1,34,100],[1,60,100],[1,87,100],[2,14,100],[2,40,100]]
dringmultlistarr = [[0,27,100],[0,53,100],[0,80,100],[1,7,100],[1,34,100],[1,60,100],[1,87,100],[2,14,100],[2,40,100]]
fhimultlistarr = [[0,27,100],[0,53,100],[0,80,100],[1,7,100],[1,34,100],[1,60,100],[1,87,100],[2,14,100],[2,40,100]]
rackemultlistarr = [[0,27,100],[0,53,100],[0,80,100],[1,7,100],[1,34,100],[1,60,100],[1,87,100],[2,14,100],[2,40,100]]
multlistdatadict[trafficname] = dict()
multlistdatadict[trafficname]["leafspine"] = leafspinemultlistarr
multlistdatadict[trafficname]["dring"] = dringmultlistarr
multlistdatadict[trafficname]["fhi"] = fhimultlistarr
multlistdatadict[trafficname]["racke"] = rackemultlistarr

leafspinemultnamearr = range(10,91,10)
dringmultnamearr = range(10,91,10)
fhimultnamearr = range(10,91,10)
rackemultnamearr = range(10,91,10)
multnamedatadict[trafficname] = dict()
multnamedatadict[trafficname]["leafspine"] = leafspinemultnamearr
multnamedatadict[trafficname]["dring"] = dringmultnamearr
multnamedatadict[trafficname]["fhi"] = fhimultnamearr
multnamedatadict[trafficname]["racke"] = rackemultnamearr

sumfile = f"{homedir}/DRing/src/emp/datacentre/experiments/routing/{trafficname}.txt"
fhisumfile = f"{homedir}/DRing/src/emp/datacentre/experiments/routing_fhi/{trafficname}.txt"
rackesumfile = f"{homedir}/DRing/src/emp/datacentre/experiments/routing_racke/{trafficname}_0.txt"
sumfiledatadict[trafficname] = dict()
sumfiledatadict[trafficname]["leafspine"] = sumfile
sumfiledatadict[trafficname]["dring"] = sumfile
sumfiledatadict[trafficname]["fhi"] = fhisumfile
sumfiledatadict[trafficname]["racke"] = rackesumfile

# %%
trafficname = "cluster_c"
trafficnamedatalist.append(trafficname)

leafspinemultlistarr = [[0,19,100],[0,38,100],[0,57,100],[0,75,100],[0,94,100],[1,13,100],[1,32,100],[1,51,100],[1,70,100]]
dringmultlistarr = [[0,19,100],[0,38,100],[0,57,100],[0,75,100],[0,94,100],[1,13,100],[1,32,100],[1,51,100],[1,70,100]]
fhimultlistarr = [[0,19,100],[0,38,100],[0,57,100],[0,75,100],[0,94,100],[1,13,100],[1,32,100],[1,51,100],[1,70,100]]
rackemultlistarr = [[0,19,100],[0,38,100],[0,57,100],[0,75,100],[0,94,100],[1,13,100],[1,32,100],[1,51,100],[1,70,100]]
multlistdatadict[trafficname] = dict()
multlistdatadict[trafficname]["leafspine"] = leafspinemultlistarr
multlistdatadict[trafficname]["dring"] = dringmultlistarr
multlistdatadict[trafficname]["fhi"] = fhimultlistarr
multlistdatadict[trafficname]["racke"] = rackemultlistarr

leafspinemultnamearr = range(10,91,10)
dringmultnamearr = range(10,91,10)
fhimultnamearr = range(10,91,10)
rackemultnamearr = range(10,91,10)
multnamedatadict[trafficname] = dict()
multnamedatadict[trafficname]["leafspine"] = leafspinemultnamearr
multnamedatadict[trafficname]["dring"] = dringmultnamearr
multnamedatadict[trafficname]["fhi"] = fhimultnamearr
multnamedatadict[trafficname]["racke"] = rackemultnamearr

sumfile = f"{homedir}/DRing/src/emp/datacentre/experiments/routing/{trafficname}.txt"
dringsumfile = f"{homedir}/DRing/src/emp/datacentre/experiments/routing2/{trafficname}.txt"
fhisumfile = f"{homedir}/DRing/src/emp/datacentre/experiments/routing_fhi/{trafficname}.txt"
rackesumfile = f"{homedir}/DRing/src/emp/datacentre/experiments/routing_racke/{trafficname}_0.txt"
sumfiledatadict[trafficname] = dict()
sumfiledatadict[trafficname]["leafspine"] = sumfile
sumfiledatadict[trafficname]["dring"] = dringsumfile
sumfiledatadict[trafficname]["fhi"] = fhisumfile
sumfiledatadict[trafficname]["racke"] = rackesumfile

# %%
markerlist=['*','x','o','.']
labellist=["Starfish","Leaf-spine,Shortest","DRing,VLB","DRing,SMORE"]
colorlist = ["#fb8500","#023047","#219ebc","#8ecae6"]
titlelist=["UNV","ENP","DB","WS","HD"]
ylimlist = [50,50,50,50,50]
xlimlist = [40,25,95,95,95]

# matplotlib.rcParams["figure.figsize"] = (4, 1.3)
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

fig,axs = plt.subplots(1,5,figsize=(5*5,3*1))

for itrafficname,trafficname in enumerate(trafficnamedatalist):
    for iitemname,itemname in enumerate(itemnamearr):
        # print(f"{trafficname},{itemname}")
        xlist = list()
        ylist_over_mult = list()
        for imultlist,multlist in enumerate(multlistdatadict[trafficname][itemname]):
            mult = multlist[0]
            numerator = multlist[1]
            denominator = multlist[2]
            multname = multnamedatadict[trafficname][itemname][imultlist]

            # xlist.append(mult + numerator/denominator)
            xlist.append(multname)

            with open(sumfiledatadict[trafficname][itemname],'r') as f:
                lines = f.readlines()
                fct_over_fseed = list()
                for fseed in fseedarr:
                    
                    if itemname == "leafspine":
                        logfile = f"m_leafspine_{trafficname}_{multname}_{fseed}.log"
                    else:
                        if itemname=="racke":
                            logfile = f"m_dring_{trafficname}_0_{multname}_{fseed}.log"
                        else:
                            logfile = f"m_dring_{trafficname}_{multname}_{fseed}.log"
                    
                    # print(logfile)
                    for line in lines:
                        tokens = line.split()
                        if tokens[0] == logfile:
                            n99fct = float(tokens[3])
                            fct_over_fseed.append(n99fct)
                ylist_over_mult.append(sum(fct_over_fseed)/len(fct_over_fseed))
        axs[itrafficname].plot(xlist,ylist_over_mult,label=labellist[iitemname],marker=markerlist[iitemname],markersize=12,color=colorlist[iitemname])
        if itrafficname==0:
            # axs[itrafficname].legend()
            axs[itrafficname].set_ylabel('99ile FCT (ms)', fontsize=20)
        axs[itrafficname].set_xlabel('Load (%)', fontsize=20)
        axs[itrafficname].set_title(titlelist[itrafficname], fontsize=20)
        axs[itrafficname].set_ylim(0,ylimlist[itrafficname])
        axs[itrafficname].set_xlim(0,xlimlist[itrafficname])
        axs[itrafficname].set_xticklabels([str(int(x)) for x in axs[itrafficname].get_xticks()], fontsize=16)
        axs[itrafficname].set_yticklabels([str(int(x)) for x in axs[itrafficname].get_yticks()], fontsize=16)
        axs[itrafficname].grid(color='lightgrey', linestyle='dashed', axis="both")

handles, labels = axs[0].get_legend_handles_labels()
plt.legend(handles, labels, loc='upper center', ncol=4, bbox_to_anchor=(-2, 1.5), fontsize=20)
plt.tight_layout()
plt.savefig(f"{homedir}/DRing/src/emp/datacentre/nsdi25_plotting/fig_overall.pdf", dpi=600, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_2302115/4038224155.py:56: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[itrafficname].set_xticklabels([str(int(x)) for x in axs[itrafficname].get_xticks()], fontsize=16)
# /tmp/ipykernel_2302115/4038224155.py:57: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[itrafficname].set_yticklabels([str(int(x)) for x in axs[itrafficname].get_yticks()], fontsize=16)
# /tmp/ipykernel_2302115/4038224155.py:62: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()

# %%
# # analysis, should comment out by default
# testloaddatadict = dict()
# testloaddatadict["unv1"] = {"leafspine":15,"dring":35}
# testloaddatadict["prv1"] = {"leafspine":10,"dring":20}
# testloaddatadict["cluster_a"] = {"leafspine":60,"dring":90}
# testloaddatadict["cluster_b"] = {"leafspine":90,"dring":90}
# testloaddatadict["cluster_c"] = {"leafspine":90,"dring":90}

# ratiolist = list()
# for trafficname in trafficnamedatalist:
#     leafspinemultname = testloaddatadict[trafficname]["leafspine"]
#     with open(sumfiledatadict[trafficname]["leafspine"],'r') as f:
#         lines = f.readlines()
#         fct_over_fseed = list()
#         for fseed in fseedarr:
#             logfile = f"m_leafspine_{trafficname}_{leafspinemultname}_{fseed}.log"
#             # print(logfile)
#             for line in lines:
#                 tokens = line.split()
#                 if tokens[0] == logfile:
#                     # print("yes")
#                     n99fct = float(tokens[3])
#                     fct_over_fseed.append(n99fct)
#         leafspinefct = sum(fct_over_fseed)/len(fct_over_fseed)

#     # dringmultname = testloaddatadict[trafficname]["dring"]
#     with open(sumfiledatadict[trafficname]["dring"],'r') as f:
#         lines = f.readlines()
#         fct_over_fseed = list()
#         for fseed in fseedarr:
#             logfile = f"m_dring_{trafficname}_{leafspinemultname}_{fseed}.log"
#             for line in lines:
#                 tokens = line.split()
#                 if tokens[0] == logfile:
#                     n99fct = float(tokens[3])
#                     fct_over_fseed.append(n99fct)
#         dringfct = sum(fct_over_fseed)/len(fct_over_fseed)

#     print(f"{trafficname}:{leafspinefct},{dringfct}")
#     ratiolist.append((dringfct-leafspinefct)/leafspinefct)
# print(sum(ratiolist)/len(ratiolist))
# print(ratiolist)

# %%
# # # analysis, should comment out by default
# testloaddatadict = dict()
# testloaddatadict = {"unv1":20,"prv1":16,"cluster_a":50,"cluster_b":60,"cluster_c":90}

# ratiolist = list()
# for trafficname in trafficnamedatalist:
#     leafspinemultname = testloaddatadict[trafficname]
#     with open(sumfiledatadict[trafficname]["fhi"],'r') as f:
#         lines = f.readlines()
#         fct_over_fseed = list()
#         for fseed in fseedarr:
#             logfile = f"m_dring_{trafficname}_{leafspinemultname}_{fseed}.log"
#             # print(logfile)
#             for line in lines:
#                 tokens = line.split()
#                 if tokens[0] == logfile:
#                     # print("yes")
#                     n99fct = float(tokens[3])
#                     fct_over_fseed.append(n99fct)
#         leafspinefct = sum(fct_over_fseed)/len(fct_over_fseed)

#     # dringmultname = testloaddatadict[trafficname]["dring"]
#     with open(sumfiledatadict[trafficname]["dring"],'r') as f:
#         lines = f.readlines()
#         fct_over_fseed = list()
#         for fseed in fseedarr:
#             logfile = f"m_dring_{trafficname}_{leafspinemultname}_{fseed}.log"
#             for line in lines:
#                 tokens = line.split()
#                 if tokens[0] == logfile:
#                     n99fct = float(tokens[3])
#                     fct_over_fseed.append(n99fct)
#         dringfct = sum(fct_over_fseed)/len(fct_over_fseed)

#     print(f"{trafficname}:{leafspinefct},{dringfct}")
#     ratiolist.append((dringfct-leafspinefct)/leafspinefct)
# print(sum(ratiolist)/len(ratiolist))
# print(ratiolist)

# %%
# # # analysis, should comment out by default
# testloaddatadict = dict()
# testloaddatadict = {"unv1":35,"prv1":0,"cluster_a":90,"cluster_b":0,"cluster_c":90}

# ratiolist = list()
# for trafficname in ["unv1","cluster_a","cluster_c"]:
#     leafspinemultname = testloaddatadict[trafficname]
#     with open(sumfiledatadict[trafficname]["racke"],'r') as f:
#         lines = f.readlines()
#         fct_over_fseed = list()
#         for fseed in fseedarr:
#             logfile = f"m_dring_{trafficname}_0_{leafspinemultname}_{fseed}.log"
#             # print(logfile)
#             for line in lines:
#                 tokens = line.split()
#                 if tokens[0] == logfile:
#                     # print("yes")
#                     n99fct = float(tokens[3])
#                     fct_over_fseed.append(n99fct)
#         leafspinefct = sum(fct_over_fseed)/len(fct_over_fseed)

#     # dringmultname = testloaddatadict[trafficname]["dring"]
#     with open(sumfiledatadict[trafficname]["dring"],'r') as f:
#         lines = f.readlines()
#         fct_over_fseed = list()
#         for fseed in fseedarr:
#             logfile = f"m_dring_{trafficname}_{leafspinemultname}_{fseed}.log"
#             for line in lines:
#                 tokens = line.split()
#                 if tokens[0] == logfile:
#                     n99fct = float(tokens[3])
#                     fct_over_fseed.append(n99fct)
#         dringfct = sum(fct_over_fseed)/len(fct_over_fseed)

#     print(f"{trafficname}:{leafspinefct},{dringfct}")
#     ratiolist.append((dringfct-leafspinefct)/leafspinefct)
# print(sum(ratiolist)/len(ratiolist))
# print(ratiolist)
# Out:
# unv1:42.81634,28.055500000000002
# cluster_a:9.160696,4.345872
# cluster_c:15.858960000000002,1.919586
# -0.5831008641161327
# [-0.34474782291059897, -0.5255958717547226, -0.8789588976830763]
