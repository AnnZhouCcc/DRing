# %% [markdown]
# solve
# inspired by https://github.com/AnnZhouCcc/topobench/blob/master/lpmaker/graphs/Graph.java#L1382

# %%
# set parameters
graphname = "dring"
numsw = 80
numport = 64
numserver = 2988
numfaillink = 0
numlink = 2132
fseed = 0
homedir = "/home/annzhou"

method = 2
crossover = 0
factor = 64


clist = [64,48,32,16,4]
s=4
multlist = [[1,44,100],[1,92,100],[2,88,100],[5,76,100],[23,0,0]]
tseedlist = range(5)


for ic,c in enumerate(clist):
    mult = multlist[ic][0]
    numerator = multlist[ic][1]
    denominator = multlist[ic][2]
    multstr = f"{mult}_{numerator}_{denominator}"
    for tseed in tseedlist:
        trafficname = f"c2s_{c}_{s}_{tseed}_{multstr}"
        flowfile = f"{homedir}/DRing/src/emp/datacentre/flowfiles/c2s_{c}_{s}_{multstr}_{tseed}"

        routingdict = dict()
        with open(f"{homedir}/DRing/src/emp/datacentre/experiments/torbottleneck/whatrouting.txt",'r') as f:
            lines = f.readlines()
            for line in lines:
                tokens = line.split(',')
                if tokens[0]==flowfile:
                    routingdict[tokens[1]] = float(tokens[2])
        if max(routingdict.values()) == routingdict["ecmp"]:
            routingname = "ecmp"
        elif max(routingdict.values()) == routingdict["su2"]:
            routingname = "su2"
        elif max(routingdict.values()) == routingdict["su3"]:
            routingname = "su3"

        if graphname=="dring" or graphname=="rrg":
            netpathfile = f"{homedir}/DRing/src/emp/datacentre/netpathfiles/netpath_{routingname}_{graphname}.txt"
        else:
            print("ERROR: leafspine does not need to compute path weight")

        if graphname=="dring":
            graphfile = f"{homedir}/DRing/src/emp/datacentre/graphfiles/ring_supergraph/double_ring/instance1_{numsw}_{numport}.edgelist"
        elif graphname=="rrg":
            graphfile = f"{homedir}/DRing/src/emp/datacentre/graphfiles/ring_supergraph/rrg/instance1_{numsw}_{numport}.edgelist"
        else:
            print("ERROR: leafspine does not need to compute path weight")

        linkfailurefile = f"{homedir}/DRing/src/emp/datacentre/linkfailurefiles/{graphname}_{numlink}_{numfaillink}_{fseed}"

        serverfile = f"{homedir}/DRing/src/emp/datacentre/serverfiles/{graphname}_{numserver}_{numsw}_{numport}"

        tag = f"{graphname}_{numfaillink}_{fseed}_{routingname}_{trafficname}_{method}_{crossover}_{factor}"
        varfile = f"{homedir}/DRing/src/emp/datacentre/qvarfiles/var_{tag}"
        qvarfile = f"{homedir}/DRing/src/emp/datacentre/qvarfiles/qvar_{tag}"
        modelfile = f"{homedir}/DRing/src/emp/datacentre/makepathweightfiles/model.lp"


        # read netpathfile
        netpath = list()
        for i in range(numsw):
            netpath.append(list())
            for j in range(numsw):
                netpath[i].append(list())
        with open(netpathfile,'r') as f:
            lines = f.readlines()
            # produce
            fromsw = 0
            tosw = 0
            for line in lines:
                if "->" not in line:
                    tokens = line.split()
                    fromsw = int(tokens[0])
                    tosw = int(tokens[1])
                else:
                    path = [fromsw]
                    tokens = line.split()
                    for token in tokens:
                        hops = token.split("->")
                        path.append(int(hops[1]))
                    netpath[fromsw][tosw].append(path)

            # check
            for line in lines:
                if "->" not in line:
                    tokens = line.split()
                    fromsw = int(tokens[0])
                    tosw = int(tokens[1])
                    numpaths = int(tokens[2])
                    if len(netpath[fromsw][tosw])!=numpaths:
                        print(f"ERROR: netpath is wrong, fromsw={fromsw}, tosw={tosw}, numpaths from file={numpaths}, numpaths from array={len(netpath[fromsw][tosw])}")

        # read graphfile
        link = list()
        for i in range(numsw):
            link.append(list())
            for j in range(numsw):
                link[i].append(0)
        with open(graphfile,'r') as f:
            lines = f.readlines()
            for line in lines:
                tokens = line.split("->")
                fromsw = int(tokens[0])
                tosw = int(tokens[1])
                link[fromsw][tosw] = 1
                link[tosw][fromsw] = 1

        # read linkfailurefile (if needed)
        if numfaillink > 0:
            with open(linkfailurefile,'r') as f:
                lines = f.readlines()
                for line in lines:
                    tokens = line.split()
                    fromsw = int(tokens[0])
                    tosw = int(tokens[1])
                    if link[fromsw][tosw] != 1:
                        print(f"ERROR: should have a link from {fromsw} to {tosw} but not")
                    else:
                        link[fromsw][tosw] /= 2

        # read serverfile
        serverdict = dict()
        with open(serverfile,'r') as f:
            lines = f.readlines()
            for line in lines:
                tokens = line.split(',')
                serverdict[int(tokens[0])] = int(tokens[1])

        # read flowfile
        traffic = list()
        for i in range(numsw):
            traffic.append(list())
            for j in range(numsw):
                traffic[i].append(0)
        with open(flowfile,'r') as f:
            lines = f.readlines()
            for line in lines:
                tokens = line.split(",")
                fromsvr = int(tokens[0])
                tosvr = int(tokens[1])
                if fromsvr>=numserver or tosvr>=numserver: continue
                fromsw = serverdict[fromsvr]
                tosw = serverdict[tosvr]
                if fromsw == tosw: continue
                flowbytes = int(tokens[2])
                traffic[fromsw][tosw] += flowbytes


        # precompute
        flowsvialink = list()
        for i in range(numsw):
            flowsvialink.append(list())
            for j in range(numsw):
                flowsvialink[i].append(list())
        for fromsw in range(numsw):
            for tosw in range(numsw):
                if traffic[fromsw][tosw] > 0:
                    for pid,path in enumerate(netpath[fromsw][tosw]):
                        fidpidstr = f"{fromsw},{tosw},{pid}"
                        prevhop = fromsw
                        for hop in path[1:]:
                            flowsvialink[prevhop][hop].append(fidpidstr)
                            prevhop = hop

        for fromsw in range(numsw):
            for tosw in range(numsw):
                traffic[fromsw][tosw] /= 100000


        import gurobipy as gp
        from gurobipy import GRB

        # Create a new model
        model = gp.Model("mcf")

        # Add variables
        maxpid = 0
        for fromsw in range(numsw):
            for tosw in range(numsw):
                maxpid = max(maxpid,len(netpath[fromsw][tosw]))
        vararr = list()
        for fromsw in range(numsw):
            vararr.append(list())
            for tosw in range(numsw):
                vararr[fromsw].append(list())
                for pid in range(maxpid):
                    vararr[fromsw][tosw].append(None)
        for fromsw in range(numsw):
            for tosw in range(numsw):
                if traffic[fromsw][tosw] > 0:
                    for pid in range(len(netpath[fromsw][tosw])):
                        var = model.addVar(name=f"{fromsw}_{tosw}_{pid}")
                        vararr[fromsw][tosw][pid] = var
        k = model.addVar(name="k")

        # Set objective function
        model.setObjective(k, GRB.MAXIMIZE)

        # Add constraints
        # Constraint 0: for each fid: sum(pid) >= k * traffic[fid.from][fid.to]
        for fromsw in range(numsw):
            for tosw in range(numsw):
                if traffic[fromsw][tosw] > 0:
                    varlist = list()
                    for pid in range(len(netpath[fromsw][tosw])):
                        varlist.append(vararr[fromsw][tosw][pid])
                    model.addConstr(sum(varlist)>=k*traffic[fromsw][tosw],f"c0_{fromsw}_{tosw}")

        # Constraint 1: for each link: sum(fid_pid) <= link[link.from][link.to]
        for linkfrom in range(numsw):
            for linkto in range(numsw):
                flowstrlist = flowsvialink[linkfrom][linkto]
                if len(flowstrlist) > 0:
                    varlist = list()
                    for flowstr in flowstrlist:
                        tokens = flowstr.split(',')
                        flowfrom = int(tokens[0])
                        flowto = int(tokens[1])
                        pid = int(tokens[2])
                        varlist.append(vararr[flowfrom][flowto][pid])
                    model.addConstr(sum(varlist)<=link[linkfrom][linkto],f"c1_{linkfrom}_{linkto}")

        # Optimize model
        model.setParam('Method',method)
        model.setParam('Crossover',crossover)
        model.optimize()
        # model.write(modelfile)

        # Print results
        if model.status == GRB.OPTIMAL:
            print(f"Optimal objective value: {model.objVal}")
            with open(varfile,'w') as f:
                f.write(f"{k.varName},{k.x}\n")
                for fromsw in range(numsw):
                    for tosw in range(numsw):
                        if traffic[fromsw][tosw] > 0:
                            for pid in range(len(netpath[fromsw][tosw])):
                                var = vararr[fromsw][tosw][pid]
                                f.write(f"{var.varName},{var.x}\n")
        else:
            print("No optimal solution found")


        import random
        random.seed(0)

        def quantize_to_multiple_of_1_64(x,factor):
            return round(x * factor) / factor

        def quantize_and_adjust_with_indices(indexed_values,factor,isprint=False):
            if isprint: print(indexed_values)
            # Quantize each value
            quantized_values = [(i, quantize_to_multiple_of_1_64(v,factor)) for i, v in indexed_values]
            if isprint: print(quantized_values)
            
            # Calculate the current sum
            current_sum = sum(v for _, v in quantized_values)
            
            # Calculate the difference between the sum and 1
            difference = current_sum - 1
            if isprint: print(f"currsum={current_sum}, difference={difference}")

            random_values = [(v, random.random()) for v in quantized_values]
            if isprint: print(random_values)
            
            if difference != 0:
                if difference > 0:
                    # Sort indices by quantized values to adjust the largest values first
                    sorted_random = sorted(random_values, key=lambda x: (x[0][1],x[1]), reverse=True)
                    # sorted_quantized = sorted(quantized_values, key=lambda x: x[1], reverse=True)
                    sorted_quantized = [v for v,_ in sorted_random]
                    if isprint: print(sorted_random)
                    if isprint: print(sorted_quantized)
                    
                    while difference !=0:
                        for i, value in sorted_quantized:
                            if difference == 0:
                                break
                            # Calculate adjustment
                            # adjustment = min(difference, value % (1 / factor))
                            # adjustment = difference
                            new_value = value - 1.0/factor
                            
                            # Update the quantized values
                            quantized_values = [(idx, new_value if idx == i else v) for idx, v in quantized_values]
                            difference -= 1.0/factor
                        
                else:
                    # If the difference is negative (i.e., sum is less than 1), we need to increase values
                    # sorted_quantized = sorted(quantized_values, key=lambda x: x[1])
                    sorted_random = sorted(random_values, key=lambda x: (x[0][1],x[1]))
                    # sorted_quantized = sorted(quantized_values, key=lambda x: x[1], reverse=True)
                    sorted_quantized = [v for v,_ in sorted_random]
                    
                    while difference != 0:
                        for i, value in sorted_quantized:
                            if difference == 0:
                                break
                            # Calculate adjustment
                            # adjustment = min(-difference, (1 / factor) - (value % (1 / factor)))
                            # adjustment = -difference
                            new_value = value + 1.0/factor
                            
                            # Update the quantized values
                            quantized_values = [(idx, new_value if idx == i else v) for idx, v in quantized_values]
                            difference += 1.0/factor
            
            # Return the list sorted by original indices
            # return [v for i, v in sorted(quantized_values)]
            if isprint: print(quantized_values)
            return quantized_values


        with open(varfile,'r') as f:
            lines = f.readlines()[1:]

        valuearr = list()
        weightarr = list()
        qweightarr = list()
        for i in range(numsw):
            valuearr.append(list())
            weightarr.append(list())
            qweightarr.append(list())
            for j in range(numsw):
                valuearr[i].append(list())
                weightarr[i].append(list())
                qweightarr[i].append(list()) 

        for line in lines:
            tokens = line.split(',')
            varname = tokens[0]
            vartokens = varname.split('_')
            fromsw = int(vartokens[0])
            tosw = int(vartokens[1])
            pid = int(vartokens[2])
            value = float(tokens[1])
            valuearr[fromsw][tosw].append([pid,value])
            weightarr[fromsw][tosw].append([pid,value])

        for fromsw in range(numsw):
            for tosw in range(numsw):
                if len(valuearr[fromsw][tosw])>0:
                    valuesum = 0
                    for _,value in valuearr[fromsw][tosw]:
                        valuesum += value
                    valuetoweight = 1.0/valuesum
                    for ipv,pv in enumerate(weightarr[fromsw][tosw]):
                        weightarr[fromsw][tosw][ipv][1] = pv[1] * valuetoweight

        for fromsw in range(numsw):
            for tosw in range(numsw):
                if len(weightarr[fromsw][tosw])>0:
                    qweightarr[fromsw][tosw] = quantize_and_adjust_with_indices(weightarr[fromsw][tosw],factor)

        with open(qvarfile,'w') as f:
            for fromsw in range(numsw):
                for tosw in range(numsw):
                    if len(qweightarr[fromsw][tosw])>0:
                        for pid,weight in qweightarr[fromsw][tosw]:
                            if weight>0:
                                f.write(f"{fromsw},{tosw},{pid},{weight}\n")


        # check qvarfile
        checkweightarr = list()
        for i in range(numsw):
            checkweightarr.append(list())
            for j in range(numsw):
                checkweightarr[i].append(0)
        with open(qvarfile,'r') as f:
            lines = f.readlines()
            for line in lines:
                tokens = line.split(',')
                fromsw = int(tokens[0])
                tosw = int(tokens[1])
                pid = int(tokens[2])
                weight = float(tokens[3])
                checkweightarr[fromsw][tosw] += weight

        for fromsw in range(numsw):
            for tosw in range(numsw):
                if checkweightarr[fromsw][tosw]!=0 and checkweightarr[fromsw][tosw]!=1:
                    print(f"from {fromsw} to {tosw}: weight={checkweightarr[fromsw][tosw]}")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-01-09
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2843 rows, 173971 columns and 689730 nonzeros
# Model fingerprint: 0x8e6858b6
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.35s
# Presolved: 2843 rows, 173971 columns, 689730 nonzeros
# Ordering time: 0.20s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 3.953e+05
#  Factor NZ  : 1.241e+06 (roughly 80 MB of memory)
#  Factor Ops : 8.423e+08 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.33585437e-02  2.85063353e-03  4.29e+02 7.28e-04  6.70e-02     1s
#    1   6.77179003e-05  1.05566414e+01  2.79e+02 1.95e-02  4.45e-02     1s
#    2   3.15298998e-03  1.33088665e+01  6.45e+01 1.03e-03  1.12e-02     1s
#    3   5.83846949e-04  1.00398153e+01  8.72e+00 1.25e-04  1.71e-03     1s
#    4   4.53152433e-04  7.32800970e+00  3.20e+00 0.00e+00  7.01e-04     1s
#    5   1.57557588e-04  5.61548141e+00  8.17e-02 1.26e-04  1.42e-04     1s
#    6   1.53109983e-04  9.11880670e-02  3.44e-15 1.42e-07  2.06e-06     1s
#    7   1.87371236e-04  1.79663004e-02  2.16e-15 6.40e-10  4.03e-07     1s
#    8   2.46600738e-04  6.49278420e-03  1.78e-15 0.00e+00  1.42e-07     1s
#    9   3.31058130e-04  3.76016434e-03  1.89e-15 0.00e+00  7.77e-08     1s
#   10   3.85624330e-04  2.38152915e-03  1.89e-15 0.00e+00  4.52e-08     1s
#   11   4.42255606e-04  1.73376068e-03  1.39e-15 0.00e+00  2.93e-08     1s
#   12   4.04496375e-04  1.51702562e-03  3.11e-15 0.00e+00  2.52e-08     2s
#   13   4.29097108e-04  8.93131357e-04  2.00e-15 0.00e+00  1.05e-08     2s
#   14   5.11393043e-04  5.88058706e-04  4.88e-15 0.00e+00  1.74e-09     2s
#   15   5.12944329e-04  5.13127334e-04  1.67e-14 2.06e-17  4.15e-12     2s
#   16   5.12953930e-04  5.12954113e-04  1.10e-14 2.11e-17  4.15e-15     2s
#
# Barrier solved model in 16 iterations and 1.77 seconds (1.10 work units)
# Optimal objective 5.12953930e-04
#
# Optimal objective value: 0.0005129539296888995
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2764 rows, 156549 columns and 620672 nonzeros
# Model fingerprint: 0xa5d16ef7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.29s
# Presolved: 2764 rows, 156549 columns, 620672 nonzeros
# Ordering time: 0.15s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 3.598e+05
#  Factor NZ  : 1.293e+06 (roughly 70 MB of memory)
#  Factor Ops : 7.936e+08 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.41962578e-02  2.34046338e-03  3.05e+02 1.98e-04  6.98e-02     1s
#    1   1.28597685e-04  2.42480352e+01  1.62e+02 1.49e-02  3.76e-02     1s
#    2   6.62865397e-03  2.39803131e+01  6.56e+01 3.22e-03  1.54e-02     1s
#    3   1.38090551e-03  1.71644495e+01  1.17e+01 1.36e-03  2.91e-03     1s
#    4   3.50652786e-04  1.14550879e+01  2.24e+00 5.35e-04  6.58e-04     1s
#    5   1.38098768e-04  1.03891555e+01  5.71e-02 4.58e-04  1.49e-04     1s
#    6   1.31798994e-04  4.64780977e-01  3.16e-15 1.48e-06  5.91e-06     1s
#    7   1.58229398e-04  5.52306384e-02  3.00e-15 1.56e-07  7.00e-07     1s
#    8   2.34914923e-04  2.14161238e-02  2.00e-15 5.27e-08  2.69e-07     1s
#    9   3.25041656e-04  6.92264955e-03  2.11e-15 4.93e-10  8.37e-08     1s
#   10   4.00272463e-04  3.48399233e-03  1.89e-15 0.00e+00  3.91e-08     1s
#   11   4.61734834e-04  1.74375653e-03  1.61e-15 0.00e+00  1.62e-08     1s
#   12   4.73716748e-04  1.05176313e-03  1.72e-15 0.00e+00  7.31e-09     1s
#   13   4.54767072e-04  8.99797973e-04  2.10e-14 0.00e+00  5.62e-09     1s
#   14   5.18191154e-04  5.79523275e-04  1.19e-14 0.00e+00  7.72e-10     2s
#   15   5.41578075e-04  5.43805006e-04  2.41e-14 0.00e+00  2.80e-11     2s
#   16   5.41934351e-04  5.41941023e-04  1.03e-13 0.00e+00  8.39e-14     2s
#
# Barrier solved model in 16 iterations and 1.65 seconds (0.95 work units)
# Optimal objective 5.41934351e-04
#
# Optimal objective value: 0.0005419343509280034
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2602 rows, 155509 columns and 616542 nonzeros
# Model fingerprint: 0xb2b63d48
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.35s
# Presolved: 2602 rows, 155509 columns, 616542 nonzeros
# Ordering time: 0.13s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 3.471e+05
#  Factor NZ  : 8.835e+05 (roughly 70 MB of memory)
#  Factor Ops : 4.846e+08 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.29754307e-03  1.12615953e-03  1.02e+02 4.05e-04  2.03e-02     1s
#    1   1.05042996e-05  1.22569094e+00  4.91e+01 6.49e-02  9.86e-03     1s
#    2   3.11461619e-03  1.96965552e+00  4.44e+01 5.39e-02  8.97e-03     1s
#    3   6.34562863e-04  2.31121042e+00  1.09e+01 4.39e-02  2.38e-03     1s
#    4   3.66660887e-04  1.89378963e+00  3.90e+00 1.84e-02  9.00e-04     1s
#    5   2.88237871e-04  1.48042048e+00  8.68e-01 1.02e-02  2.34e-04     1s
#    6   1.95937480e-04  1.34569249e+00  1.95e-01 4.30e-03  7.64e-05     1s
#    7   1.56336602e-04  8.57990736e-01  1.02e-03 1.79e-03  2.48e-05     1s
#    8   1.58512958e-04  1.09742697e-01  1.64e-06 2.07e-04  3.12e-06     1s
#    9   1.79537272e-04  6.52595397e-03  5.55e-16 1.16e-05  1.81e-07     1s
#   10   2.94306489e-04  2.24757653e-03  4.72e-16 3.74e-06  5.51e-08     1s
#   11   3.68050254e-04  1.65489246e-03  4.72e-16 2.20e-06  3.60e-08     1s
#   12   3.96468783e-04  1.33067983e-03  3.61e-16 1.59e-06  2.61e-08     1s
#   13   4.21412332e-04  1.05552826e-03  3.33e-16 1.05e-06  1.76e-08     1s
#   14   4.67083295e-04  8.76943813e-04  4.69e-15 6.87e-07  1.14e-08     1s
#   15   4.85005756e-04  5.50557639e-04  8.88e-16 5.94e-08  1.77e-09     2s
#   16   4.97306639e-04  5.03076876e-04  2.25e-14 2.17e-09  1.51e-10     2s
#   17   4.97727309e-04  4.97790720e-04  6.25e-13 3.88e-12  1.61e-12     2s
#   18   4.97763796e-04  4.97763797e-04  9.57e-13 2.99e-17  1.44e-17     2s
#
# Barrier solved model in 18 iterations and 1.72 seconds (0.97 work units)
# Optimal objective 4.97763796e-04
#
# Optimal objective value: 0.0004977637959383598
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2922 rows, 193543 columns and 767328 nonzeros
# Model fingerprint: 0x3ec6046e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.41s
# Presolved: 2922 rows, 193543 columns, 767328 nonzeros
# Ordering time: 0.20s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 4.445e+05
#  Factor NZ  : 1.876e+06 (roughly 100 MB of memory)
#  Factor Ops : 1.626e+09 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.92818421e-03  1.31623271e-03  8.17e+01 4.05e-04  1.67e-02     1s
#    1   1.06464208e-05  1.44787822e+00  3.50e+01 6.24e-02  7.25e-03     1s
#    2   1.94119506e-03  2.43228212e+00  3.27e+01 5.23e-02  6.82e-03     1s
#    3   3.87560138e-04  3.54556957e+00  5.11e+00 2.25e-02  1.15e-03     1s
#    4   2.93624158e-04  2.42823962e+00  1.24e+00 1.05e-02  3.18e-04     1s
#    5   2.53368190e-04  1.69836600e+00  4.31e-01 5.73e-03  1.28e-04     1s
#    6   1.87048276e-04  1.30929872e+00  2.25e-02 2.52e-03  3.34e-05     1s
#    7   1.80387768e-04  6.96279727e-01  2.41e-15 1.24e-03  1.59e-05     1s
#    8   1.83462125e-04  6.02422581e-03  7.22e-16 1.04e-05  1.33e-07     1s
#    9   2.85019009e-04  3.09833004e-03  6.66e-16 4.80e-06  6.35e-08     2s
#   10   3.70614665e-04  2.70142725e-03  4.44e-16 4.09e-06  5.27e-08     2s
#   11   4.34487037e-04  1.80555948e-03  1.72e-14 2.28e-06  3.08e-08     2s
#   12   4.54570832e-04  1.17340883e-03  9.48e-15 1.07e-06  1.60e-08     2s
#   13   4.84402475e-04  5.97614581e-04  2.78e-15 1.23e-07  2.47e-09     2s
#   14   4.86943086e-04  4.92085354e-04  4.28e-14 2.11e-09  1.08e-10     2s
#   15   4.88020018e-04  4.88033787e-04  3.68e-13 9.85e-13  2.82e-13     2s
#   16   4.88021512e-04  4.88021512e-04  2.11e-12 3.47e-17  2.85e-19     2s
#
# Barrier solved model in 16 iterations and 1.96 seconds (1.25 work units)
# Optimal objective 4.88021512e-04
#
# Optimal objective value: 0.00048802151198675903
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2922 rows, 194583 columns and 771458 nonzeros
# Model fingerprint: 0x193796cd
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.46s
# Presolved: 2922 rows, 194583 columns, 771458 nonzeros
# Ordering time: 0.22s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 4.512e+05
#  Factor NZ  : 1.911e+06 (roughly 100 MB of memory)
#  Factor Ops : 1.679e+09 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.99897278e-03  1.26727690e-03  8.49e+01 3.48e-04  1.75e-02     1s
#    1   9.25827953e-06  1.55522670e+00  3.50e+01 5.32e-02  7.30e-03     1s
#    2   1.75660356e-03  2.62732490e+00  3.23e+01 3.86e-02  6.80e-03     1s
#    3   2.54079548e-04  3.60170207e+00  3.62e+00 1.45e-02  8.39e-04     1s
#    4   2.15016035e-04  2.23008634e+00  9.87e-01 6.01e-03  2.60e-04     1s
#    5   1.62159314e-04  1.77502993e+00  2.47e-01 3.49e-03  9.01e-05     1s
#    6   1.49293838e-04  1.38890763e+00  8.82e-02 2.18e-03  4.59e-05     1s
#    7   1.36980327e-04  1.06050440e+00  8.88e-16 1.44e-03  2.36e-05     2s
#    8   1.38735082e-04  6.86018803e-03  7.63e-16 9.13e-06  1.50e-07     2s
#    9   2.55826277e-04  3.35299817e-03  5.83e-16 4.34e-06  6.85e-08     2s
#   10   3.43865800e-04  2.34537506e-03  4.72e-16 2.59e-06  4.40e-08     2s
#   11   4.25946451e-04  1.60559320e-03  4.44e-16 1.40e-06  2.59e-08     2s
#   12   4.64959968e-04  1.08305742e-03  7.22e-16 6.83e-07  1.35e-08     2s
#   13   4.93918804e-04  5.35243478e-04  8.05e-16 2.45e-08  8.78e-10     2s
#   14   5.00711677e-04  5.01036033e-04  2.48e-15 1.35e-10  6.78e-12     2s
#   15   5.00721414e-04  5.00721749e-04  2.39e-15 4.98e-17  6.78e-15     2s
#
# Barrier solved model in 15 iterations and 2.20 seconds (1.24 work units)
# Optimal objective 5.00721414e-04
#
# Optimal objective value: 0.0005007214142723872
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2631 rows, 127731 columns and 506406 nonzeros
# Model fingerprint: 0x47bf0ea7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.24s
# Presolved: 2631 rows, 127731 columns, 506406 nonzeros
# Ordering time: 0.14s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 2.999e+05
#  Factor NZ  : 1.011e+06 (roughly 60 MB of memory)
#  Factor Ops : 5.668e+08 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.68964975e-03  1.28097531e-03  9.14e+01 5.36e-04  2.18e-02     1s
#    1   1.12025312e-05  1.36414527e+00  4.73e+01 5.96e-02  1.15e-02     1s
#    2   3.21642087e-03  3.16457254e+00  3.65e+01 1.86e-02  9.06e-03     1s
#    3   7.26931035e-04  2.99883536e+00  2.63e+00 3.37e-03  7.38e-04     1s
#    4   5.69817841e-04  1.75087337e+00  1.21e+00 1.50e-03  3.52e-04     1s
#    5   3.48972310e-04  1.41509381e+00  3.20e-01 8.71e-04  1.19e-04     1s
#    6   2.37342322e-04  9.27059671e-01  1.18e-15 4.09e-04  2.92e-05     1s
#    7   2.38595042e-04  3.87658776e-03  5.27e-16 1.55e-06  1.15e-07     1s
#    8   3.50236308e-04  2.57438117e-03  5.13e-16 7.62e-07  6.99e-08     1s
#    9   3.87095665e-04  1.69396605e-03  3.89e-16 3.25e-07  4.10e-08     1s
#   10   4.18109232e-04  1.59584264e-03  4.16e-16 4.67e-07  3.70e-08     1s
#   11   4.53811551e-04  9.08104768e-04  6.77e-15 1.50e-07  1.42e-08     1s
#   12   4.78988694e-04  6.00694556e-04  2.55e-15 1.68e-08  3.78e-09     1s
#   13   4.86844588e-04  5.05625799e-04  1.33e-15 1.04e-09  5.80e-10     1s
#   14   4.95153211e-04  4.96207791e-04  2.21e-15 0.00e+00  3.25e-11     1s
#   15   4.95364976e-04  4.95366055e-04  1.29e-15 4.39e-17  3.31e-14     1s
#
# Barrier solved model in 15 iterations and 1.34 seconds (0.75 work units)
# Optimal objective 4.95364976e-04
#
# Optimal objective value: 0.0004953649761081642
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2762 rows, 151447 columns and 600295 nonzeros
# Model fingerprint: 0xee857bfd
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.34s
# Presolved: 2762 rows, 151447 columns, 600295 nonzeros
# Ordering time: 0.18s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 3.598e+05
#  Factor NZ  : 1.737e+06 (roughly 80 MB of memory)
#  Factor Ops : 1.418e+09 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.15440740e-03  1.83515169e-03  1.22e+02 9.50e-04  2.76e-02     1s
#    1   1.85132557e-05  2.17678188e+00  7.15e+01 6.20e-02  1.64e-02     1s
#    2   4.18668209e-03  3.80875774e+00  5.29e+01 3.69e-02  1.24e-02     1s
#    3   6.05356340e-04  4.98807907e+00  8.99e+00 9.21e-03  2.22e-03     1s
#    4   3.70926901e-04  3.36256732e+00  3.73e+00 3.25e-03  9.49e-04     1s
#    5   1.83943104e-04  2.56105244e+00  8.97e-01 2.05e-03  2.75e-04     1s
#    6   1.45804031e-04  2.05446469e+00  2.34e-01 1.18e-03  1.04e-04     1s
#    7   1.37239864e-04  1.56669748e+00  1.99e-02 7.69e-04  4.62e-05     1s
#    8   1.37705701e-04  4.88453892e-02  1.39e-15 5.77e-06  1.29e-06     1s
#    9   1.51772885e-04  1.01025575e-02  9.99e-16 1.12e-06  2.64e-07     1s
#   10   2.27470425e-04  4.55164644e-03  8.60e-16 4.55e-07  1.15e-07     1s
#   11   3.31022976e-04  2.86089101e-03  7.22e-16 4.47e-07  6.70e-08     1s
#   12   3.86372800e-04  1.45820031e-03  6.38e-16 1.64e-07  2.83e-08     1s
#   13   4.16297533e-04  8.82607002e-04  1.28e-15 5.91e-08  1.23e-08     2s
#   14   4.44538399e-04  5.58152204e-04  1.03e-15 1.29e-08  2.98e-09     2s
#   15   4.56179937e-04  5.10012364e-04  3.08e-15 4.68e-09  1.41e-09     2s
#   16   4.62271162e-04  4.77271810e-04  3.55e-15 2.36e-10  3.90e-10     2s
#   17   4.65875938e-04  4.72502135e-04  1.59e-13 2.76e-11  1.72e-10     2s
#   18   4.67946896e-04  4.71173123e-04  4.45e-13 1.08e-19  8.38e-11     2s
#   19   4.70789848e-04  4.70871560e-04  3.78e-13 8.79e-17  2.12e-12     2s
#   20   4.70817822e-04  4.70817903e-04  5.34e-14 1.26e-19  2.12e-15     2s
#
# Barrier solved model in 20 iterations and 1.96 seconds (1.12 work units)
# Optimal objective 4.70817822e-04
#
# Optimal objective value: 0.00047081782156549934
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2426 rows, 23393 columns and 88776 nonzeros
# Model fingerprint: 0x31f9335d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.05s
# Presolved: 2426 rows, 23393 columns, 88776 nonzeros
# Ordering time: 0.02s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 6.083e+04
#  Factor NZ  : 1.689e+05 (roughly 12 MB of memory)
#  Factor Ops : 1.969e+07 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.45528054e-03  1.13710574e-03  2.20e+01 6.21e-04  2.78e-02     0s
#    1   2.28944457e-05  1.74840683e+00  1.33e+01 3.65e-02  1.68e-02     0s
#    2   2.63199284e-03  3.03102558e+00  5.59e+00 0.00e+00  7.76e-03     0s
#    3   4.85793888e-04  2.01340249e+00  4.06e-01 0.00e+00  8.13e-04     0s
#    4   1.86023847e-04  1.23207553e+00  6.07e-03 0.00e+00  1.98e-04     0s
#    5   1.75307092e-04  1.67419798e-01  5.55e-16 0.00e+00  2.61e-05     0s
#    6   1.80054744e-04  2.38613489e-03  5.55e-16 0.00e+00  3.45e-07     0s
#    7   3.20470073e-04  1.60363021e-03  3.89e-16 0.00e+00  2.00e-07     0s
#    8   4.20691840e-04  1.24713365e-03  3.33e-16 0.00e+00  1.29e-07     0s
#    9   4.68404236e-04  7.97707864e-04  3.33e-16 0.00e+00  5.14e-08     0s
#   10   4.89037780e-04  5.55515351e-04  2.14e-15 0.00e+00  1.04e-08     0s
#   11   5.03581170e-04  5.30740479e-04  1.09e-14 0.00e+00  4.24e-09     0s
#   12   5.15917934e-04  5.18320800e-04  1.13e-13 5.42e-20  3.75e-10     0s
#   13   5.16686356e-04  5.16776366e-04  5.83e-12 4.20e-17  1.41e-11     0s
#   14   5.16687720e-04  5.16687810e-04  2.54e-11 9.39e-20  1.41e-14     0s
#
# Barrier solved model in 14 iterations and 0.25 seconds (0.13 work units)
# Optimal objective 5.16687720e-04
#
# Optimal objective value: 0.0005166877202709288
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2711 rows, 153534 columns and 608594 nonzeros
# Model fingerprint: 0x7aaff7a3
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.33s
# Presolved: 2711 rows, 153534 columns, 608594 nonzeros
# Ordering time: 0.17s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 3.558e+05
#  Factor NZ  : 1.505e+06 (roughly 70 MB of memory)
#  Factor Ops : 1.072e+09 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.83765171e-03  1.34639496e-03  9.31e+01 4.35e-04  2.23e-02     1s
#    1   1.12040215e-05  1.51500498e+00  4.32e+01 5.53e-02  1.05e-02     1s
#    2   3.18625489e-03  2.78145351e+00  3.80e+01 3.74e-02  9.36e-03     1s
#    3   6.36300694e-04  3.51693876e+00  4.66e+00 1.14e-02  1.24e-03     1s
#    4   4.45594356e-04  2.15879290e+00  1.07e+00 6.35e-03  3.25e-04     1s
#    5   3.41674991e-04  1.65132367e+00  3.68e-01 4.10e-03  1.36e-04     1s
#    6   2.73788450e-04  1.27946042e+00  1.31e-01 2.20e-03  6.14e-05     1s
#    7   2.18822164e-04  1.15388387e+00  3.43e-04 2.04e-03  3.30e-05     1s
#    8   2.20007248e-04  2.12104235e-02  2.75e-06 3.83e-05  5.99e-07     1s
#    9   2.77439775e-04  3.06072517e-03  6.11e-16 3.85e-06  7.83e-08     1s
#   10   3.64163261e-04  1.97413607e-03  5.41e-16 1.94e-06  4.48e-08     1s
#   11   4.38278511e-04  1.35379605e-03  4.16e-16 1.05e-06  2.54e-08     1s
#   12   4.60366764e-04  7.46326961e-04  4.44e-16 2.81e-07  7.85e-09     1s
#   13   4.83319956e-04  4.95132965e-04  1.42e-15 5.02e-09  3.14e-10     2s
#   14   4.84253695e-04  4.84324499e-04  6.74e-15 2.93e-11  1.88e-12     2s
#   15   4.84256943e-04  4.84257016e-04  2.60e-15 3.98e-19  1.88e-15     2s
#
# Barrier solved model in 15 iterations and 1.61 seconds (0.93 work units)
# Optimal objective 4.84256943e-04
#
# Optimal objective value: 0.0004842569431114576
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2756 rows, 158289 columns and 627558 nonzeros
# Model fingerprint: 0xdad4a4b4
# Coefficient statistics:
#   Matrix range     [8e-01, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.35s
# Presolved: 2756 rows, 158289 columns, 627558 nonzeros
# Ordering time: 0.17s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 3.673e+05
#  Factor NZ  : 1.356e+06 (roughly 80 MB of memory)
#  Factor Ops : 9.391e+08 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.99691706e-03  1.70460492e-03  9.81e+01 8.32e-04  2.11e-02     1s
#    1   1.39269747e-05  1.71152793e+00  5.43e+01 5.61e-02  1.18e-02     1s
#    2   3.51035422e-03  3.59050134e+00  3.98e+01 2.35e-02  8.88e-03     1s
#    3   6.71136448e-04  3.37751031e+00  2.49e+00 2.70e-03  6.33e-04     1s
#    4   5.29735062e-04  2.13248604e+00  1.11e+00 1.16e-03  2.94e-04     1s
#    5   2.96573250e-04  1.63467383e+00  2.28e-01 5.89e-04  8.71e-05     1s
#    6   2.17931118e-04  1.00179963e+00  2.11e-02 2.53e-04  2.82e-05     1s
#    7   2.08867594e-04  6.89567615e-02  1.08e-04 1.11e-05  1.73e-06     1s
#    8   2.16555724e-04  6.21183108e-03  6.84e-05 9.36e-07  1.51e-07     1s
#    9   2.92710191e-04  3.32051200e-03  3.16e-05 4.36e-07  7.63e-08     1s
#   10   3.28283857e-04  2.43255007e-03  2.52e-05 3.59e-07  5.30e-08     1s
#   11   3.98133725e-04  1.58200988e-03  1.29e-05 9.59e-08  2.98e-08     1s
#   12   4.25915781e-04  1.30697398e-03  8.43e-06 6.70e-08  2.21e-08     1s
#   13   4.48858724e-04  7.95178199e-04  4.53e-06 3.74e-08  8.69e-09     1s
#   14   4.62445493e-04  5.84421482e-04  2.75e-06 3.88e-09  3.06e-09     2s
#   15   4.73242520e-04  5.02432547e-04  1.47e-06 2.46e-10  7.29e-10     2s
#   16   4.82600660e-04  4.88227757e-04  3.73e-07 0.00e+00  1.40e-10     2s
#   17   4.81937994e-04  4.85153543e-04  8.32e-08 0.00e+00  8.00e-11     2s
#   18   4.83427566e-04  4.85039484e-04  4.18e-08 0.00e+00  4.01e-11     2s
#   19   4.84873345e-04  4.84893037e-04  1.22e-11 1.08e-19  4.90e-13     2s
#   20   4.84873584e-04  4.84873584e-04  4.56e-11 4.86e-17  1.27e-18     2s
#
# Barrier solved model in 20 iterations and 1.94 seconds (1.09 work units)
# Optimal objective 4.84873584e-04
#
# Optimal objective value: 0.00048487358416228894
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2586 rows, 112289 columns and 445269 nonzeros
# Model fingerprint: 0x47ed4cbc
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.22s
# Presolved: 2586 rows, 112289 columns, 445269 nonzeros
# Ordering time: 0.11s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 1.781e+05
#  Factor NZ  : 7.276e+05 (roughly 40 MB of memory)
#  Factor Ops : 4.003e+08 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   9.45359603e-03  1.53966078e-03  1.54e+02 6.28e-04  5.06e-02     1s
#    1   2.51900749e-05  1.21384511e+00  8.45e+01 6.12e-02  2.83e-02     1s
#    2   6.22579431e-03  2.64357615e+00  6.22e+01 2.97e-02  2.13e-02     1s
#    3   5.74652812e-04  3.21322291e+00  3.99e+00 6.51e-03  1.54e-03     1s
#    4   4.71864885e-04  2.07162616e+00  1.32e+00 2.77e-03  5.57e-04     1s
#    5   3.50830268e-04  1.48107283e+00  5.49e-01 1.67e-03  2.61e-04     1s
#    6   2.50513054e-04  1.14904988e+00  1.09e-01 1.14e-03  9.65e-05     1s
#    7   2.14840511e-04  4.28417040e-01  6.11e-16 2.67e-04  2.32e-05     1s
#    8   2.19788886e-04  2.41026679e-02  4.16e-16 1.47e-05  1.29e-06     1s
#    9   2.66175314e-04  7.47079246e-03  3.47e-16 3.73e-06  3.88e-07     1s
#   10   3.01173795e-04  3.84214229e-03  3.89e-16 1.63e-06  1.90e-07     1s
#   11   4.04293513e-04  2.31995936e-03  4.16e-16 7.64e-07  1.03e-07     1s
#   12   4.42978679e-04  1.45709661e-03  3.33e-16 3.79e-07  5.43e-08     1s
#   13   4.90702925e-04  7.02656816e-04  3.75e-16 6.86e-08  1.13e-08     1s
#   14   5.04755014e-04  5.39763703e-04  7.36e-16 1.59e-09  1.84e-09     1s
#   15   5.23134473e-04  5.26219757e-04  6.38e-16 0.00e+00  1.62e-10     1s
#   16   5.23999468e-04  5.24618559e-04  1.43e-15 0.00e+00  3.24e-11     1s
#   17   5.24593235e-04  5.24594677e-04  9.23e-16 1.13e-17  7.55e-14     1s
#
# Barrier solved model in 17 iterations and 1.26 seconds (0.69 work units)
# Optimal objective 5.24593235e-04
#
# Optimal objective value: 0.0005245932350252491
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2289 rows, 78218 columns and 310065 nonzeros
# Model fingerprint: 0xdc514810
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.13s
# Presolved: 2289 rows, 78218 columns, 310065 nonzeros
# Ordering time: 0.03s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 1.338e+05
#  Factor NZ  : 4.152e+05 (roughly 27 MB of memory)
#  Factor Ops : 1.401e+08 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7.86378103e-03  1.41707640e-03  2.68e+02 2.64e-03  8.25e-02     0s
#    1   2.28359577e-05  7.08646929e-01  1.85e+02 5.28e-02  5.80e-02     0s
#    2   3.94105601e-04  1.34505836e+00  4.42e+01 1.94e-02  1.47e-02     0s
#    3   1.08569998e-04  1.25771759e+00  4.79e+00 2.16e-03  1.73e-03     1s
#    4   8.64051822e-05  8.00118170e-01  1.09e+00 9.74e-04  4.65e-04     1s
#    5   6.95027407e-05  5.48081417e-01  2.53e-01 6.16e-04  1.56e-04     1s
#    6   7.67775661e-05  3.92111005e-01  1.46e-04 3.95e-04  5.56e-05     1s
#    7   8.43261520e-05  1.79565011e-02  3.89e-16 1.73e-05  2.53e-06     1s
#    8   2.40559812e-04  1.01076181e-02  5.69e-16 7.70e-06  1.40e-06     1s
#    9   3.28141732e-04  3.87956466e-03  3.61e-16 2.40e-06  5.02e-07     1s
#   10   4.06453628e-04  1.99798349e-03  3.47e-16 8.45e-07  2.24e-07     1s
#   11   4.75668872e-04  9.68119940e-04  3.33e-16 2.03e-07  6.91e-08     1s
#   12   5.18059314e-04  6.00854677e-04  9.85e-16 2.36e-09  1.15e-08     1s
#   13   5.35954263e-04  5.56643202e-04  1.30e-15 0.00e+00  2.86e-09     1s
#   14   5.46091165e-04  5.50201311e-04  7.47e-15 8.67e-19  5.69e-10     1s
#   15   5.48927540e-04  5.49372975e-04  6.48e-15 7.50e-17  6.16e-11     1s
#   16   5.49279679e-04  5.49280125e-04  3.34e-15 6.51e-19  6.17e-14     1s
#
# Barrier solved model in 16 iterations and 0.80 seconds (0.46 work units)
# Optimal objective 5.49279679e-04
#
# Optimal objective value: 0.0005492796785775043
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2337 rows, 77150 columns and 305866 nonzeros
# Model fingerprint: 0x2566101e
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.17s
# Presolved: 2337 rows, 77150 columns, 305866 nonzeros
# Ordering time: 0.09s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 1.297e+05
#  Factor NZ  : 5.085e+05 (roughly 26 MB of memory)
#  Factor Ops : 2.066e+08 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.18944977e-02  1.75990767e-03  1.88e+02 1.05e-03  6.48e-02     1s
#    1   4.03931882e-05  1.37402012e+00  1.14e+02 5.49e-02  4.01e-02     1s
#    2   4.45429049e-03  2.56454785e+00  5.35e+01 2.72e-02  1.93e-02     1s
#    3   5.30471150e-04  2.71656178e+00  4.68e+00 3.98e-03  1.87e-03     1s
#    4   3.12925831e-04  1.63929537e+00  1.51e+00 1.86e-03  6.64e-04     1s
#    5   2.51961597e-04  1.26267144e+00  8.06e-01 1.28e-03  3.76e-04     1s
#    6   1.89035555e-04  1.01003253e+00  1.57e-01 8.44e-04  1.29e-04     1s
#    7   1.75081941e-04  6.59510419e-01  3.36e-02 4.09e-04  5.92e-05     1s
#    8   1.71471001e-04  1.43122227e-01  3.89e-04 7.45e-05  1.11e-05     1s
#    9   1.83275478e-04  1.00920632e-02  1.46e-04 4.99e-06  7.71e-07     1s
#   10   2.64165141e-04  4.48489835e-03  5.56e-05 2.04e-06  3.28e-07     1s
#   11   3.54355474e-04  2.55350417e-03  3.14e-05 1.13e-06  1.70e-07     1s
#   12   4.49869694e-04  1.48662781e-03  1.98e-05 4.28e-07  7.97e-08     1s
#   13   4.95494238e-04  6.49215553e-04  1.09e-05 7.15e-09  1.16e-08     1s
#   14   5.34223609e-04  5.63204300e-04  2.84e-06 9.02e-10  2.18e-09     1s
#   15   5.40076308e-04  5.45870673e-04  9.85e-07 1.14e-11  4.36e-10     1s
#   16   5.42776410e-04  5.44202209e-04  3.27e-07 0.00e+00  1.07e-10     1s
#   17   5.43998685e-04  5.44004947e-04  3.76e-15 0.00e+00  4.70e-13     1s
#
# Barrier solved model in 17 iterations and 0.87 seconds (0.48 work units)
# Optimal objective 5.43998685e-04
#
# Optimal objective value: 0.000543998685098093
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2586 rows, 121561 columns and 482121 nonzeros
# Model fingerprint: 0x6a70d737
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.29s
# Presolved: 2586 rows, 121561 columns, 482121 nonzeros
# Ordering time: 0.10s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 2.166e+05
#  Factor NZ  : 8.475e+05 (roughly 45 MB of memory)
#  Factor Ops : 4.664e+08 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   8.43778873e-03  1.56644916e-03  1.35e+02 8.41e-04  4.40e-02     1s
#    1   2.75431724e-05  1.38562953e+00  7.87e+01 5.63e-02  2.61e-02     1s
#    2   4.81332761e-03  2.97062285e+00  4.57e+01 1.92e-02  1.56e-02     1s
#    3   7.70337258e-04  3.20332862e+00  3.73e+00 2.33e-03  1.39e-03     1s
#    4   5.56077658e-04  1.98041202e+00  1.27e+00 1.06e-03  5.06e-04     1s
#    5   3.64611104e-04  1.58712866e+00  4.22e-01 8.43e-04  2.07e-04     1s
#    6   2.52265909e-04  1.08541251e+00  1.02e-01 3.35e-04  7.46e-05     1s
#    7   2.00018266e-04  5.22952810e-01  6.52e-16 1.22e-04  2.26e-05     1s
#    8   2.03473887e-04  8.36905652e-03  5.55e-16 1.90e-06  3.53e-07     1s
#    9   2.98275384e-04  4.18027668e-03  5.00e-16 7.81e-07  1.67e-07     1s
#   10   3.68697849e-04  2.83206893e-03  2.78e-16 4.81e-07  1.06e-07     1s
#   11   4.28948286e-04  2.03791661e-03  3.05e-16 3.47e-07  6.94e-08     1s
#   12   4.45351006e-04  1.72425767e-03  7.22e-16 3.07e-07  5.51e-08     1s
#   13   4.79659260e-04  7.26851269e-04  1.63e-14 3.56e-08  1.06e-08     1s
#   14   4.96457593e-04  5.67317381e-04  1.03e-14 8.09e-09  3.04e-09     1s
#   15   5.03169778e-04  5.05383862e-04  2.51e-14 2.20e-11  9.44e-11     1s
#   16   5.03479893e-04  5.03482315e-04  1.94e-13 4.49e-15  1.03e-13     1s
#
# Barrier solved model in 16 iterations and 1.40 seconds (0.78 work units)
# Optimal objective 5.03479893e-04
#
# Optimal objective value: 0.0005034798926229164
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2667 rows, 134525 columns and 533592 nonzeros
# Model fingerprint: 0x0c4585f7
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.28s
# Presolved: 2667 rows, 134525 columns, 533592 nonzeros
# Ordering time: 0.12s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 2.258e+05
#  Factor NZ  : 8.520e+05 (roughly 50 MB of memory)
#  Factor Ops : 4.856e+08 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.33107088e-02  1.56886245e-03  2.57e+02 9.26e-04  7.51e-02     1s
#    1   4.61210841e-05  1.35385657e+00  1.63e+02 6.16e-02  4.86e-02     1s
#    2   8.00725901e-03  2.79457352e+00  8.88e+01 3.69e-02  2.72e-02     1s
#    3   4.88712385e-04  3.72542022e+00  8.29e+00 1.38e-02  2.76e-03     1s
#    4   3.29724260e-04  2.60589517e+00  2.68e+00 5.45e-03  9.50e-04     1s
#    5   2.50312221e-04  2.06315146e+00  1.00e+00 3.62e-03  4.00e-04     1s
#    6   1.81092130e-04  1.65395418e+00  3.87e-01 2.50e-03  1.88e-04     1s
#    7   1.39971898e-04  1.33814229e+00  7.49e-02 1.68e-03  7.76e-05     1s
#    8   1.27621139e-04  4.87064512e-01  2.12e-04 4.77e-04  2.09e-05     1s
#    9   1.33630088e-04  1.05209967e-02  4.66e-15 9.60e-06  4.43e-07     1s
#   10   1.73919368e-04  6.27191505e-03  2.97e-15 5.41e-06  2.60e-07     1s
#   11   2.23074341e-04  3.69196704e-03  2.72e-15 2.98e-06  1.47e-07     1s
#   12   2.45560661e-04  2.50761463e-03  3.08e-15 1.82e-06  9.57e-08     1s
#   13   3.66672277e-04  1.98498413e-03  7.91e-16 1.28e-06  6.84e-08     1s
#   14   4.04533143e-04  1.32303785e-03  1.44e-15 6.56e-07  3.86e-08     1s
#   15   4.46133405e-04  6.75218426e-04  9.51e-15 1.11e-07  9.51e-09     1s
#   16   4.55880216e-04  4.91175943e-04  1.46e-15 1.01e-08  1.45e-09     1s
#   17   4.64728158e-04  4.67312646e-04  1.17e-14 1.50e-10  1.05e-10     1s
#   18   4.65321320e-04  4.65350810e-04  2.90e-13 6.25e-13  1.19e-12     1s
#   19   4.65325505e-04  4.65325534e-04  5.30e-13 2.17e-19  1.19e-15     2s
#
# Barrier solved model in 19 iterations and 1.51 seconds (0.90 work units)
# Optimal objective 4.65325505e-04
#
# Optimal objective value: 0.0004653255048543522
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 1654 rows, 7846 columns and 29432 nonzeros
# Model fingerprint: 0xfe91f44c
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 12 rows and 0 columns
# Presolve time: 0.03s
# Presolved: 1642 rows, 7846 columns, 29420 nonzeros
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 3.589e+04
#  Factor NZ  : 6.416e+04 (roughly 2 MB of memory)
#  Factor Ops : 9.793e+06 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.28463955e-02  1.29372043e-03  1.82e+02 2.11e-03  4.06e-01     0s
#    1   1.97349528e-04  2.91400605e+00  1.27e+02 7.99e-03  2.72e-01     0s
#    2   6.86049238e-05  2.79541033e+00  1.40e+01 0.00e+00  3.41e-02     0s
#    3   1.00293613e-05  1.48553821e+00  1.94e+00 0.00e+00  6.45e-03     0s
#    4   4.58282179e-06  6.39617520e-01  3.46e-01 0.00e+00  1.77e-03     0s
#    5   2.87904611e-06  7.47501416e-02  1.11e-15 0.00e+00  1.47e-04     0s
#    6   4.72833803e-06  1.62674575e-02  5.55e-16 0.00e+00  3.20e-05     0s
#    7   4.60293535e-05  1.26342947e-02  3.33e-16 0.00e+00  2.48e-05     0s
#    8   1.25744782e-04  6.76867783e-03  4.44e-16 0.00e+00  1.31e-05     0s
#    9   3.01932534e-04  4.35329684e-03  3.33e-16 0.00e+00  7.97e-06     0s
#   10   4.48064050e-04  1.82405814e-03  4.44e-16 0.00e+00  2.71e-06     0s
#   11   4.87854733e-04  1.24237607e-03  4.44e-16 0.00e+00  1.48e-06     0s
#   12   4.83436648e-04  1.15903666e-03  4.44e-16 0.00e+00  1.33e-06     0s
#   13   5.16220241e-04  7.67117836e-04  2.11e-15 0.00e+00  4.94e-07     0s
#   14   5.35517468e-04  5.66158106e-04  7.11e-15 0.00e+00  6.03e-08     0s
#   15   5.39839051e-04  5.40632910e-04  2.44e-14 0.00e+00  1.56e-09     0s
#   16   5.39931443e-04  5.39932237e-04  2.19e-14 2.17e-19  1.56e-12     0s
#
# Barrier solved model in 16 iterations and 0.14 seconds (0.04 work units)
# Optimal objective 5.39931443e-04
#
# Optimal objective value: 0.0005399314434829403
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2469 rows, 83666 columns and 331628 nonzeros
# Model fingerprint: 0x76860510
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.16s
# Presolved: 2469 rows, 83666 columns, 331628 nonzeros
# Ordering time: 0.06s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 8.269e+04
#  Factor NZ  : 2.728e+05 (roughly 17 MB of memory)
#  Factor Ops : 8.850e+07 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.23248823e-02  1.95188519e-03  1.14e+02 1.08e-03  6.51e-02     0s
#    1   7.58222801e-05  1.33813004e+00  6.88e+01 5.43e-02  4.01e-02     0s
#    2   7.41114559e-03  2.56205830e+00  2.90e+01 2.23e-02  1.74e-02     0s
#    3   7.72003583e-04  2.65517817e+00  3.01e+00 4.17e-03  1.94e-03     0s
#    4   3.67581045e-04  1.74853909e+00  8.10e-01 1.55e-03  5.79e-04     0s
#    5   2.62225569e-04  1.38121274e+00  2.50e-01 9.80e-04  2.22e-04     0s
#    6   2.01748383e-04  9.37510911e-01  8.57e-02 4.61e-04  9.40e-05     0s
#    7   1.54711655e-04  4.20368161e-01  1.07e-02 1.17e-04  2.66e-05     0s
#    8   1.51333793e-04  2.66213482e-02  1.67e-16 3.04e-06  1.48e-06     0s
#    9   2.06098475e-04  1.26670048e-02  1.53e-16 1.28e-06  6.95e-07     1s
#   10   2.80554362e-04  7.20536514e-03  9.71e-17 6.83e-07  3.86e-07     1s
#   11   3.38604074e-04  4.64971835e-03  1.04e-16 4.89e-07  2.40e-07     1s
#   12   4.04631287e-04  2.19848565e-03  1.25e-16 1.49e-07  9.99e-08     1s
#   13   4.41900788e-04  1.22869613e-03  1.25e-16 5.45e-08  4.38e-08     1s
#   14   4.78427497e-04  7.57814814e-04  1.67e-16 1.14e-08  1.55e-08     1s
#   15   4.99539394e-04  6.24127239e-04  1.53e-16 4.81e-09  6.92e-09     1s
#   16   5.04723880e-04  5.18527251e-04  1.11e-16 0.00e+00  7.63e-10     1s
#   17   5.13017624e-04  5.13632042e-04  2.42e-15 0.00e+00  3.39e-11     1s
#   18   5.13071074e-04  5.13071691e-04  1.34e-15 7.70e-17  3.40e-14     1s
#
# Barrier solved model in 18 iterations and 0.60 seconds (0.39 work units)
# Optimal objective 5.13071074e-04
#
# Optimal objective value: 0.0005130710744766029
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2315 rows, 74402 columns and 295071 nonzeros
# Model fingerprint: 0x7da609e6
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.14s
# Presolved: 2315 rows, 74402 columns, 295071 nonzeros
# Ordering time: 0.02s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 6.862e+04
#  Factor NZ  : 2.411e+05 (roughly 14 MB of memory)
#  Factor Ops : 7.237e+07 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.53506293e-02  1.70938839e-03  1.48e+02 1.96e-03  8.72e-02     0s
#    1   6.88439994e-05  8.81057155e-01  9.95e+01 5.42e-02  5.98e-02     0s
#    2   1.90881327e-03  1.64161278e+00  3.07e+01 2.25e-02  1.96e-02     0s
#    3   3.17633077e-04  1.65563957e+00  2.37e+00 2.69e-03  1.71e-03     0s
#    4   2.25989558e-04  9.71137838e-01  4.13e-01 7.53e-04  3.84e-04     0s
#    5   1.62125092e-04  7.35268602e-01  1.05e-01 4.82e-04  1.57e-04     0s
#    6   1.34857439e-04  2.60997641e-01  7.98e-03 1.03e-04  3.76e-05     0s
#    7   1.42988577e-04  2.16153129e-02  2.22e-16 6.88e-06  2.92e-06     0s
#    8   1.89271353e-04  9.51608538e-03  1.39e-16 2.74e-06  1.27e-06     0s
#    9   2.59346017e-04  4.62390167e-03  1.67e-16 1.20e-06  5.92e-07     0s
#   10   3.52446316e-04  2.70615645e-03  1.39e-16 6.05e-07  3.19e-07     0s
#   11   3.78003363e-04  1.46306732e-03  8.33e-17 2.65e-07  1.47e-07     0s
#   12   4.11032090e-04  5.30283778e-04  1.67e-16 1.18e-08  1.61e-08     0s
#   13   4.33055784e-04  4.61159349e-04  3.05e-16 5.51e-10  3.77e-09     0s
#   14   4.40111431e-04  4.46165227e-04  9.58e-16 0.00e+00  8.11e-10     0s
#   15   4.43884362e-04  4.44234040e-04  4.22e-14 3.32e-19  4.68e-11     0s
#   16   4.43949289e-04  4.43949827e-04  4.12e-14 3.25e-19  7.21e-14     0s
#
# Barrier solved model in 16 iterations and 0.49 seconds (0.31 work units)
# Optimal objective 4.43949289e-04
#
# Optimal objective value: 0.00044394928856264824
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2247 rows, 64677 columns and 256630 nonzeros
# Model fingerprint: 0xe4258a23
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.14s
# Presolved: 2247 rows, 64677 columns, 256630 nonzeros
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 8.882e+04
#  Factor NZ  : 1.886e+05 (roughly 10 MB of memory)
#  Factor Ops : 4.961e+07 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.82313127e-03  1.42038087e-03  1.01e+02 2.78e-03  6.90e-02     0s
#    1   2.00146683e-05  3.99828048e-01  6.61e+01 5.15e-02  4.59e-02     0s
#    2   2.69659354e-05  7.37916053e-01  1.04e+01 1.68e-02  7.84e-03     0s
#    3   7.22575028e-06  5.19471895e-01  1.17e+00 3.76e-03  1.03e-03     0s
#    4   4.71577787e-06  3.51659665e-01  2.19e-01 2.20e-03  2.90e-04     0s
#    5   4.23230343e-06  2.14898527e-01  8.07e-03 1.03e-03  8.48e-05     0s
#    6   4.78930980e-06  1.63012867e-02  1.39e-16 5.71e-05  6.04e-06     0s
#    7   9.68194319e-05  1.05543013e-02  9.71e-17 3.46e-05  3.86e-06     0s
#    8   1.68829250e-04  5.16662583e-03  1.60e-16 1.63e-05  1.84e-06     0s
#    9   2.52784135e-04  2.68594872e-03  1.46e-16 6.92e-06  8.92e-07     0s
#   10   3.94065433e-04  1.58518022e-03  1.25e-16 2.96e-06  4.34e-07     0s
#   11   4.28846141e-04  1.17353199e-03  1.04e-16 1.67e-06  2.70e-07     0s
#   12   4.83625547e-04  9.36339212e-04  8.33e-17 1.10e-06  1.64e-07     0s
#   13   5.14441456e-04  5.56362174e-04  3.33e-16 2.51e-08  1.49e-08     0s
#   14   5.22656691e-04  5.24706930e-04  4.30e-16 8.41e-10  7.26e-10     0s
#   15   5.22705156e-04  5.22705250e-04  6.25e-16 3.22e-14  3.32e-14     0s
#
# Barrier solved model in 15 iterations and 0.38 seconds (0.23 work units)
# Optimal objective 5.22705156e-04
#
# Optimal objective value: 0.0005227051563180159
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 1881 rows, 12440 columns and 46808 nonzeros
# Model fingerprint: 0x33c4dd21
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.02s
# Presolved: 1881 rows, 12440 columns, 46808 nonzeros
# Ordering time: 0.01s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 1.588e+04
#  Factor NZ  : 7.852e+04 (roughly 3 MB of memory)
#  Factor Ops : 1.042e+07 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.80037162e-02  3.39487356e-02  2.13e+02 2.15e-03  3.37e-01     0s
#    1   1.93428248e-04  2.99700695e+00  1.55e+02 2.06e-02  2.40e-01     0s
#    2   2.85101332e-04  3.52160571e+00  1.30e+01 6.94e-17  2.41e-02     0s
#    3   5.88450531e-05  1.83522548e+00  2.91e+00 1.39e-17  6.31e-03     0s
#    4   2.12102644e-05  9.73805174e-01  4.81e-01 2.08e-17  1.78e-03     0s
#    5   1.25202588e-05  2.65588828e-01  1.33e-15 1.04e-17  3.33e-04     0s
#    6   1.48642234e-05  2.17211237e-02  1.33e-15 0.00e+00  2.72e-05     0s
#    7   4.74435295e-05  1.43601408e-02  1.11e-15 0.00e+00  1.80e-05     0s
#    8   1.18844029e-04  8.60737013e-03  6.66e-16 0.00e+00  1.07e-05     0s
#    9   2.46177313e-04  4.53008138e-03  8.88e-16 0.00e+00  5.38e-06     0s
#   10   3.06901672e-04  2.37093114e-03  6.66e-16 0.00e+00  2.59e-06     0s
#   11   3.81665996e-04  1.44693850e-03  9.99e-16 0.00e+00  1.34e-06     0s
#   12   4.27193187e-04  1.12937826e-03  5.55e-16 0.00e+00  8.81e-07     0s
#   13   4.59082810e-04  6.86720302e-04  8.88e-16 0.00e+00  2.86e-07     0s
#   14   4.70830891e-04  6.09309231e-04  4.44e-15 0.00e+00  1.74e-07     0s
#   15   4.82333862e-04  4.98767738e-04  8.05e-14 9.79e-22  2.06e-08     0s
#   16   4.85737269e-04  4.89764533e-04  1.40e-13 4.30e-23  5.05e-09     0s
#   17   4.87733254e-04  4.87836030e-04  4.40e-12 3.70e-17  1.29e-10     0s
#   18   4.87741556e-04  4.87741659e-04  3.71e-12 2.25e-19  1.29e-13     0s
#
# Barrier solved model in 18 iterations and 0.14 seconds (0.06 work units)
# Optimal objective 4.87741556e-04
#
# Optimal objective value: 0.0004877415557518048
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 1483 rows, 17501 columns and 69367 nonzeros
# Model fingerprint: 0x1ba23d7d
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.03s
# Presolved: 1483 rows, 17501 columns, 69367 nonzeros
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.054e+04
#  Factor NZ  : 1.807e+04 (roughly 2 MB of memory)
#  Factor Ops : 1.524e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.80255857e-02  1.03169925e-03  3.64e+02 2.47e-03  4.73e-01     0s
#    1   1.92727565e-04  1.26888701e+00  1.97e+02 6.51e-03  2.55e-01     0s
#    2   2.27005495e-05  1.07937699e+00  1.11e+01 3.19e-04  1.64e-02     0s
#    3   7.97662020e-06  5.24342498e-01  1.03e+00 0.00e+00  2.37e-03     0s
#    4   6.28933063e-06  2.40471060e-01  2.21e-01 0.00e+00  7.78e-04     0s
#    5   7.73122667e-06  7.56450362e-02  4.06e-02 0.00e+00  1.88e-04     0s
#    6   6.12395824e-05  1.69449825e-02  2.64e-05 0.00e+00  3.61e-05     0s
#    7   1.55372128e-04  3.26960600e-03  1.94e-16 0.00e+00  6.65e-06     0s
#    8   2.74186646e-04  1.67286907e-03  1.25e-16 0.00e+00  2.99e-06     0s
#    9   3.09250700e-04  1.19380797e-03  1.11e-16 0.00e+00  1.89e-06     0s
#   10   3.43474154e-04  7.76164225e-04  1.11e-16 0.00e+00  9.24e-07     0s
#   11   3.70162395e-04  6.46575692e-04  9.71e-17 0.00e+00  5.90e-07     0s
#   12   3.92104465e-04  5.21159210e-04  1.39e-16 0.00e+00  2.76e-07     0s
#   13   4.03654966e-04  4.43651199e-04  6.11e-16 0.00e+00  8.54e-08     0s
#   14   4.18116203e-04  4.23649165e-04  2.08e-16 0.00e+00  1.18e-08     0s
#   15   4.18788229e-04  4.18791042e-04  2.36e-16 0.00e+00  6.00e-12     0s
#
# Barrier solved model in 15 iterations and 0.09 seconds (0.05 work units)
# Optimal objective 4.18788229e-04
#
# Optimal objective value: 0.00041878822862734423
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 614 rows, 2609 columns and 10084 nonzeros
# Model fingerprint: 0x91fe97ac
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 20 rows and 20 columns
# Presolve time: 0.01s
# Presolved: 594 rows, 2589 columns, 10044 nonzeros
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.483e+03
#  Factor NZ  : 2.283e+03
#  Factor Ops : 6.582e+04 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.68253120e-02  1.54283009e-03  1.01e+02 2.70e-03  7.01e-01     0s
#    1   4.77462180e-05  3.41465524e-01  5.13e+01 4.16e-17  2.93e-01     0s
#    2   8.21814582e-06  2.63192268e-01  5.48e-01 2.78e-16  1.18e-02     0s
#    3   4.89617158e-06  1.15805577e-02  5.55e-17 4.86e-17  4.03e-04     0s
#    4   4.18922268e-05  3.64917750e-03  4.16e-17 1.73e-17  1.25e-04     0s
#    5   2.97417616e-04  2.18265881e-03  4.16e-17 7.81e-18  6.56e-05     0s
#    6   3.80157922e-04  9.47012043e-04  4.16e-17 2.39e-18  1.97e-05     0s
#    7   3.86098336e-04  4.71083128e-04  5.55e-17 3.69e-18  2.96e-06     0s
#    8   3.92349830e-04  3.96586073e-04  5.55e-17 1.65e-19  1.47e-07     0s
#    9   3.92452881e-04  3.92457118e-04  2.50e-16 1.99e-17  1.47e-10     0s
#
# Barrier solved model in 9 iterations and 0.03 seconds (0.01 work units)
# Optimal objective 3.92452881e-04
#
# Optimal objective value: 0.00039245288136764407
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 1401 rows, 15645 columns and 61984 nonzeros
# Model fingerprint: 0x2829e9b9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.03s
# Presolved: 1401 rows, 15645 columns, 61984 nonzeros
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 9.382e+03
#  Factor NZ  : 1.666e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.400e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.79126233e-02  7.36105506e-04  4.60e+02 2.19e-03  6.03e-01     0s
#    1   2.34204263e-04  1.23582483e+00  2.49e+02 6.92e-03  3.20e-01     0s
#    2   6.08976082e-05  1.01740634e+00  1.24e+01 5.55e-17  1.84e-02     0s
#    3   1.15429527e-05  4.37942803e-01  6.62e-01 1.11e-16  1.92e-03     0s
#    4   1.04604943e-05  1.89188433e-01  8.97e-02 5.55e-17  5.88e-04     0s
#    5   1.66341646e-05  4.62675884e-02  1.69e-04 1.94e-16  1.19e-04     0s
#    6   9.03686282e-05  6.72543125e-03  1.35e-07 3.82e-17  1.71e-05     0s
#    7   2.15476482e-04  1.48181115e-03  1.98e-10 6.94e-18  3.26e-06     0s
#    8   3.62899471e-04  9.63875781e-04  3.30e-11 8.46e-18  1.55e-06     0s
#    9   4.08212809e-04  7.46585443e-04  1.90e-11 6.83e-18  8.71e-07     0s
#   10   4.38226774e-04  6.11177157e-04  1.02e-11 1.46e-17  4.45e-07     0s
#   11   4.58808593e-04  5.12453533e-04  3.58e-12 2.17e-19  1.38e-07     0s
#   12   4.59078661e-04  4.65848941e-04  6.11e-16 4.81e-19  1.74e-08     0s
#   13   4.63323835e-04  4.63413121e-04  1.30e-15 6.25e-17  2.30e-10     0s
#   14   4.63330375e-04  4.63330384e-04  1.33e-15 4.34e-19  2.38e-14     0s
#
# Barrier solved model in 14 iterations and 0.09 seconds (0.05 work units)
# Optimal objective 4.63330375e-04
#
# Optimal objective value: 0.00046333037512821183
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2020 rows, 23075 columns and 91361 nonzeros
# Model fingerprint: 0x5211c979
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.04s
# Presolved: 2020 rows, 23075 columns, 91361 nonzeros
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.117e+04
#  Factor NZ  : 2.060e+04 (roughly 1 MB of memory)
#  Factor Ops : 2.061e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.80160548e-02  1.48296692e-03  3.96e+02 1.95e-03  4.66e-01     0s
#    1   1.80945451e-04  1.01800305e+00  2.16e+02 1.10e-02  2.51e-01     0s
#    2   3.11668248e-05  9.73809519e-01  8.55e+00 5.11e-04  1.23e-02     0s
#    3   1.00060727e-05  4.44752923e-01  5.78e-01 2.05e-05  1.71e-03     0s
#    4   8.56339536e-06  1.09629753e-01  5.03e-02 0.00e+00  3.18e-04     0s
#    5   2.61757182e-05  2.76962135e-02  1.86e-05 0.00e+00  6.93e-05     0s
#    6   1.09945299e-04  6.49800537e-03  1.39e-16 0.00e+00  1.60e-05     0s
#    7   2.05331596e-04  3.23003615e-03  1.53e-16 0.00e+00  7.57e-06     0s
#    8   3.08500109e-04  1.68300136e-03  1.11e-16 0.00e+00  3.44e-06     0s
#    9   3.81641625e-04  1.08986557e-03  1.39e-16 0.00e+00  1.77e-06     0s
#   10   4.05428908e-04  8.83270936e-04  9.71e-17 0.00e+00  1.20e-06     0s
#   11   4.21729629e-04  6.68103689e-04  9.71e-17 0.00e+00  6.17e-07     0s
#   12   4.45271457e-04  5.06526546e-04  1.80e-16 0.00e+00  1.53e-07     0s
#   13   4.46882060e-04  4.51161201e-04  1.96e-14 0.00e+00  1.07e-08     0s
#   14   4.47497703e-04  4.47525881e-04  3.27e-14 1.17e-17  7.05e-11     0s
#   15   4.47498449e-04  4.47498449e-04  1.08e-11 5.75e-18  1.91e-16     0s
#
# Barrier solved model in 15 iterations and 0.10 seconds (0.06 work units)
# Optimal objective 4.47498449e-04
#
# Optimal objective value: 0.0004474984492304189
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 901 rows, 2519 columns and 9410 nonzeros
# Model fingerprint: 0x772416be
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 901 rows, 2519 columns, 9410 nonzeros
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.802e+03
#  Factor NZ  : 9.211e+03
#  Factor Ops : 4.921e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.90614863e-02  1.02840424e-03  6.30e+01 1.58e-03  3.66e-01     0s
#    1   1.10245834e-04  9.44678959e-01  3.36e+01 1.26e-02  1.81e-01     0s
#    2   3.91572735e-05  9.55741095e-01  1.52e+00 1.80e-04  1.72e-02     0s
#    3   1.74363119e-05  3.13078485e-01  4.25e-01 7.03e-06  4.67e-03     0s
#    4   8.38848676e-06  4.97451663e-02  2.22e-16 0.00e+00  5.03e-04     0s
#    5   1.35338415e-05  7.13084895e-03  2.22e-16 0.00e+00  7.20e-05     0s
#    6   1.75487284e-04  4.30257631e-03  2.22e-16 0.00e+00  4.17e-05     0s
#    7   2.93433331e-04  1.86824802e-03  2.22e-16 0.00e+00  1.59e-05     0s
#    8   3.71966276e-04  9.35801329e-04  2.22e-16 0.00e+00  5.70e-06     0s
#    9   4.14109156e-04  6.79368925e-04  2.22e-16 0.00e+00  2.68e-06     0s
#   10   4.64775506e-04  6.01806162e-04  5.00e-16 0.00e+00  1.39e-06     0s
#   11   4.87430295e-04  5.69084490e-04  1.22e-15 0.00e+00  8.26e-07     0s
#   12   4.99131802e-04  5.20451702e-04  3.44e-15 0.00e+00  2.16e-07     0s
#   13   5.01215541e-04  5.02925171e-04  2.50e-14 0.00e+00  1.73e-08     0s
#   14   5.02051737e-04  5.02056239e-04  2.48e-13 2.44e-18  4.55e-11     0s
#
# Barrier solved model in 14 iterations and 0.04 seconds (0.01 work units)
# Optimal objective 5.02051737e-04
#
# Optimal objective value: 0.0005020517365156156
