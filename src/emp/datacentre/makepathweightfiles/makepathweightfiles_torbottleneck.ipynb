# %% [markdown]
# solve
# inspired by https://github.com/AnnZhouCcc/topobench/blob/master/lpmaker/graphs/Graph.java#L1382

# %%
# set parameters
graphname = "dring"
numsw = 80
numport = 64
numserver = 2988
numfaillink = 0
numlink = 2132
fseed = 0
homedir = "/u/az6922"

method = 2
crossover = 0
factor = 64


clist = [64,48,32,16,4]
s=4
multlist = [[0,72,100],[0,96,100],[1,44,100],[2,88,100],[11,50,100]]
tseedlist = range(5)


for ic,c in enumerate(clist):
    mult = multlist[ic][0]
    numerator = multlist[ic][1]
    denominator = multlist[ic][2]
    multstr = f"{mult}_{numerator}_{denominator}"
    for tseed in tseedlist:
        trafficname = f"c2s_{c}_{s}_{tseed}_{multstr}"
        flowfile = f"{homedir}/DRing/src/emp/datacentre/flowfiles/c2s_{c}_{s}_{multstr}_{tseed}"

        routingdict = dict()
        with open(f"{homedir}/DRing/src/emp/datacentre/experiments/torbottleneck/whatrouting.txt",'r') as f:
            lines = f.readlines()
            for line in lines:
                tokens = line.split(',')
                if tokens[0]==flowfile:
                    routingdict[tokens[1]] = float(tokens[2])
        if max(routingdict.values()) == routingdict["ecmp"]:
            routingname = "ecmp"
        elif max(routingdict.values()) == routingdict["su2"]:
            routingname = "su2"
        elif max(routingdict.values()) == routingdict["su3"]:
            routingname = "su3"

        if graphname=="dring" or graphname=="rrg":
            netpathfile = f"{homedir}/DRing/src/emp/datacentre/netpathfiles/netpath_{routingname}_{graphname}.txt"
        else:
            print("ERROR: leafspine does not need to compute path weight")

        if graphname=="dring":
            graphfile = f"{homedir}/DRing/src/emp/datacentre/graphfiles/ring_supergraph/double_ring/instance1_{numsw}_{numport}.edgelist"
        elif graphname=="rrg":
            graphfile = f"{homedir}/DRing/src/emp/datacentre/graphfiles/ring_supergraph/rrg/instance1_{numsw}_{numport}.edgelist"
        else:
            print("ERROR: leafspine does not need to compute path weight")

        linkfailurefile = f"{homedir}/DRing/src/emp/datacentre/linkfailurefiles/{graphname}_{numlink}_{numfaillink}_{fseed}"

        serverfile = f"{homedir}/DRing/src/emp/datacentre/serverfiles/{graphname}_{numserver}_{numsw}_{numport}"

        tag = f"{graphname}_{numfaillink}_{fseed}_{routingname}_{trafficname}_{method}_{crossover}_{factor}"
        varfile = f"{homedir}/DRing/src/emp/datacentre/qvarfiles/var_{tag}"
        qvarfile = f"{homedir}/DRing/src/emp/datacentre/qvarfiles/qvar_{tag}"
        modelfile = f"{homedir}/DRing/src/emp/datacentre/makepathweightfiles/model.lp"


        # read netpathfile
        netpath = list()
        for i in range(numsw):
            netpath.append(list())
            for j in range(numsw):
                netpath[i].append(list())
        with open(netpathfile,'r') as f:
            lines = f.readlines()
            # produce
            fromsw = 0
            tosw = 0
            for line in lines:
                if "->" not in line:
                    tokens = line.split()
                    fromsw = int(tokens[0])
                    tosw = int(tokens[1])
                else:
                    path = [fromsw]
                    tokens = line.split()
                    for token in tokens:
                        hops = token.split("->")
                        path.append(int(hops[1]))
                    netpath[fromsw][tosw].append(path)

            # check
            for line in lines:
                if "->" not in line:
                    tokens = line.split()
                    fromsw = int(tokens[0])
                    tosw = int(tokens[1])
                    numpaths = int(tokens[2])
                    if len(netpath[fromsw][tosw])!=numpaths:
                        print(f"ERROR: netpath is wrong, fromsw={fromsw}, tosw={tosw}, numpaths from file={numpaths}, numpaths from array={len(netpath[fromsw][tosw])}")

        # read graphfile
        link = list()
        for i in range(numsw):
            link.append(list())
            for j in range(numsw):
                link[i].append(0)
        with open(graphfile,'r') as f:
            lines = f.readlines()
            for line in lines:
                tokens = line.split("->")
                fromsw = int(tokens[0])
                tosw = int(tokens[1])
                link[fromsw][tosw] = 1
                link[tosw][fromsw] = 1

        # read linkfailurefile (if needed)
        if numfaillink > 0:
            with open(linkfailurefile,'r') as f:
                lines = f.readlines()
                for line in lines:
                    tokens = line.split()
                    fromsw = int(tokens[0])
                    tosw = int(tokens[1])
                    if link[fromsw][tosw] != 1:
                        print(f"ERROR: should have a link from {fromsw} to {tosw} but not")
                    else:
                        link[fromsw][tosw] /= 2

        # read serverfile
        serverdict = dict()
        with open(serverfile,'r') as f:
            lines = f.readlines()
            for line in lines:
                tokens = line.split(',')
                serverdict[int(tokens[0])] = int(tokens[1])

        # read flowfile
        traffic = list()
        for i in range(numsw):
            traffic.append(list())
            for j in range(numsw):
                traffic[i].append(0)
        with open(flowfile,'r') as f:
            lines = f.readlines()
            for line in lines:
                tokens = line.split(",")
                fromsvr = int(tokens[0])
                tosvr = int(tokens[1])
                if fromsvr>=numserver or tosvr>=numserver: continue
                fromsw = serverdict[fromsvr]
                tosw = serverdict[tosvr]
                if fromsw == tosw: continue
                flowbytes = int(tokens[2])
                traffic[fromsw][tosw] += flowbytes


        # precompute
        flowsvialink = list()
        for i in range(numsw):
            flowsvialink.append(list())
            for j in range(numsw):
                flowsvialink[i].append(list())
        for fromsw in range(numsw):
            for tosw in range(numsw):
                if traffic[fromsw][tosw] > 0:
                    for pid,path in enumerate(netpath[fromsw][tosw]):
                        fidpidstr = f"{fromsw},{tosw},{pid}"
                        prevhop = fromsw
                        for hop in path[1:]:
                            flowsvialink[prevhop][hop].append(fidpidstr)
                            prevhop = hop

        for fromsw in range(numsw):
            for tosw in range(numsw):
                traffic[fromsw][tosw] /= 100000


        import gurobipy as gp
        from gurobipy import GRB

        # Create a new model
        model = gp.Model("mcf")

        # Add variables
        maxpid = 0
        for fromsw in range(numsw):
            for tosw in range(numsw):
                maxpid = max(maxpid,len(netpath[fromsw][tosw]))
        vararr = list()
        for fromsw in range(numsw):
            vararr.append(list())
            for tosw in range(numsw):
                vararr[fromsw].append(list())
                for pid in range(maxpid):
                    vararr[fromsw][tosw].append(None)
        for fromsw in range(numsw):
            for tosw in range(numsw):
                if traffic[fromsw][tosw] > 0:
                    for pid in range(len(netpath[fromsw][tosw])):
                        var = model.addVar(name=f"{fromsw}_{tosw}_{pid}")
                        vararr[fromsw][tosw][pid] = var
        k = model.addVar(name="k")

        # Set objective function
        model.setObjective(k, GRB.MAXIMIZE)

        # Add constraints
        # Constraint 0: for each fid: sum(pid) >= k * traffic[fid.from][fid.to]
        for fromsw in range(numsw):
            for tosw in range(numsw):
                if traffic[fromsw][tosw] > 0:
                    varlist = list()
                    for pid in range(len(netpath[fromsw][tosw])):
                        varlist.append(vararr[fromsw][tosw][pid])
                    model.addConstr(sum(varlist)>=k*traffic[fromsw][tosw],f"c0_{fromsw}_{tosw}")

        # Constraint 1: for each link: sum(fid_pid) <= link[link.from][link.to]
        for linkfrom in range(numsw):
            for linkto in range(numsw):
                flowstrlist = flowsvialink[linkfrom][linkto]
                if len(flowstrlist) > 0:
                    varlist = list()
                    for flowstr in flowstrlist:
                        tokens = flowstr.split(',')
                        flowfrom = int(tokens[0])
                        flowto = int(tokens[1])
                        pid = int(tokens[2])
                        varlist.append(vararr[flowfrom][flowto][pid])
                    model.addConstr(sum(varlist)<=link[linkfrom][linkto],f"c1_{linkfrom}_{linkto}")

        # Optimize model
        model.setParam('Method',method)
        model.setParam('Crossover',crossover)
        model.optimize()
        # model.write(modelfile)

        # Print results
        if model.status == GRB.OPTIMAL:
            print(f"Optimal objective value: {model.objVal}")
            with open(varfile,'w') as f:
                f.write(f"{k.varName},{k.x}\n")
                for fromsw in range(numsw):
                    for tosw in range(numsw):
                        if traffic[fromsw][tosw] > 0:
                            for pid in range(len(netpath[fromsw][tosw])):
                                var = vararr[fromsw][tosw][pid]
                                f.write(f"{var.varName},{var.x}\n")
        else:
            print("No optimal solution found")


        import random
        random.seed(0)

        def quantize_to_multiple_of_1_64(x,factor):
            return round(x * factor) / factor

        def quantize_and_adjust_with_indices(indexed_values,factor,isprint=False):
            if isprint: print(indexed_values)
            # Quantize each value
            quantized_values = [(i, quantize_to_multiple_of_1_64(v,factor)) for i, v in indexed_values]
            if isprint: print(quantized_values)
            
            # Calculate the current sum
            current_sum = sum(v for _, v in quantized_values)
            
            # Calculate the difference between the sum and 1
            difference = current_sum - 1
            if isprint: print(f"currsum={current_sum}, difference={difference}")

            random_values = [(v, random.random()) for v in quantized_values]
            if isprint: print(random_values)
            
            if difference != 0:
                if difference > 0:
                    # Sort indices by quantized values to adjust the largest values first
                    sorted_random = sorted(random_values, key=lambda x: (x[0][1],x[1]), reverse=True)
                    # sorted_quantized = sorted(quantized_values, key=lambda x: x[1], reverse=True)
                    sorted_quantized = [v for v,_ in sorted_random]
                    if isprint: print(sorted_random)
                    if isprint: print(sorted_quantized)
                    
                    while difference !=0:
                        for i, value in sorted_quantized:
                            if difference == 0:
                                break
                            # Calculate adjustment
                            # adjustment = min(difference, value % (1 / factor))
                            # adjustment = difference
                            new_value = value - 1.0/factor
                            
                            # Update the quantized values
                            quantized_values = [(idx, new_value if idx == i else v) for idx, v in quantized_values]
                            difference -= 1.0/factor
                        
                else:
                    # If the difference is negative (i.e., sum is less than 1), we need to increase values
                    # sorted_quantized = sorted(quantized_values, key=lambda x: x[1])
                    sorted_random = sorted(random_values, key=lambda x: (x[0][1],x[1]))
                    # sorted_quantized = sorted(quantized_values, key=lambda x: x[1], reverse=True)
                    sorted_quantized = [v for v,_ in sorted_random]
                    
                    while difference != 0:
                        for i, value in sorted_quantized:
                            if difference == 0:
                                break
                            # Calculate adjustment
                            # adjustment = min(-difference, (1 / factor) - (value % (1 / factor)))
                            # adjustment = -difference
                            new_value = value + 1.0/factor
                            
                            # Update the quantized values
                            quantized_values = [(idx, new_value if idx == i else v) for idx, v in quantized_values]
                            difference += 1.0/factor
            
            # Return the list sorted by original indices
            # return [v for i, v in sorted(quantized_values)]
            if isprint: print(quantized_values)
            return quantized_values


        with open(varfile,'r') as f:
            lines = f.readlines()[1:]

        valuearr = list()
        weightarr = list()
        qweightarr = list()
        for i in range(numsw):
            valuearr.append(list())
            weightarr.append(list())
            qweightarr.append(list())
            for j in range(numsw):
                valuearr[i].append(list())
                weightarr[i].append(list())
                qweightarr[i].append(list()) 

        for line in lines:
            tokens = line.split(',')
            varname = tokens[0]
            vartokens = varname.split('_')
            fromsw = int(vartokens[0])
            tosw = int(vartokens[1])
            pid = int(vartokens[2])
            value = float(tokens[1])
            valuearr[fromsw][tosw].append([pid,value])
            weightarr[fromsw][tosw].append([pid,value])

        for fromsw in range(numsw):
            for tosw in range(numsw):
                if len(valuearr[fromsw][tosw])>0:
                    valuesum = 0
                    for _,value in valuearr[fromsw][tosw]:
                        valuesum += value
                    valuetoweight = 1.0/valuesum
                    for ipv,pv in enumerate(weightarr[fromsw][tosw]):
                        weightarr[fromsw][tosw][ipv][1] = pv[1] * valuetoweight

        for fromsw in range(numsw):
            for tosw in range(numsw):
                if len(weightarr[fromsw][tosw])>0:
                    qweightarr[fromsw][tosw] = quantize_and_adjust_with_indices(weightarr[fromsw][tosw],factor)

        with open(qvarfile,'w') as f:
            for fromsw in range(numsw):
                for tosw in range(numsw):
                    if len(qweightarr[fromsw][tosw])>0:
                        for pid,weight in qweightarr[fromsw][tosw]:
                            if weight>0:
                                f.write(f"{fromsw},{tosw},{pid},{weight}\n")


        # check qvarfile
        checkweightarr = list()
        for i in range(numsw):
            checkweightarr.append(list())
            for j in range(numsw):
                checkweightarr[i].append(0)
        with open(qvarfile,'r') as f:
            lines = f.readlines()
            for line in lines:
                tokens = line.split(',')
                fromsw = int(tokens[0])
                tosw = int(tokens[1])
                pid = int(tokens[2])
                weight = float(tokens[3])
                checkweightarr[fromsw][tosw] += weight

        for fromsw in range(numsw):
            for tosw in range(numsw):
                if checkweightarr[fromsw][tosw]!=0 and checkweightarr[fromsw][tosw]!=1:
                    print(f"from {fromsw} to {tosw}: weight={checkweightarr[fromsw][tosw]}")
# Out:
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2843 rows, 173971 columns and 689730 nonzeros
# Model fingerprint: 0xc6232cc0
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.26s
# Presolved: 2843 rows, 173971 columns, 689730 nonzeros
# Ordering time: 0.15s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 3.953e+05
#  Factor NZ  : 1.241e+06 (roughly 80 MB of memory)
#  Factor Ops : 8.423e+08 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.51982272e-03  2.25303858e-03  1.01e+02 8.41e-04  2.09e-02     1s
#    1   1.26463151e-05  1.54233165e+00  4.75e+01 5.13e-02  9.92e-03     1s
#    2   4.54299059e-03  3.27710067e+00  3.90e+01 2.91e-02  8.28e-03     1s
#    3   1.21005778e-03  3.70712209e+00  4.29e+00 8.98e-03  9.88e-04     1s
#    4   1.00955367e-03  2.73159839e+00  1.23e+00 5.80e-03  3.27e-04     1s
#    5   8.59987055e-04  1.86852873e+00  4.82e-01 3.29e-03  1.45e-04     1s
#    6   7.12826534e-04  1.36696378e+00  2.03e-01 1.49e-03  6.76e-05     1s
#    7   5.24601665e-04  1.26255207e+00  1.16e-02 1.29e-03  3.23e-05     1s
#    8   5.15836906e-04  4.26104556e-02  1.25e-15 1.61e-05  9.89e-07     1s
#    9   5.98302150e-04  9.85834898e-03  6.94e-16 3.38e-06  2.17e-07     1s
#   10   7.86658101e-04  5.89297488e-03  5.00e-16 2.13e-06  1.19e-07     1s
#   11   8.92761702e-04  5.06030431e-03  6.11e-16 1.33e-06  9.74e-08     1s
#   12   9.59361134e-04  2.31933657e-03  1.03e-15 3.93e-07  3.17e-08     1s
#   13   1.01948150e-03  1.26249017e-03  2.61e-15 9.60e-08  5.65e-09     1s
#   14   1.02533695e-03  1.02934884e-03  5.27e-15 5.09e-10  9.21e-11     1s
#   15   1.02545054e-03  1.02545056e-03  2.84e-15 1.56e-15  3.00e-16     1s
#
# Barrier solved model in 15 iterations and 1.16 seconds (1.01 work units)
# Optimal objective 1.02545054e-03
#
# Optimal objective value: 0.0010254505428073056
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2764 rows, 156549 columns and 620672 nonzeros
# Model fingerprint: 0x79f50d04
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.25s
# Presolved: 2764 rows, 156549 columns, 620672 nonzeros
# Ordering time: 0.11s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 3.598e+05
#  Factor NZ  : 1.293e+06 (roughly 70 MB of memory)
#  Factor Ops : 7.936e+08 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.65322450e-02  4.13767926e-03  3.46e+02 8.42e-04  7.91e-02     1s
#    1   8.19215300e-05  1.04085054e+01  2.22e+02 1.90e-02  5.17e-02     1s
#    2   4.33047493e-03  1.22779189e+01  4.56e+01 1.12e-02  1.12e-02     1s
#    3   1.66137087e-03  7.99719465e+00  9.40e+00 3.02e-03  2.48e-03     1s
#    4   7.98985561e-04  5.98534465e+00  2.27e+00 1.46e-03  7.03e-04     1s
#    5   6.02003861e-04  4.75112957e+00  1.03e+00 6.88e-04  3.41e-04     1s
#    6   3.85199141e-04  3.10893137e+00  1.92e-02 2.09e-04  8.34e-05     1s
#    7   3.98722451e-04  7.53668310e-02  3.00e-15 4.69e-06  1.94e-06     1s
#    8   4.96149087e-04  2.11336000e-02  2.11e-15 1.20e-06  5.33e-07     1s
#    9   6.42461171e-04  1.14481335e-02  1.89e-15 5.94e-07  2.79e-07     1s
#   10   8.59425636e-04  5.84902589e-03  2.00e-15 2.49e-07  1.29e-07     1s
#   11   9.23567906e-04  3.13972802e-03  1.67e-15 9.08e-08  5.69e-08     1s
#   12   9.69731595e-04  1.64978075e-03  3.44e-15 1.01e-08  1.72e-08     1s
#   13   1.03857908e-03  1.26999300e-03  2.88e-14 2.80e-09  5.85e-09     1s
#   14   1.08301831e-03  1.08639932e-03  6.48e-14 0.00e+00  8.50e-11     1s
#   15   1.08418179e-03  1.08418220e-03  4.39e-14 0.00e+00  1.01e-14     1s
#
# Barrier solved model in 15 iterations and 0.96 seconds (0.90 work units)
# Optimal objective 1.08418179e-03
#
# Optimal objective value: 0.0010841817943850428
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2602 rows, 155509 columns and 616542 nonzeros
# Model fingerprint: 0x6b30074c
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.23s
# Presolved: 2602 rows, 155509 columns, 616542 nonzeros
# Ordering time: 0.11s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 3.471e+05
#  Factor NZ  : 8.835e+05 (roughly 70 MB of memory)
#  Factor Ops : 4.846e+08 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.07548290e-02  2.75914933e-03  1.30e+02 3.05e-04  2.55e-02     0s
#    1   2.47184123e-05  4.80584011e+00  5.97e+01 5.34e-02  1.19e-02     1s
#    2   4.93086043e-03  6.93243331e+00  5.38e+01 3.50e-02  1.08e-02     1s
#    3   9.42354507e-04  9.05139371e+00  9.83e+00 2.20e-02  2.13e-03     1s
#    4   6.00510774e-04  6.12266012e+00  2.30e+00 9.67e-03  5.64e-04     1s
#    5   3.85243312e-04  4.84476882e+00  4.11e-01 6.10e-03  1.58e-04     1s
#    6   3.02504637e-04  3.09512412e+00  5.92e-02 2.19e-03  5.32e-05     1s
#    7   2.83784172e-04  6.96653246e-01  1.48e-04 2.37e-04  9.58e-06     1s
#    8   2.97042768e-04  1.58998416e-02  1.11e-15 5.31e-06  2.15e-07     1s
#    9   5.33735641e-04  8.63373456e-03  1.28e-15 2.71e-06  1.11e-07     1s
#   10   7.17015489e-04  4.24685098e-03  1.28e-15 1.30e-06  4.80e-08     1s
#   11   8.07649448e-04  3.00024691e-03  1.14e-15 7.89e-07  2.97e-08     1s
#   12   8.75040079e-04  2.41828681e-03  5.44e-15 5.50e-07  2.09e-08     1s
#   13   9.07194207e-04  1.94834036e-03  9.16e-16 3.62e-07  1.41e-08     1s
#   14   9.56335418e-04  1.36597160e-03  5.83e-15 1.30e-07  5.51e-09     1s
#   15   9.94215856e-04  1.08728768e-03  7.33e-15 2.32e-08  1.24e-09     1s
#   16   1.00305543e-03  1.00931802e-03  9.26e-14 2.41e-10  8.00e-11     1s
#   17   1.00341785e-03  1.00344015e-03  1.03e-12 6.84e-14  2.83e-13     1s
#   18   1.00343284e-03  1.00343286e-03  6.03e-11 3.94e-17  2.83e-16     1s
#
# Barrier solved model in 18 iterations and 0.97 seconds (0.94 work units)
# Optimal objective 1.00343284e-03
#
# Optimal objective value: 0.0010034328402609295
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2922 rows, 193543 columns and 767328 nonzeros
# Model fingerprint: 0x54ea4dbe
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.30s
# Presolved: 2922 rows, 193543 columns, 767328 nonzeros
# Ordering time: 0.15s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 4.445e+05
#  Factor NZ  : 1.876e+06 (roughly 100 MB of memory)
#  Factor Ops : 1.626e+09 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.45959013e-03  2.75548991e-03  1.17e+02 1.12e-03  2.37e-02     1s
#    1   1.64443242e-05  2.79846141e+00  6.04e+01 4.70e-02  1.25e-02     1s
#    2   5.37171961e-03  5.16505603e+00  4.81e+01 2.16e-02  1.01e-02     1s
#    3   1.21525182e-03  6.05402717e+00  8.25e+00 1.53e-02  1.84e-03     1s
#    4   9.69810550e-04  4.41269263e+00  2.97e+00 8.14e-03  7.16e-04     1s
#    5   8.03930691e-04  3.27222536e+00  1.05e+00 5.16e-03  2.90e-04     1s
#    6   6.24782334e-04  2.57275512e+00  3.95e-01 3.27e-03  1.34e-04     1s
#    7   5.35859896e-04  2.07856446e+00  1.17e-01 2.03e-03  6.51e-05     1s
#    8   4.92073120e-04  6.99248128e-01  3.31e-02 3.60e-04  1.70e-05     1s
#    9   4.74530149e-04  4.15191529e-02  1.61e-15 9.72e-06  8.57e-07     1s
#   10   5.19079231e-04  1.29931751e-02  9.99e-16 2.68e-06  2.59e-07     1s
#   11   7.10461172e-04  7.26117963e-03  8.05e-16 1.35e-06  1.36e-07     1s
#   12   8.04665231e-04  4.78634867e-03  7.49e-16 8.24e-07  8.27e-08     1s
#   13   8.80238126e-04  3.36513968e-03  1.18e-13 4.92e-07  5.16e-08     1s
#   14   8.89618334e-04  2.68912988e-03  7.92e-14 3.52e-07  3.73e-08     1s
#   15   9.11113099e-04  1.86147558e-03  2.62e-14 1.72e-07  1.97e-08     1s
#   16   9.50008585e-04  1.25983611e-03  1.40e-14 4.66e-08  6.41e-09     1s
#   17   9.54540861e-04  9.55932031e-04  2.16e-14 1.65e-11  2.84e-11     1s
#   18   9.55028268e-04  9.55028290e-04  3.86e-13 0.00e+00  4.31e-16     1s
#
# Barrier solved model in 18 iterations and 1.31 seconds (1.28 work units)
# Optimal objective 9.55028268e-04
#
# Optimal objective value: 0.000955028268420941
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2922 rows, 194583 columns and 771458 nonzeros
# Model fingerprint: 0xbf26c297
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.29s
# Presolved: 2922 rows, 194583 columns, 771458 nonzeros
# Ordering time: 0.16s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 4.512e+05
#  Factor NZ  : 1.911e+06 (roughly 100 MB of memory)
#  Factor Ops : 1.679e+09 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.45913359e-03  2.44792025e-03  9.22e+01 9.49e-04  1.93e-02     1s
#    1   1.74475212e-05  1.51531344e+00  4.13e+01 6.25e-02  8.70e-03     1s
#    2   3.19383288e-03  2.69727914e+00  3.77e+01 5.20e-02  8.03e-03     1s
#    3   5.21460660e-04  4.04006374e+00  5.01e+00 2.27e-02  1.17e-03     1s
#    4   4.21357787e-04  3.15466669e+00  1.65e+00 1.54e-02  4.37e-04     1s
#    5   4.20903118e-04  2.14502353e+00  8.27e-01 8.90e-03  2.31e-04     1s
#    6   3.23327439e-04  1.88402062e+00  1.69e-01 4.97e-03  7.79e-05     1s
#    7   2.99070651e-04  1.39041884e+00  1.11e-15 2.94e-03  3.29e-05     1s
#    8   3.03611525e-04  1.07399643e-02  9.44e-16 2.20e-05  2.47e-07     1s
#    9   6.73661093e-04  6.09655572e-03  5.41e-16 1.22e-05  1.27e-07     1s
#   10   7.58111857e-04  4.19203516e-03  4.44e-16 6.78e-06  7.93e-08     1s
#   11   8.19225619e-04  3.66187187e-03  7.77e-16 5.46e-06  6.57e-08     1s
#   12   8.91486623e-04  2.25052156e-03  2.44e-15 2.66e-06  3.11e-08     1s
#   13   9.42700137e-04  1.31336172e-03  2.07e-15 5.30e-07  8.29e-09     1s
#   14   9.95592158e-04  1.04723347e-03  2.30e-15 6.97e-08  1.15e-09     1s
#   15   9.98766111e-04  9.98880008e-04  1.02e-14 4.59e-11  2.37e-12     1s
#   16   9.98791558e-04  9.98791558e-04  7.73e-14 5.63e-17  3.11e-18     1s
#
# Barrier solved model in 16 iterations and 1.26 seconds (1.23 work units)
# Optimal objective 9.98791558e-04
#
# Optimal objective value: 0.0009987915582136016
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2631 rows, 127731 columns and 506406 nonzeros
# Model fingerprint: 0x67e9e01a
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.21s
# Presolved: 2631 rows, 127731 columns, 506406 nonzeros
# Ordering time: 0.09s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 2.999e+05
#  Factor NZ  : 1.011e+06 (roughly 60 MB of memory)
#  Factor Ops : 5.668e+08 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.27994717e-03  2.44459501e-03  1.02e+02 1.25e-03  2.45e-02     0s
#    1   1.77790558e-05  1.85271818e+00  5.66e+01 5.23e-02  1.38e-02     0s
#    2   4.13294328e-03  3.28738183e+00  3.28e+01 2.78e-02  8.18e-03     1s
#    3   1.11040857e-03  3.26415844e+00  3.36e+00 3.20e-03  9.21e-04     1s
#    4   8.08134786e-04  2.05672018e+00  1.35e+00 2.07e-03  3.93e-04     1s
#    5   4.50118556e-04  1.64528201e+00  1.91e-01 1.18e-03  9.63e-05     1s
#    6   3.98285467e-04  1.15759239e+00  6.43e-03 6.60e-04  3.83e-05     1s
#    7   4.00696535e-04  1.51253781e-02  1.47e-15 4.64e-06  4.63e-07     1s
#    8   5.22096711e-04  6.38022381e-03  1.17e-15 1.66e-06  1.84e-07     1s
#    9   6.53739421e-04  4.21133516e-03  8.33e-16 9.14e-07  1.11e-07     1s
#   10   8.05309528e-04  2.35140249e-03  5.55e-16 2.88e-07  4.83e-08     1s
#   11   8.80440789e-04  1.50803442e-03  6.66e-16 7.97e-08  1.95e-08     1s
#   12   9.25375771e-04  1.04331202e-03  9.44e-16 2.49e-09  3.64e-09     1s
#   13   9.63490536e-04  9.93903330e-04  1.92e-15 0.00e+00  9.37e-10     1s
#   14   9.76585090e-04  9.77329080e-04  3.52e-15 5.73e-12  2.29e-11     1s
#   15   9.76805316e-04  9.76809423e-04  3.14e-15 0.00e+00  1.26e-13     1s
#
# Barrier solved model in 15 iterations and 0.84 seconds (0.73 work units)
# Optimal objective 9.76805316e-04
#
# Optimal objective value: 0.0009768053160611769
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2762 rows, 151447 columns and 600295 nonzeros
# Model fingerprint: 0xae470f7d
# Coefficient statistics:
#   Matrix range     [5e-01, 7e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.22s
# Presolved: 2762 rows, 151447 columns, 600295 nonzeros
# Ordering time: 0.13s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 3.598e+05
#  Factor NZ  : 1.737e+06 (roughly 80 MB of memory)
#  Factor Ops : 1.418e+09 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.32241170e-02  3.80963988e-03  1.30e+02 6.13e-04  3.01e-02     1s
#    1   3.19264591e-05  5.16040431e+00  6.84e+01 6.20e-02  1.62e-02     1s
#    2   9.76503409e-03  9.90029080e+00  5.46e+01 3.06e-02  1.31e-02     1s
#    3   2.37945532e-03  1.16794121e+01  9.35e+00 5.23e-03  2.37e-03     1s
#    4   1.48871786e-03  7.87414478e+00  2.91e+00 4.04e-03  8.01e-04     1s
#    5   8.63003758e-04  5.93695211e+00  9.04e-01 2.35e-03  2.93e-04     1s
#    6   7.46948261e-04  4.81450462e+00  5.70e-01 1.15e-03  1.79e-04     1s
#    7   5.50219775e-04  4.21149986e+00  1.59e-01 7.77e-04  8.57e-05     1s
#    8   4.38994645e-04  2.21271740e+00  3.09e-04 3.75e-04  2.99e-05     1s
#    9   4.42661282e-04  1.06847328e-02  2.00e-15 1.76e-06  1.38e-07     1s
#   10   6.01455035e-04  5.91939226e-03  1.05e-15 7.89e-07  7.16e-08     1s
#   11   7.70174052e-04  3.46784194e-03  7.22e-16 2.68e-07  3.61e-08     1s
#   12   8.12797838e-04  2.31850197e-03  8.88e-16 1.34e-07  2.01e-08     1s
#   13   9.00782131e-04  1.29667260e-03  2.03e-15 2.44e-08  5.26e-09     1s
#   14   9.18109711e-04  1.20211637e-03  2.15e-14 1.74e-08  3.77e-09     1s
#   15   9.33379512e-04  9.82037915e-04  2.11e-14 6.33e-10  6.36e-10     1s
#   16   9.40372863e-04  9.52277404e-04  3.09e-14 0.00e+00  1.55e-10     1s
#   17   9.47964179e-04  9.48417255e-04  7.12e-14 0.00e+00  5.89e-12     1s
#   18   9.47980652e-04  9.47980677e-04  3.28e-14 2.16e-17  3.20e-16     1s
#
# Barrier solved model in 18 iterations and 1.15 seconds (1.01 work units)
# Optimal objective 9.47980652e-04
#
# Optimal objective value: 0.0009479806523834916
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2426 rows, 23393 columns and 88776 nonzeros
# Model fingerprint: 0xc5eeed73
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.04s
# Presolved: 2426 rows, 23393 columns, 88776 nonzeros
# Ordering time: 0.02s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 6.083e+04
#  Factor NZ  : 1.689e+05 (roughly 12 MB of memory)
#  Factor Ops : 1.969e+07 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.40628754e-02  2.06281282e-03  3.00e+01 2.88e-04  3.87e-02     0s
#    1   3.79983814e-05  3.99279441e+00  1.58e+01 4.75e-02  2.07e-02     0s
#    2   9.37656252e-03  1.00019031e+01  1.23e+01 0.00e+00  1.71e-02     0s
#    3   1.79830961e-03  7.42318859e+00  1.33e+00 0.00e+00  2.27e-03     0s
#    4   7.41227145e-04  4.42075078e+00  1.48e-01 0.00e+00  5.06e-04     0s
#    5   4.88652787e-04  2.34750171e+00  9.16e-16 0.00e+00  1.83e-04     0s
#    6   4.89735953e-04  3.60231276e-03  7.22e-16 0.00e+00  2.43e-07     0s
#    7   8.09658595e-04  2.57705375e-03  5.55e-16 0.00e+00  1.38e-07     0s
#    8   9.27397912e-04  1.67942297e-03  5.00e-16 0.00e+00  5.87e-08     0s
#    9   9.91296932e-04  1.17594940e-03  9.99e-16 0.00e+00  1.44e-08     0s
#   10   1.00955660e-03  1.03499104e-03  7.94e-15 0.00e+00  1.99e-09     0s
#   11   1.02155331e-03  1.02444329e-03  5.30e-13 0.00e+00  2.26e-10     0s
#   12   1.02189686e-03  1.02190617e-03  4.58e-12 3.33e-17  7.27e-13     0s
#
# Barrier solved model in 12 iterations and 0.14 seconds (0.12 work units)
# Optimal objective 1.02189686e-03
#
# Optimal objective value: 0.0010218968553977008
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2523 rows, 23722 columns and 89555 nonzeros
# Model fingerprint: 0xebc6e94d
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 8 rows and 0 columns
# Presolve time: 0.06s
# Presolved: 2515 rows, 23722 columns, 89547 nonzeros
# Ordering time: 0.02s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 6.518e+04
#  Factor NZ  : 2.628e+05 (roughly 13 MB of memory)
#  Factor Ops : 5.156e+07 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.05654427e-02  2.41431214e-03  2.59e+01 3.40e-04  2.64e-02     0s
#    1   2.64160106e-05  3.89961848e+00  1.24e+01 4.00e-02  1.27e-02     0s
#    2   6.06090125e-03  6.79993164e+00  9.52e+00 1.36e-02  1.00e-02     0s
#    3   1.61595227e-03  4.73778775e+00  1.40e+00 1.35e-03  1.68e-03     0s
#    4   4.41849508e-04  3.40498327e+00  8.31e-02 4.01e-04  3.35e-04     0s
#    5   3.51208349e-04  4.92745970e-01  8.33e-16 4.12e-05  3.83e-05     0s
#    6   3.57432608e-04  5.67537502e-03  7.49e-16 4.67e-07  4.13e-07     0s
#    7   4.86485297e-04  4.17393606e-03  4.44e-16 2.55e-07  2.86e-07     0s
#    8   6.41145249e-04  2.81277173e-03  6.11e-16 8.61e-08  1.68e-07     0s
#    9   7.31969708e-04  2.19018203e-03  7.49e-16 0.00e+00  1.13e-07     0s
#   10   8.74759961e-04  1.41343650e-03  1.55e-15 0.00e+00  4.16e-08     0s
#   11   9.07619694e-04  1.07093676e-03  1.19e-15 0.00e+00  1.26e-08     0s
#   12   9.37165591e-04  9.42679850e-04  2.64e-15 0.00e+00  4.24e-10     0s
#   13   9.38899151e-04  9.38908961e-04  1.93e-14 1.08e-19  7.54e-13     0s
#
# Barrier solved model in 13 iterations and 0.18 seconds (0.14 work units)
# Optimal objective 9.38899151e-04
#
# Optimal objective value: 0.0009388991510434956
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2756 rows, 158289 columns and 627558 nonzeros
# Model fingerprint: 0xee865987
# Coefficient statistics:
#   Matrix range     [4e-01, 7e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.23s
# Presolved: 2756 rows, 158289 columns, 627558 nonzeros
# Ordering time: 0.12s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 3.673e+05
#  Factor NZ  : 1.356e+06 (roughly 80 MB of memory)
#  Factor Ops : 9.391e+08 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.13918384e-02  3.36248464e-03  1.19e+02 6.28e-04  2.57e-02     1s
#    1   2.88422425e-05  3.73690356e+00  6.39e+01 5.50e-02  1.40e-02     1s
#    2   8.39585961e-03  8.11865009e+00  5.01e+01 2.07e-02  1.12e-02     1s
#    3   1.45785578e-03  8.03354672e+00  3.85e+00 5.20e-03  9.53e-04     1s
#    4   1.01790968e-03  4.93525793e+00  1.65e+00 2.15e-03  4.24e-04     1s
#    5   7.28062065e-04  4.05864554e+00  5.24e-01 1.32e-03  1.61e-04     1s
#    6   5.73479867e-04  3.57391088e+00  2.27e-01 9.83e-04  8.94e-05     1s
#    7   5.33573455e-04  2.55135191e+00  1.71e-01 4.21e-04  5.77e-05     1s
#    8   3.92793826e-04  1.77420448e+00  2.20e-03 2.37e-04  2.29e-05     1s
#    9   3.94292673e-04  1.18530539e-02  9.99e-16 1.48e-06  1.47e-07     1s
#   10   4.70905603e-04  5.69092674e-03  8.33e-16 7.23e-07  6.64e-08     1s
#   11   6.83510949e-04  4.22226521e-03  7.22e-16 4.18e-07  4.50e-08     1s
#   12   7.86563943e-04  3.75919729e-03  7.22e-16 4.24e-07  3.78e-08     1s
#   13   8.22161831e-04  2.69562663e-03  8.33e-16 2.73e-07  2.38e-08     1s
#   14   8.84567757e-04  1.62877462e-03  3.05e-14 9.85e-08  9.44e-09     1s
#   15   9.31585990e-04  1.09252336e-03  7.71e-14 1.46e-08  2.03e-09     1s
#   16   9.51540082e-04  9.72328911e-04  7.16e-14 3.78e-10  2.60e-10     1s
#   17   9.61023803e-04  9.64388354e-04  1.93e-12 4.81e-11  4.20e-11     1s
#   18   9.62183599e-04  9.62262341e-04  3.24e-12 7.86e-13  9.83e-13     1s
#   19   9.62189899e-04  9.62189899e-04  1.82e-11 3.55e-17  3.62e-18     1s
#
# Barrier solved model in 19 iterations and 1.10 seconds (1.05 work units)
# Optimal objective 9.62189899e-04
#
# Optimal objective value: 0.0009621898988545506
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2586 rows, 112289 columns and 445269 nonzeros
# Model fingerprint: 0xba5a7384
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.17s
# Presolved: 2586 rows, 112289 columns, 445269 nonzeros
# Ordering time: 0.08s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 1.781e+05
#  Factor NZ  : 7.276e+05 (roughly 40 MB of memory)
#  Factor Ops : 4.003e+08 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.95688954e-02  3.15880439e-03  1.60e+02 8.50e-04  5.25e-02     1s
#    1   6.15911613e-05  2.43339487e+00  9.60e+01 6.09e-02  3.20e-02     1s
#    2   1.16201600e-02  4.54826923e+00  5.65e+01 3.26e-02  1.93e-02     1s
#    3   7.17914297e-04  5.72931177e+00  6.32e+00 1.11e-02  2.33e-03     1s
#    4   4.97106152e-04  4.27016596e+00  1.61e+00 6.16e-03  6.71e-04     1s
#    5   3.81200201e-04  3.64716137e+00  5.94e-01 4.98e-03  3.07e-04     1s
#    6   2.69674057e-04  2.46135489e+00  8.77e-02 2.67e-03  9.88e-05     1s
#    7   2.56373567e-04  1.04503029e+00  6.11e-16 8.23e-04  2.97e-05     1s
#    8   2.67772510e-04  2.31846180e-02  4.72e-16 1.80e-05  6.52e-07     1s
#    9   4.28681819e-04  1.39183259e-02  3.89e-16 9.48e-06  3.82e-07     1s
#   10   6.35851832e-04  7.64011924e-03  3.61e-16 4.07e-06  1.97e-07     1s
#   11   8.04565753e-04  5.85431179e-03  2.78e-16 3.08e-06  1.42e-07     1s
#   12   8.71692477e-04  2.98204726e-03  2.50e-16 1.02e-06  5.87e-08     1s
#   13   9.78141577e-04  1.78065184e-03  3.19e-16 3.83e-07  2.20e-08     1s
#   14   1.03822631e-03  1.11588716e-03  3.33e-16 5.15e-09  2.06e-09     1s
#   15   1.03685048e-03  1.07929930e-03  8.19e-16 2.31e-09  1.12e-09     1s
#   16   1.06399060e-03  1.06624628e-03  5.19e-15 0.00e+00  5.92e-11     1s
#   17   1.06427147e-03  1.06427408e-03  7.49e-16 0.00e+00  6.84e-14     1s
#
# Barrier solved model in 17 iterations and 0.78 seconds (0.68 work units)
# Optimal objective 1.06427147e-03
#
# Optimal objective value: 0.0010642714688454203
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2289 rows, 78218 columns and 310065 nonzeros
# Model fingerprint: 0x5f9fd853
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.10s
# Presolved: 2289 rows, 78218 columns, 310065 nonzeros
# Ordering time: 0.02s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 1.338e+05
#  Factor NZ  : 4.152e+05 (roughly 27 MB of memory)
#  Factor Ops : 1.401e+08 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.66914933e-02  2.71027205e-03  2.91e+02 1.79e-03  8.95e-02     0s
#    1   4.36675500e-05  1.63534476e+00  1.91e+02 5.24e-02  5.96e-02     0s
#    2   1.17342275e-03  3.59028330e+00  3.38e+01 9.79e-03  1.16e-02     0s
#    3   4.36711144e-04  2.74373053e+00  4.16e+00 1.96e-03  1.57e-03     0s
#    4   3.27213655e-04  1.86025010e+00  9.43e-01 1.12e-03  4.44e-04     0s
#    5   2.67305892e-04  1.27975467e+00  2.05e-01 5.69e-04  1.51e-04     0s
#    6   2.29466434e-04  3.13751244e-01  1.33e-15 3.15e-05  2.19e-05     0s
#    7   2.88993199e-04  4.20216664e-02  5.27e-16 4.14e-06  2.91e-06     0s
#    8   4.11941427e-04  2.26815334e-02  7.22e-16 1.89e-06  1.55e-06     0s
#    9   5.44393786e-04  1.59775004e-02  8.33e-16 1.27e-06  1.08e-06     0s
#   10   6.96012508e-04  8.02916439e-03  3.89e-16 5.98e-07  5.11e-07     0s
#   11   7.02580610e-04  7.42072507e-03  3.89e-16 5.45e-07  4.68e-07     0s
#   12   8.38819477e-04  4.21986720e-03  3.33e-16 2.45e-07  2.35e-07     0s
#   13   8.88354625e-04  2.77442978e-03  4.44e-16 1.30e-07  1.31e-07     0s
#   14   9.98327285e-04  1.31706729e-03  5.55e-16 4.80e-09  2.21e-08     0s
#   15   1.04256348e-03  1.11410544e-03  8.05e-16 1.26e-10  4.95e-09     0s
#   16   1.06248190e-03  1.08660149e-03  2.72e-15 0.00e+00  1.67e-09     1s
#   17   1.07687862e-03  1.08169867e-03  1.06e-14 0.00e+00  3.34e-10     1s
#   18   1.08021124e-03  1.08022308e-03  9.42e-15 4.34e-19  8.19e-13     1s
#   19   1.08021756e-03  1.08021756e-03  3.07e-15 4.16e-17  8.46e-19     1s
#
# Barrier solved model in 19 iterations and 0.54 seconds (0.48 work units)
# Optimal objective 1.08021756e-03
#
# Optimal objective value: 0.0010802175558092138
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2337 rows, 77150 columns and 305866 nonzeros
# Model fingerprint: 0x359e3473
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.12s
# Presolved: 2337 rows, 77150 columns, 305866 nonzeros
# Ordering time: 0.06s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 1.297e+05
#  Factor NZ  : 5.085e+05 (roughly 26 MB of memory)
#  Factor Ops : 2.066e+08 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.30137339e-02  3.16001119e-03  1.79e+02 7.54e-04  6.35e-02     0s
#    1   6.57027182e-05  2.64141115e+00  1.01e+02 6.07e-02  3.66e-02     0s
#    2   1.26521220e-02  6.09232109e+00  5.95e+01 1.68e-02  2.21e-02     0s
#    3   2.11517383e-03  6.11239611e+00  6.50e+00 3.43e-03  2.61e-03     0s
#    4   1.07915497e-03  3.26935670e+00  1.44e+00 1.62e-03  6.60e-04     0s
#    5   6.48248793e-04  2.57262317e+00  4.10e-01 9.56e-04  2.43e-04     0s
#    6   5.06374656e-04  2.04300049e+00  5.08e-02 6.70e-04  9.57e-05     0s
#    7   4.79340369e-04  5.90941880e-01  2.48e-04 1.47e-04  2.29e-05     0s
#    8   4.90480108e-04  1.01703186e-02  6.38e-16 2.40e-06  3.75e-07     0s
#    9   6.55299599e-04  7.52339038e-03  4.58e-16 1.66e-06  2.66e-07     0s
#   10   7.60187203e-04  5.02303137e-03  3.61e-16 9.06e-07  1.65e-07     0s
#   11   8.90558448e-04  3.01241074e-03  3.61e-16 4.51e-07  8.17e-08     1s
#   12   1.01517230e-03  1.53810734e-03  2.78e-16 7.53e-08  2.00e-08     1s
#   13   1.05129552e-03  1.30581535e-03  8.88e-16 3.08e-08  9.69e-09     1s
#   14   1.08287270e-03  1.12630272e-03  2.41e-15 9.50e-11  1.63e-09     1s
#   15   1.09310086e-03  1.10726599e-03  3.08e-15 0.00e+00  5.32e-10     1s
#   16   1.10384028e-03  1.10414148e-03  4.25e-15 5.75e-17  1.13e-11     1s
#   17   1.10387436e-03  1.10387437e-03  2.05e-15 3.04e-19  2.91e-16     1s
#
# Barrier solved model in 17 iterations and 0.57 seconds (0.47 work units)
# Optimal objective 1.10387436e-03
#
# Optimal objective value: 0.0011038743616116396
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2586 rows, 121561 columns and 482121 nonzeros
# Model fingerprint: 0xa91b6b95
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.21s
# Presolved: 2586 rows, 121561 columns, 482121 nonzeros
# Ordering time: 0.08s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 2.166e+05
#  Factor NZ  : 8.475e+05 (roughly 45 MB of memory)
#  Factor Ops : 4.664e+08 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.00344169e-02  3.43728138e-03  1.64e+02 5.00e-04  5.31e-02     1s
#    1   5.16723558e-05  3.36624250e+00  8.54e+01 5.42e-02  2.81e-02     1s
#    2   1.17776797e-02  7.00629477e+00  6.67e+01 2.59e-02  2.24e-02     1s
#    3   1.31407447e-03  7.97257619e+00  4.91e+00 6.25e-03  1.81e-03     1s
#    4   9.34277495e-04  4.63203504e+00  1.10e+00 2.81e-03  4.75e-04     1s
#    5   7.77501438e-04  4.06786595e+00  6.24e-01 1.93e-03  2.90e-04     1s
#    6   5.27048029e-04  3.35633498e+00  1.47e-01 1.35e-03  1.19e-04     1s
#    7   4.10228015e-04  2.22311368e+00  1.37e-03 7.07e-04  4.97e-05     1s
#    8   4.11645003e-04  9.93765471e-03  5.27e-16 2.87e-06  2.11e-07     1s
#    9   4.77369668e-04  6.66840771e-03  4.16e-16 1.50e-06  1.37e-07     1s
#   10   5.58539661e-04  5.29836068e-03  3.47e-16 1.10e-06  1.05e-07     1s
#   11   7.53636188e-04  3.86354032e-03  3.61e-16 6.99e-07  6.87e-08     1s
#   12   8.71134405e-04  2.80151389e-03  3.89e-16 5.17e-07  4.26e-08     1s
#   13   9.55466470e-04  1.74017662e-03  7.91e-16 1.98e-07  1.73e-08     1s
#   14   1.00035657e-03  1.24930806e-03  3.86e-15 5.70e-08  5.46e-09     1s
#   15   1.01469522e-03  1.02752771e-03  1.08e-13 1.45e-09  2.78e-10     1s
#   16   1.01694346e-03  1.01696918e-03  2.28e-12 4.81e-17  5.48e-13     1s
#   17   1.01695088e-03  1.01695088e-03  1.22e-11 2.17e-19  5.59e-19     1s
#
# Barrier solved model in 17 iterations and 1.01 seconds (0.79 work units)
# Optimal objective 1.01695088e-03
#
# Optimal objective value: 0.0010169508761879308
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2667 rows, 134525 columns and 533592 nonzeros
# Model fingerprint: 0xeb516b42
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.20s
# Presolved: 2667 rows, 134525 columns, 533592 nonzeros
# Ordering time: 0.09s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 2.258e+05
#  Factor NZ  : 8.520e+05 (roughly 50 MB of memory)
#  Factor Ops : 4.856e+08 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.77653690e-02  3.19372563e-03  2.68e+02 7.71e-04  7.86e-02     1s
#    1   9.67772502e-05  3.11861689e+00  1.66e+02 5.66e-02  4.95e-02     1s
#    2   1.74853475e-02  5.67988602e+00  9.47e+01 3.27e-02  2.87e-02     1s
#    3   5.44585049e-04  7.93230007e+00  7.58e+00 6.96e-03  2.49e-03     1s
#    4   4.57106937e-04  5.69400535e+00  2.60e+00 3.60e-03  9.14e-04     1s
#    5   3.55865732e-04  4.30313753e+00  7.86e-01 2.26e-03  3.26e-04     1s
#    6   2.85113949e-04  3.60408384e+00  2.93e-01 1.64e-03  1.59e-04     1s
#    7   2.17877867e-04  3.04542904e+00  6.26e-02 1.16e-03  8.06e-05     1s
#    8   2.01142259e-04  4.00809667e-01  5.69e-16 5.28e-05  8.24e-06     1s
#    9   2.44239412e-04  7.38246833e-02  5.00e-16 9.08e-06  1.51e-06     1s
#   10   3.41970182e-04  2.52256808e-02  4.72e-16 2.63e-06  5.10e-07     1s
#   11   4.03851987e-04  1.37367987e-02  4.72e-16 1.32e-06  2.73e-07     1s
#   12   5.45367129e-04  8.47024399e-03  3.19e-16 7.42e-07  1.62e-07     1s
#   13   6.60421994e-04  4.64805231e-03  3.33e-16 3.38e-07  8.15e-08     1s
#   14   7.58667107e-04  3.56205637e-03  3.89e-16 2.77e-07  5.73e-08     1s
#   15   8.06896741e-04  2.41425260e-03  3.33e-16 1.20e-07  3.28e-08     1s
#   16   8.80777142e-04  1.21525074e-03  5.83e-16 1.51e-08  6.80e-09     1s
#   17   9.16954036e-04  9.99444311e-04  4.52e-15 1.54e-09  1.67e-09     1s
#   18   9.37559628e-04  9.57366702e-04  1.33e-13 2.36e-12  3.99e-10     1s
#   19   9.47873647e-04  9.52316900e-04  6.01e-13 0.00e+00  8.96e-11     1s
#   20   9.50357158e-04  9.50365419e-04  5.09e-13 1.63e-19  1.66e-13     1s
#
# Barrier solved model in 20 iterations and 1.02 seconds (0.91 work units)
# Optimal objective 9.50357158e-04
#
# Optimal objective value: 0.0009503571580422132
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 1654 rows, 7846 columns and 29432 nonzeros
# Model fingerprint: 0x71a0c42b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 12 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 1642 rows, 7846 columns, 29420 nonzeros
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 3.589e+04
#  Factor NZ  : 6.416e+04 (roughly 2 MB of memory)
#  Factor Ops : 9.793e+06 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.43958043e-02  2.38649702e-03  1.85e+02 2.58e-03  4.12e-01     0s
#    1   2.33253641e-04  2.96414863e+00  1.29e+02 7.32e-03  2.78e-01     0s
#    2   2.91366991e-05  2.87067955e+00  1.05e+01 5.55e-17  2.71e-02     0s
#    3   9.27473676e-06  1.57815980e+00  1.95e+00 1.55e-15  6.63e-03     0s
#    4   5.23937751e-06  6.27043804e-01  2.93e-01 1.11e-16  1.67e-03     0s
#    5   4.32468208e-06  5.83074325e-02  4.44e-16 1.80e-16  1.15e-04     0s
#    6   2.17248830e-05  3.08335614e-02  4.44e-16 6.94e-17  6.06e-05     0s
#    7   2.36221230e-04  2.19515308e-02  6.66e-16 5.59e-17  4.27e-05     0s
#    8   4.08808274e-04  1.22427286e-02  4.44e-16 2.26e-17  2.33e-05     0s
#    9   6.96982994e-04  4.90907990e-03  5.55e-16 6.07e-18  8.29e-06     0s
#   10   8.68893239e-04  3.44332943e-03  5.55e-16 2.39e-17  5.07e-06     0s
#   11   9.24467121e-04  1.77880112e-03  4.44e-16 8.67e-19  1.68e-06     0s
#   12   9.77918932e-04  1.30626225e-03  9.99e-16 1.42e-17  6.46e-07     0s
#   13   1.01164317e-03  1.03752868e-03  2.34e-14 1.21e-17  5.09e-08     0s
#   14   1.01696831e-03  1.01708156e-03  2.02e-14 5.42e-19  2.23e-10     0s
#   15   1.01700829e-03  1.01700841e-03  2.82e-14 5.35e-19  2.23e-13     0s
#
# Barrier solved model in 15 iterations and 0.09 seconds (0.04 work units)
# Optimal objective 1.01700829e-03
#
# Optimal objective value: 0.0010170082938959798
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2469 rows, 83666 columns and 331628 nonzeros
# Model fingerprint: 0x87809ef3
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.10s
# Presolved: 2469 rows, 83666 columns, 331628 nonzeros
# Ordering time: 0.04s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 8.269e+04
#  Factor NZ  : 2.728e+05 (roughly 17 MB of memory)
#  Factor Ops : 8.850e+07 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.73853635e-02  4.04873889e-03  1.46e+02 2.56e-03  7.46e-02     0s
#    1   1.27989321e-04  1.80739066e+00  9.98e+01 5.12e-02  5.19e-02     0s
#    2   9.08364399e-04  3.60175140e+00  2.95e+01 1.44e-02  1.62e-02     0s
#    3   1.28380410e-04  3.24208889e+00  2.63e+00 2.50e-03  1.61e-03     0s
#    4   8.98390300e-05  2.08783058e+00  6.61e-01 1.08e-03  4.72e-04     0s
#    5   7.30512408e-05  1.66879239e+00  2.12e-01 6.58e-04  2.00e-04     0s
#    6   6.49122466e-05  7.91796817e-01  1.15e-02 1.77e-04  4.84e-05     0s
#    7   7.46158421e-05  7.54810310e-02  2.36e-16 1.23e-05  4.22e-06     0s
#    8   6.54014480e-05  5.79068634e-02  2.78e-16 1.07e-05  3.24e-06     0s
#    9   3.57143021e-04  2.73957208e-02  2.78e-16 3.70e-06  1.51e-06     0s
#   10   5.14306668e-04  1.16488541e-02  2.50e-16 1.43e-06  6.22e-07     0s
#   11   6.92345638e-04  7.38462158e-03  1.11e-16 8.26e-07  3.74e-07     0s
#   12   8.80476402e-04  3.47656852e-03  1.11e-16 2.82e-07  1.45e-07     0s
#   13   9.44970768e-04  2.23620900e-03  1.11e-16 1.26e-07  7.19e-08     0s
#   14   9.96210626e-04  1.80493908e-03  1.25e-16 7.64e-08  4.50e-08     0s
#   15   1.03467711e-03  1.25892966e-03  1.32e-16 2.11e-08  1.25e-08     0s
#   16   1.06120979e-03  1.09135059e-03  4.75e-16 1.04e-10  1.67e-09     0s
#   17   1.07562069e-03  1.08183995e-03  3.77e-14 1.49e-11  3.44e-10     0s
#   18   1.07730967e-03  1.07738271e-03  2.38e-13 9.12e-18  4.03e-12     0s
#   19   1.07731652e-03  1.07731652e-03  3.13e-11 2.66e-17  2.63e-16     0s
#
# Barrier solved model in 19 iterations and 0.40 seconds (0.39 work units)
# Optimal objective 1.07731652e-03
#
# Optimal objective value: 0.0010773165183350544
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2315 rows, 74402 columns and 295071 nonzeros
# Model fingerprint: 0x36a46353
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.09s
# Presolved: 2315 rows, 74402 columns, 295071 nonzeros
# Ordering time: 0.02s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 6.862e+04
#  Factor NZ  : 2.411e+05 (roughly 14 MB of memory)
#  Factor Ops : 7.237e+07 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.17505382e-02  3.57414168e-03  1.45e+02 2.02e-03  9.01e-02     0s
#    1   1.36434307e-04  1.79436090e+00  9.80e+01 5.84e-02  6.21e-02     0s
#    2   2.97011622e-03  3.17371672e+00  3.47e+01 2.92e-02  2.30e-02     0s
#    3   1.78912397e-04  3.81510147e+00  2.34e+00 4.26e-03  1.85e-03     0s
#    4   1.48502496e-04  2.59064835e+00  5.27e-01 2.14e-03  5.25e-04     0s
#    5   1.30032576e-04  2.03659179e+00  1.71e-01 1.54e-03  2.49e-04     0s
#    6   1.23260264e-04  1.41552452e+00  2.25e-02 9.28e-04  1.12e-04     0s
#    7   1.26065748e-04  1.66344177e-01  2.78e-16 8.14e-05  1.16e-05     0s
#    8   2.44758037e-04  4.34086503e-02  1.94e-16 1.89e-05  3.01e-06     0s
#    9   3.76926059e-04  2.16856440e-02  1.94e-16 9.01e-06  1.48e-06     0s
#   10   5.82888364e-04  1.04115825e-02  1.39e-16 4.17e-06  6.83e-07     0s
#   11   6.96258641e-04  6.12982694e-03  2.22e-16 2.03e-06  3.77e-07     0s
#   12   8.07967792e-04  2.89812940e-03  1.67e-16 6.71e-07  1.44e-07     0s
#   13   8.67689415e-04  1.52522936e-03  1.39e-16 1.88e-07  4.53e-08     0s
#   14   9.12304352e-04  9.74439455e-04  2.50e-16 2.97e-09  4.19e-09     0s
#   15   9.30420319e-04  9.43989157e-04  2.03e-15 5.82e-10  9.14e-10     0s
#   16   9.33196620e-04  9.34196703e-04  2.88e-14 2.45e-12  6.70e-11     0s
#   17   9.33346270e-04  9.33425476e-04  7.22e-12 3.82e-14  5.30e-12     0s
#   18   9.33373440e-04  9.33373519e-04  9.65e-11 6.51e-19  5.30e-15     0s
#
# Barrier solved model in 18 iterations and 0.33 seconds (0.32 work units)
# Optimal objective 9.33373440e-04
#
# Optimal objective value: 0.0009333734395684573
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2247 rows, 64677 columns and 256630 nonzeros
# Model fingerprint: 0x376a2d02
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.10s
# Presolved: 2247 rows, 64677 columns, 256630 nonzeros
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 8.882e+04
#  Factor NZ  : 1.886e+05 (roughly 10 MB of memory)
#  Factor Ops : 4.961e+07 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.69902011e-02  2.84540747e-03  1.17e+02 1.33e-03  9.04e-02     0s
#    1   5.51223997e-05  1.03555055e+00  6.81e+01 5.12e-02  5.33e-02     0s
#    2   4.38864477e-03  2.28347710e+00  2.46e+01 1.35e-02  2.02e-02     0s
#    3   9.19564170e-04  1.91452490e+00  2.66e+00 2.81e-03  2.46e-03     0s
#    4   5.62957773e-04  1.50146254e+00  6.46e-01 1.94e-03  7.86e-04     0s
#    5   4.40843045e-04  1.01812405e+00  2.26e-01 1.22e-03  3.66e-04     0s
#    6   3.57302287e-04  5.52435965e-01  8.35e-02 4.50e-04  1.51e-04     0s
#    7   2.92538595e-04  1.56062792e-01  4.02e-04 6.82e-05  2.80e-05     0s
#    8   3.26977054e-04  1.71011243e-02  1.34e-08 7.21e-06  3.00e-06     0s
#    9   4.73876950e-04  1.09446083e-02  6.66e-09 4.37e-06  1.87e-06     0s
#   10   6.52080323e-04  5.83804437e-03  3.80e-09 2.02e-06  9.26e-07     0s
#   11   7.75926863e-04  3.06156767e-03  2.24e-09 8.18e-07  4.08e-07     0s
#   12   8.99300224e-04  2.28496518e-03  9.05e-10 4.83e-07  2.47e-07     0s
#   13   9.58855476e-04  1.81983770e-03  5.44e-10 2.73e-07  1.53e-07     0s
#   14   1.00943105e-03  1.17454210e-03  2.37e-10 3.47e-08  2.93e-08     0s
#   15   1.01518965e-03  1.16695625e-03  2.06e-10 3.22e-08  2.69e-08     0s
#   16   1.02945304e-03  1.13808623e-03  1.17e-10 2.37e-08  1.93e-08     0s
#   17   1.04345406e-03  1.09584047e-03  3.38e-11 1.61e-08  9.30e-09     0s
#   18   1.04985892e-03  1.05225189e-03  9.56e-15 4.22e-10  4.25e-10     0s
#   19   1.05006697e-03  1.05006752e-03  1.48e-15 1.01e-13  9.85e-14     0s
#
# Barrier solved model in 19 iterations and 0.28 seconds (0.24 work units)
# Optimal objective 1.05006697e-03
#
# Optimal objective value: 0.001050066967571179
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2399 rows, 84880 columns and 336453 nonzeros
# Model fingerprint: 0xf2425936
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.13s
# Presolved: 2399 rows, 84880 columns, 336453 nonzeros
# Ordering time: 0.03s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 7.876e+04
#  Factor NZ  : 2.697e+05 (roughly 16 MB of memory)
#  Factor Ops : 8.491e+07 (less than 1 second per iteration)
#  Threads    : 32
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.15717963e-02  3.42834262e-03  1.61e+02 1.01e-03  9.00e-02     0s
#    1   1.04819448e-04  2.19387900e+00  9.60e+01 5.69e-02  5.46e-02     0s
#    2   1.19459920e-02  4.63608382e+00  3.81e+01 2.05e-02  2.26e-02     0s
#    3   1.40183614e-03  4.61690652e+00  3.91e+00 3.54e-03  2.55e-03     0s
#    4   7.63372662e-04  3.14939076e+00  8.14e-01 1.29e-03  6.49e-04     0s
#    5   5.04160205e-04  2.44936595e+00  2.38e-01 7.98e-04  2.75e-04     0s
#    6   3.35579469e-04  1.18864962e+00  4.30e-16 3.42e-04  7.12e-05     0s
#    7   3.42885223e-04  2.14075905e-02  2.50e-16 6.05e-06  1.26e-06     0s
#    8   4.54103111e-04  1.05341628e-02  2.22e-16 2.46e-06  6.03e-07     0s
#    9   6.19795004e-04  5.78404898e-03  1.94e-16 1.07e-06  3.09e-07     0s
#   10   7.53258158e-04  4.09712090e-03  2.08e-16 6.40e-07  2.00e-07     0s
#   11   8.35624295e-04  2.42167845e-03  1.80e-16 2.49e-07  9.45e-08     0s
#   12   9.32519074e-04  1.31159122e-03  2.78e-16 3.03e-08  2.24e-08     0s
#   13   9.60006717e-04  1.02203589e-03  4.65e-16 2.36e-09  3.65e-09     0s
#   14   9.69170073e-04  9.71906682e-04  2.19e-14 3.42e-12  1.60e-10     0s
#   15   9.70041673e-04  9.70042251e-04  8.31e-14 0.00e+00  3.39e-14     0s
#
# Barrier solved model in 15 iterations and 0.38 seconds (0.35 work units)
# Optimal objective 9.70041673e-04
#
# Optimal objective value: 0.0009700416727676173
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 616 rows, 2041 columns and 7555 nonzeros
# Model fingerprint: 0x11e5f591
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 28 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 588 rows, 2041 columns, 7527 nonzeros
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.542e+03
#  Factor NZ  : 7.453e+03
#  Factor Ops : 4.311e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.62239647e-02  1.53117322e-03  9.97e+01 8.19e-03  3.78e-01     0s
#    1   9.53564169e-06  4.41838382e-01  5.28e+01 2.22e-16  1.93e-01     0s
#    2   3.01993128e-06  3.48899073e-01  3.01e+00 5.55e-17  1.79e-02     0s
#    3   2.48978322e-06  1.09940186e-01  1.51e-01 8.33e-17  3.12e-03     0s
#    4   2.97868225e-06  1.37536006e-02  9.22e-04 9.71e-17  3.07e-04     0s
#    5   2.17489406e-05  5.33379515e-03  4.47e-05 1.21e-16  1.18e-04     0s
#    6   2.88119934e-04  3.19366405e-03  8.76e-08 5.55e-17  6.47e-05     0s
#    7   5.22614826e-04  1.63586551e-03  2.39e-08 1.91e-17  2.48e-05     0s
#    8   6.32933878e-04  1.16360233e-03  1.33e-08 1.86e-17  1.18e-05     0s
#    9   6.84597347e-04  7.84045104e-04  1.89e-09 1.30e-18  2.21e-06     0s
#   10   6.88544089e-04  6.88652672e-04  4.44e-16 1.41e-18  2.42e-09     0s
#   11   6.88556861e-04  6.88556969e-04  4.44e-16 8.67e-19  2.42e-12     0s
#
# Barrier solved model in 11 iterations and 0.03 seconds (0.01 work units)
# Optimal objective 6.88556861e-04
#
# Optimal objective value: 0.0006885568605358979
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 614 rows, 2609 columns and 10084 nonzeros
# Model fingerprint: 0xf26efaee
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 20 rows and 20 columns
# Presolve time: 0.04s
# Presolved: 594 rows, 2589 columns, 10044 nonzeros
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.283e+03
#  Factor NZ  : 2.121e+03
#  Factor Ops : 5.805e+04 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.76969043e-02  2.55080953e-03  1.01e+02 2.77e-03  6.94e-01     0s
#    1   4.87041242e-05  3.39629892e-01  4.93e+01 5.55e-17  2.81e-01     0s
#    2   1.02271145e-05  2.63797842e-01  7.21e-01 5.55e-17  1.31e-02     0s
#    3   7.45431730e-06  1.68243235e-02  2.22e-16 3.73e-17  6.20e-04     0s
#    4   2.35428728e-04  6.26950322e-03  2.78e-17 6.25e-17  2.22e-04     0s
#    5   7.62831773e-04  1.66244592e-03  3.33e-16 1.32e-17  3.32e-05     0s
#    6   7.95505170e-04  8.96944681e-04  4.44e-16 5.96e-19  3.74e-06     0s
#    7   8.13426567e-04  8.24708198e-04  8.88e-16 5.42e-19  4.16e-07     0s
#    8   8.13355130e-04  8.17681453e-04  6.66e-16 1.20e-17  1.59e-07     0s
#    9   8.15628889e-04  8.15690910e-04  4.44e-16 8.30e-20  2.29e-09     0s
#   10   8.15635730e-04  8.15635792e-04  4.44e-16 6.36e-18  2.29e-12     0s
#
# Barrier solved model in 10 iterations and 0.05 seconds (0.01 work units)
# Optimal objective 8.15635730e-04
#
# Optimal objective value: 0.000815635730125254
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 1401 rows, 15645 columns and 61984 nonzeros
# Model fingerprint: 0x0f5ea6f3
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.03s
# Presolved: 1401 rows, 15645 columns, 61984 nonzeros
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 9.382e+03
#  Factor NZ  : 1.666e+04 (roughly 1 MB of memory)
#  Factor Ops : 1.400e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.85325095e-02  1.36720721e-03  4.60e+02 2.37e-03  6.02e-01     0s
#    1   2.40499597e-04  1.27708596e+00  2.47e+02 3.63e-03  3.20e-01     0s
#    2   4.48820458e-05  9.87407226e-01  1.18e+01 1.35e-04  1.76e-02     0s
#    3   1.39152473e-05  3.96118525e-01  7.30e-01 0.00e+00  1.92e-03     0s
#    4   1.60499618e-05  1.74517899e-01  5.63e-02 0.00e+00  5.11e-04     0s
#    5   3.67092838e-05  6.18092150e-02  1.11e-04 0.00e+00  1.59e-04     0s
#    6   6.14158109e-08  8.29545412e-03  2.17e-06 0.00e+00  2.14e-05     0s
#    7   2.45200892e-06  5.94974162e-03  3.63e-08 0.00e+00  1.53e-05     0s
#    8   3.01633783e-04  4.81040765e-03  1.15e-10 0.00e+00  1.16e-05     0s
#    9   5.35322622e-04  1.88618137e-03  1.12e-12 0.00e+00  3.48e-06     0s
#   10   7.24901444e-04  1.42142640e-03  3.18e-13 0.00e+00  1.79e-06     0s
#   11   7.92632843e-04  1.15837469e-03  1.59e-13 0.00e+00  9.41e-07     0s
#   12   8.31607877e-04  9.73976404e-04  7.50e-14 0.00e+00  3.66e-07     0s
#   13   8.53933178e-04  9.03347878e-04  1.38e-14 0.00e+00  1.27e-07     0s
#   14   8.56023220e-04  8.56178979e-04  2.41e-15 0.00e+00  4.01e-10     0s
#   15   8.56106967e-04  8.56106969e-04  7.22e-16 0.00e+00  4.28e-15     0s
#
# Barrier solved model in 15 iterations and 0.06 seconds (0.05 work units)
# Optimal objective 8.56106967e-04
#
# Optimal objective value: 0.000856106967315667
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 2020 rows, 23075 columns and 91361 nonzeros
# Model fingerprint: 0x900d9e08
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.03s
# Presolved: 2020 rows, 23075 columns, 91361 nonzeros
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.117e+04
#  Factor NZ  : 2.060e+04 (roughly 1 MB of memory)
#  Factor Ops : 2.061e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.89366305e-02  2.41270214e-03  3.96e+02 2.24e-03  4.66e-01     0s
#    1   1.72199947e-04  1.07872938e+00  2.13e+02 6.91e-03  2.47e-01     0s
#    2   1.42157452e-05  9.74484824e-01  1.13e+01 4.89e-04  1.54e-02     0s
#    3   7.87096986e-06  4.84356078e-01  7.93e-01 5.91e-06  2.05e-03     0s
#    4   8.71046160e-06  1.67448212e-01  1.77e-01 0.00e+00  6.12e-04     0s
#    5   3.89440921e-05  6.44830073e-02  3.56e-04 0.00e+00  1.62e-04     0s
#    6   1.31969585e-04  2.47531733e-02  1.67e-16 0.00e+00  6.17e-05     0s
#    7   3.78372889e-04  1.13652504e-02  1.39e-16 0.00e+00  2.75e-05     0s
#    8   5.52333545e-04  6.42313329e-03  1.11e-16 0.00e+00  1.47e-05     0s
#    9   7.30961501e-04  3.69017844e-03  9.71e-17 0.00e+00  7.41e-06     0s
#   10   8.03650198e-04  2.19887354e-03  1.11e-16 0.00e+00  3.49e-06     0s
#   11   8.73728235e-04  1.74783204e-03  9.71e-17 0.00e+00  2.19e-06     0s
#   12   9.32676190e-04  1.51450810e-03  1.39e-16 0.00e+00  1.46e-06     0s
#   13   9.59645306e-04  1.01947374e-03  2.50e-16 0.00e+00  1.50e-07     0s
#   14   9.61507711e-04  9.61598430e-04  3.05e-16 1.03e-17  2.27e-10     0s
#   15   9.61528189e-04  9.61528189e-04  2.53e-15 9.74e-19  2.78e-16     0s
#
# Barrier solved model in 15 iterations and 0.07 seconds (0.06 work units)
# Optimal objective 9.61528189e-04
#
# Optimal objective value: 0.000961528188778961
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: AMD EPYC 7552 48-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 96 physical cores, 192 logical processors, using up to 32 threads
#
# Academic license 2527766 - for non-commercial use only - registered to sa___@princeton.edu
# Optimize a model with 901 rows, 2519 columns and 9410 nonzeros
# Model fingerprint: 0x057c2efe
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.02s
# Presolved: 901 rows, 2519 columns, 9410 nonzeros
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.802e+03
#  Factor NZ  : 9.211e+03
#  Factor Ops : 4.921e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.92753526e-02  1.53543591e-03  6.24e+01 1.82e-03  3.62e-01     0s
#    1   1.26135334e-04  9.96710308e-01  3.33e+01 9.68e-03  1.78e-01     0s
#    2   4.27639175e-05  9.57208237e-01  2.00e+00 1.63e-04  1.91e-02     0s
#    3   2.21911359e-05  3.26944252e-01  7.13e-01 0.00e+00  5.56e-03     0s
#    4   1.08826236e-05  6.28672763e-02  7.77e-16 0.00e+00  6.36e-04     0s
#    5   2.24322526e-05  1.31626977e-02  2.22e-16 0.00e+00  1.33e-04     0s
#    6   1.89838048e-04  1.09125738e-02  4.44e-16 0.00e+00  1.08e-04     0s
#    7   3.99426049e-04  5.08403882e-03  2.22e-16 0.00e+00  4.74e-05     0s
#    8   5.62505099e-04  2.53211515e-03  2.22e-16 0.00e+00  1.99e-05     0s
#    9   6.78821179e-04  1.36386749e-03  2.22e-16 0.00e+00  6.93e-06     0s
#   10   8.09901563e-04  1.04948652e-03  5.55e-16 0.00e+00  2.42e-06     0s
#   11   8.45069394e-04  9.69240924e-04  4.44e-16 0.00e+00  1.26e-06     0s
#   12   8.64477678e-04  8.69674720e-04  2.92e-14 0.00e+00  5.26e-08     0s
#   13   8.65089836e-04  8.65095034e-04  9.66e-15 8.67e-19  5.26e-11     0s
#
# Barrier solved model in 13 iterations and 0.03 seconds (0.01 work units)
# Optimal objective 8.65089836e-04
#
# Optimal objective value: 0.0008650898358749184
