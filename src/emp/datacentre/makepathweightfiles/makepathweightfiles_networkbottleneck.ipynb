# %% [markdown]
# solve
# inspired by https://github.com/AnnZhouCcc/topobench/blob/master/lpmaker/graphs/Graph.java#L1382

# %%
# set parameters
graphname = "dring"
numsw = 80
numport = 64
numserver = 2988
numfaillink = 0
numlink = 2132
fseed = 0
homedir = "/home/annzhou"

method = 2
crossover = 0
factor = 64


clist = [64,48,32,16,4]
# s=4
multlist = [[0,45,100],[0,80,100],[1,80,100],[7,20,100],[115,20,100]]
tseedlist = range(5)


for ic,c in enumerate(clist):
    s=c
    mult = multlist[ic][0]
    numerator = multlist[ic][1]
    denominator = multlist[ic][2]
    multstr = f"{mult}_{numerator}_{denominator}"
    for tseed in tseedlist:
        trafficname = f"c2s_{c}_{s}_{tseed}_{multstr}"
        flowfile = f"{homedir}/DRing/src/emp/datacentre/flowfiles/c2s_{c}_{s}_{multstr}_{tseed}"

        routingdict = dict()
        with open(f"{homedir}/DRing/src/emp/datacentre/experiments/networkbottleneck/whatrouting.txt",'r') as f:
            lines = f.readlines()
            for line in lines:
                tokens = line.split(',')
                if tokens[0]==flowfile:
                    routingdict[tokens[1]] = float(tokens[2])
        if max(routingdict.values()) == routingdict["ecmp"]:
            routingname = "ecmp"
        elif max(routingdict.values()) == routingdict["su2"]:
            routingname = "su2"
        elif max(routingdict.values()) == routingdict["su3"]:
            routingname = "su3"

        if graphname=="dring" or graphname=="rrg":
            netpathfile = f"{homedir}/DRing/src/emp/datacentre/netpathfiles/netpath_{routingname}_{graphname}.txt"
        else:
            print("ERROR: leafspine does not need to compute path weight")

        if graphname=="dring":
            graphfile = f"{homedir}/DRing/src/emp/datacentre/graphfiles/ring_supergraph/double_ring/instance1_{numsw}_{numport}.edgelist"
        elif graphname=="rrg":
            graphfile = f"{homedir}/DRing/src/emp/datacentre/graphfiles/ring_supergraph/rrg/instance1_{numsw}_{numport}.edgelist"
        else:
            print("ERROR: leafspine does not need to compute path weight")

        linkfailurefile = f"{homedir}/DRing/src/emp/datacentre/linkfailurefiles/{graphname}_{numlink}_{numfaillink}_{fseed}"

        serverfile = f"{homedir}/DRing/src/emp/datacentre/serverfiles/{graphname}_{numserver}_{numsw}_{numport}"

        tag = f"{graphname}_{numfaillink}_{fseed}_{routingname}_{trafficname}_{method}_{crossover}_{factor}"
        varfile = f"{homedir}/DRing/src/emp/datacentre/qvarfiles/var_{tag}"
        qvarfile = f"{homedir}/DRing/src/emp/datacentre/qvarfiles/qvar_{tag}"
        modelfile = f"{homedir}/DRing/src/emp/datacentre/makepathweightfiles/model.lp"


        # read netpathfile
        netpath = list()
        for i in range(numsw):
            netpath.append(list())
            for j in range(numsw):
                netpath[i].append(list())
        with open(netpathfile,'r') as f:
            lines = f.readlines()
            # produce
            fromsw = 0
            tosw = 0
            for line in lines:
                if "->" not in line:
                    tokens = line.split()
                    fromsw = int(tokens[0])
                    tosw = int(tokens[1])
                else:
                    path = [fromsw]
                    tokens = line.split()
                    for token in tokens:
                        hops = token.split("->")
                        path.append(int(hops[1]))
                    netpath[fromsw][tosw].append(path)

            # check
            for line in lines:
                if "->" not in line:
                    tokens = line.split()
                    fromsw = int(tokens[0])
                    tosw = int(tokens[1])
                    numpaths = int(tokens[2])
                    if len(netpath[fromsw][tosw])!=numpaths:
                        print(f"ERROR: netpath is wrong, fromsw={fromsw}, tosw={tosw}, numpaths from file={numpaths}, numpaths from array={len(netpath[fromsw][tosw])}")

        # read graphfile
        link = list()
        for i in range(numsw):
            link.append(list())
            for j in range(numsw):
                link[i].append(0)
        with open(graphfile,'r') as f:
            lines = f.readlines()
            for line in lines:
                tokens = line.split("->")
                fromsw = int(tokens[0])
                tosw = int(tokens[1])
                link[fromsw][tosw] = 1
                link[tosw][fromsw] = 1

        # read linkfailurefile (if needed)
        if numfaillink > 0:
            with open(linkfailurefile,'r') as f:
                lines = f.readlines()
                for line in lines:
                    tokens = line.split()
                    fromsw = int(tokens[0])
                    tosw = int(tokens[1])
                    if link[fromsw][tosw] != 1:
                        print(f"ERROR: should have a link from {fromsw} to {tosw} but not")
                    else:
                        link[fromsw][tosw] /= 2

        # read serverfile
        serverdict = dict()
        with open(serverfile,'r') as f:
            lines = f.readlines()
            for line in lines:
                tokens = line.split(',')
                serverdict[int(tokens[0])] = int(tokens[1])

        # read flowfile
        traffic = list()
        for i in range(numsw):
            traffic.append(list())
            for j in range(numsw):
                traffic[i].append(0)
        with open(flowfile,'r') as f:
            lines = f.readlines()
            for line in lines:
                tokens = line.split(",")
                fromsvr = int(tokens[0])
                tosvr = int(tokens[1])
                if fromsvr>=numserver or tosvr>=numserver: continue
                fromsw = serverdict[fromsvr]
                tosw = serverdict[tosvr]
                if fromsw == tosw: continue
                flowbytes = int(tokens[2])
                traffic[fromsw][tosw] += flowbytes


        # precompute
        flowsvialink = list()
        for i in range(numsw):
            flowsvialink.append(list())
            for j in range(numsw):
                flowsvialink[i].append(list())
        for fromsw in range(numsw):
            for tosw in range(numsw):
                if traffic[fromsw][tosw] > 0:
                    for pid,path in enumerate(netpath[fromsw][tosw]):
                        fidpidstr = f"{fromsw},{tosw},{pid}"
                        prevhop = fromsw
                        for hop in path[1:]:
                            flowsvialink[prevhop][hop].append(fidpidstr)
                            prevhop = hop

        for fromsw in range(numsw):
            for tosw in range(numsw):
                traffic[fromsw][tosw] /= 100000


        import gurobipy as gp
        from gurobipy import GRB

        # Create a new model
        model = gp.Model("mcf")

        # Add variables
        maxpid = 0
        for fromsw in range(numsw):
            for tosw in range(numsw):
                maxpid = max(maxpid,len(netpath[fromsw][tosw]))
        vararr = list()
        for fromsw in range(numsw):
            vararr.append(list())
            for tosw in range(numsw):
                vararr[fromsw].append(list())
                for pid in range(maxpid):
                    vararr[fromsw][tosw].append(None)
        for fromsw in range(numsw):
            for tosw in range(numsw):
                if traffic[fromsw][tosw] > 0:
                    for pid in range(len(netpath[fromsw][tosw])):
                        var = model.addVar(name=f"{fromsw}_{tosw}_{pid}")
                        vararr[fromsw][tosw][pid] = var
        k = model.addVar(name="k")

        # Set objective function
        model.setObjective(k, GRB.MAXIMIZE)

        # Add constraints
        # Constraint 0: for each fid: sum(pid) >= k * traffic[fid.from][fid.to]
        for fromsw in range(numsw):
            for tosw in range(numsw):
                if traffic[fromsw][tosw] > 0:
                    varlist = list()
                    for pid in range(len(netpath[fromsw][tosw])):
                        varlist.append(vararr[fromsw][tosw][pid])
                    model.addConstr(sum(varlist)>=k*traffic[fromsw][tosw],f"c0_{fromsw}_{tosw}")

        # Constraint 1: for each link: sum(fid_pid) <= link[link.from][link.to]
        for linkfrom in range(numsw):
            for linkto in range(numsw):
                flowstrlist = flowsvialink[linkfrom][linkto]
                if len(flowstrlist) > 0:
                    varlist = list()
                    for flowstr in flowstrlist:
                        tokens = flowstr.split(',')
                        flowfrom = int(tokens[0])
                        flowto = int(tokens[1])
                        pid = int(tokens[2])
                        varlist.append(vararr[flowfrom][flowto][pid])
                    model.addConstr(sum(varlist)<=link[linkfrom][linkto],f"c1_{linkfrom}_{linkto}")

        # Optimize model
        model.setParam('Method',method)
        model.setParam('Crossover',crossover)
        model.optimize()
        # model.write(modelfile)

        # Print results
        if model.status == GRB.OPTIMAL:
            print(f"Optimal objective value: {model.objVal}")
            with open(varfile,'w') as f:
                f.write(f"{k.varName},{k.x}\n")
                for fromsw in range(numsw):
                    for tosw in range(numsw):
                        if traffic[fromsw][tosw] > 0:
                            for pid in range(len(netpath[fromsw][tosw])):
                                var = vararr[fromsw][tosw][pid]
                                f.write(f"{var.varName},{var.x}\n")
        else:
            print("No optimal solution found")


        import random
        random.seed(0)

        def quantize_to_multiple_of_1_64(x,factor):
            return round(x * factor) / factor

        def quantize_and_adjust_with_indices(indexed_values,factor,isprint=False):
            if isprint: print(indexed_values)
            # Quantize each value
            quantized_values = [(i, quantize_to_multiple_of_1_64(v,factor)) for i, v in indexed_values]
            if isprint: print(quantized_values)
            
            # Calculate the current sum
            current_sum = sum(v for _, v in quantized_values)
            
            # Calculate the difference between the sum and 1
            difference = current_sum - 1
            if isprint: print(f"currsum={current_sum}, difference={difference}")

            random_values = [(v, random.random()) for v in quantized_values]
            if isprint: print(random_values)
            
            if difference != 0:
                if difference > 0:
                    # Sort indices by quantized values to adjust the largest values first
                    sorted_random = sorted(random_values, key=lambda x: (x[0][1],x[1]), reverse=True)
                    # sorted_quantized = sorted(quantized_values, key=lambda x: x[1], reverse=True)
                    sorted_quantized = [v for v,_ in sorted_random]
                    if isprint: print(sorted_random)
                    if isprint: print(sorted_quantized)
                    
                    while difference !=0:
                        for i, value in sorted_quantized:
                            if difference == 0:
                                break
                            # Calculate adjustment
                            # adjustment = min(difference, value % (1 / factor))
                            # adjustment = difference
                            new_value = value - 1.0/factor
                            
                            # Update the quantized values
                            quantized_values = [(idx, new_value if idx == i else v) for idx, v in quantized_values]
                            difference -= 1.0/factor
                        
                else:
                    # If the difference is negative (i.e., sum is less than 1), we need to increase values
                    # sorted_quantized = sorted(quantized_values, key=lambda x: x[1])
                    sorted_random = sorted(random_values, key=lambda x: (x[0][1],x[1]))
                    # sorted_quantized = sorted(quantized_values, key=lambda x: x[1], reverse=True)
                    sorted_quantized = [v for v,_ in sorted_random]
                    
                    while difference != 0:
                        for i, value in sorted_quantized:
                            if difference == 0:
                                break
                            # Calculate adjustment
                            # adjustment = min(-difference, (1 / factor) - (value % (1 / factor)))
                            # adjustment = -difference
                            new_value = value + 1.0/factor
                            
                            # Update the quantized values
                            quantized_values = [(idx, new_value if idx == i else v) for idx, v in quantized_values]
                            difference += 1.0/factor
            
            # Return the list sorted by original indices
            # return [v for i, v in sorted(quantized_values)]
            if isprint: print(quantized_values)
            return quantized_values


        with open(varfile,'r') as f:
            lines = f.readlines()[1:]

        valuearr = list()
        weightarr = list()
        qweightarr = list()
        for i in range(numsw):
            valuearr.append(list())
            weightarr.append(list())
            qweightarr.append(list())
            for j in range(numsw):
                valuearr[i].append(list())
                weightarr[i].append(list())
                qweightarr[i].append(list()) 

        for line in lines:
            tokens = line.split(',')
            varname = tokens[0]
            vartokens = varname.split('_')
            fromsw = int(vartokens[0])
            tosw = int(vartokens[1])
            pid = int(vartokens[2])
            value = float(tokens[1])
            valuearr[fromsw][tosw].append([pid,value])
            weightarr[fromsw][tosw].append([pid,value])

        for fromsw in range(numsw):
            for tosw in range(numsw):
                if len(valuearr[fromsw][tosw])>0:
                    valuesum = 0
                    for _,value in valuearr[fromsw][tosw]:
                        valuesum += value
                    valuetoweight = 1.0/valuesum
                    for ipv,pv in enumerate(weightarr[fromsw][tosw]):
                        weightarr[fromsw][tosw][ipv][1] = pv[1] * valuetoweight

        for fromsw in range(numsw):
            for tosw in range(numsw):
                if len(weightarr[fromsw][tosw])>0:
                    qweightarr[fromsw][tosw] = quantize_and_adjust_with_indices(weightarr[fromsw][tosw],factor)

        with open(qvarfile,'w') as f:
            for fromsw in range(numsw):
                for tosw in range(numsw):
                    if len(qweightarr[fromsw][tosw])>0:
                        for pid,weight in qweightarr[fromsw][tosw]:
                            if weight>0:
                                f.write(f"{fromsw},{tosw},{pid},{weight}\n")


        # check qvarfile
        checkweightarr = list()
        for i in range(numsw):
            checkweightarr.append(list())
            for j in range(numsw):
                checkweightarr[i].append(0)
        with open(qvarfile,'r') as f:
            lines = f.readlines()
            for line in lines:
                tokens = line.split(',')
                fromsw = int(tokens[0])
                tosw = int(tokens[1])
                pid = int(tokens[2])
                weight = float(tokens[3])
                checkweightarr[fromsw][tosw] += weight

        for fromsw in range(numsw):
            for tosw in range(numsw):
                if checkweightarr[fromsw][tosw]!=0 and checkweightarr[fromsw][tosw]!=1:
                    print(f"from {fromsw} to {tosw}: weight={checkweightarr[fromsw][tosw]}")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-01-09
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 8452 rows, 244997 columns and 927336 nonzeros
# Model fingerprint: 0x5f935ef1
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.56s
# Presolved: 8452 rows, 244997 columns, 927336 nonzeros
# Ordering time: 1.03s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 5.915e+05
#  Factor NZ  : 2.348e+06 (roughly 120 MB of memory)
#  Factor Ops : 2.382e+09 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7.49237579e-03  6.51262500e-04  1.06e+02 1.87e-05  2.21e-02     2s
#    1   4.66486378e-05  2.84461319e+01  5.55e+01 2.56e-02  1.15e-02     2s
#    2   4.48083239e-03  3.68112314e+01  5.29e+01 4.07e-03  1.07e-02     2s
#    3   1.06863191e-03  3.49154562e+01  1.08e+01 2.26e-04  2.28e-03     2s
#    4   1.69601911e-04  2.37250843e+01  1.11e+00 0.00e+00  3.58e-04     2s
#    5   1.35325018e-05  1.69018276e+01  7.04e-04 0.00e+00  1.35e-04     2s
#    6   1.35393278e-05  1.52103263e-02  6.44e-15 0.00e+00  1.21e-07     3s
#    7   6.69544327e-05  6.06052146e-03  6.44e-15 0.00e+00  4.77e-08     3s
#    8   1.16916587e-04  3.05916112e-03  3.77e-15 0.00e+00  2.34e-08     3s
#    9   2.16051476e-04  2.28717792e-03  2.89e-15 0.00e+00  1.65e-08     3s
#   10   3.52660609e-04  1.88827285e-03  2.78e-15 0.00e+00  1.22e-08     3s
#   11   4.52922156e-04  1.33125697e-03  3.77e-15 0.00e+00  6.99e-09     3s
#   12   5.97707130e-04  1.10445046e-03  2.89e-15 0.00e+00  4.03e-09     3s
#   13   6.14443641e-04  8.96291246e-04  1.13e-14 0.00e+00  2.24e-09     3s
#   14   6.45672683e-04  7.86175547e-04  1.42e-14 0.00e+00  1.12e-09     4s
#   15   6.71449881e-04  7.53619224e-04  6.87e-13 0.00e+00  6.54e-10     4s
#   16   6.91724994e-04  7.30070593e-04  1.42e-12 0.00e+00  3.05e-10     4s
#   17   7.12065763e-04  7.18610834e-04  4.00e-12 0.00e+00  5.21e-11     4s
#   18   7.14273476e-04  7.14910623e-04  4.39e-11 0.00e+00  5.07e-12     4s
#   19   7.14443811e-04  7.14447281e-04  1.31e-10 9.05e-17  2.76e-14     4s
#
# Barrier solved model in 19 iterations and 4.08 seconds (3.21 work units)
# Optimal objective 7.14443811e-04
#
# Optimal objective value: 0.0007144438113332138
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 8452 rows, 244997 columns and 927336 nonzeros
# Model fingerprint: 0x310a4d6b
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.56s
# Presolved: 8452 rows, 244997 columns, 927336 nonzeros
# Ordering time: 1.06s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 5.915e+05
#  Factor NZ  : 2.348e+06 (roughly 120 MB of memory)
#  Factor Ops : 2.382e+09 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7.58540914e-03  6.41869984e-04  1.08e+02 1.87e-05  2.24e-02     2s
#    1   2.94291879e-05  3.00838171e+01  5.62e+01 2.30e-02  1.15e-02     2s
#    2   5.65520758e-03  4.14285204e+01  5.40e+01 0.00e+00  1.10e-02     2s
#    3   1.32085111e-03  3.61003679e+01  9.52e+00 0.00e+00  2.07e-03     2s
#    4   1.44079904e-04  2.72023291e+01  6.11e-01 0.00e+00  3.17e-04     2s
#    5   6.42528034e-05  1.76441512e+01  3.10e-04 0.00e+00  1.40e-04     2s
#    6   6.42568798e-05  4.63793495e-03  1.44e-14 0.00e+00  3.64e-08     3s
#    7   1.52745084e-04  2.53615139e-03  7.55e-15 0.00e+00  1.90e-08     3s
#    8   3.49381298e-04  2.04515679e-03  5.22e-15 0.00e+00  1.35e-08     3s
#    9   4.47080958e-04  1.29094415e-03  4.55e-15 0.00e+00  6.72e-09     3s
#   10   5.47698584e-04  1.18570553e-03  4.00e-15 0.00e+00  5.08e-09     3s
#   11   6.13536135e-04  9.90509746e-04  4.22e-15 0.00e+00  3.00e-09     3s
#   12   6.54738529e-04  8.00123696e-04  1.20e-14 0.00e+00  1.16e-09     3s
#   13   6.75571755e-04  7.47840439e-04  7.95e-14 0.00e+00  5.75e-10     3s
#   14   6.92378349e-04  7.22820230e-04  3.32e-13 0.00e+00  2.42e-10     3s
#   15   7.10855144e-04  7.16597784e-04  2.32e-12 0.00e+00  4.57e-11     3s
#   16   7.14710377e-04  7.15247484e-04  2.40e-11 8.76e-17  4.27e-12     3s
#   17   7.14913830e-04  7.14969964e-04  3.32e-10 3.39e-21  4.47e-13     4s
#   18   7.14923229e-04  7.14923641e-04  3.32e-10 1.48e-16  3.28e-15     4s
#
# Barrier solved model in 18 iterations and 3.61 seconds (3.15 work units)
# Optimal objective 7.14923229e-04
#
# Optimal objective value: 0.0007149232291294683
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 8452 rows, 244997 columns and 927336 nonzeros
# Model fingerprint: 0x2c7adac5
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.53s
# Presolved: 8452 rows, 244997 columns, 927336 nonzeros
# Ordering time: 1.02s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 5.915e+05
#  Factor NZ  : 2.348e+06 (roughly 120 MB of memory)
#  Factor Ops : 2.382e+09 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7.49063736e-03  6.48488396e-04  1.06e+02 1.89e-05  2.21e-02     2s
#    1   2.89398304e-05  3.15316126e+01  5.54e+01 2.04e-02  1.13e-02     2s
#    2   5.72568928e-03  6.55592598e+01  5.34e+01 0.00e+00  1.28e-02     2s
#    3   2.31730584e-03  5.51108464e+01  1.87e+01 0.00e+00  4.48e-03     2s
#    4   7.20528505e-04  4.34126392e+01  2.99e+00 0.00e+00  9.40e-04     2s
#    5   3.95814362e-04  2.59748938e+01  2.77e-01 0.00e+00  2.48e-04     2s
#    6   3.29427279e-04  6.05093284e+00  5.77e-15 0.00e+00  4.82e-05     2s
#    7   3.29642715e-04  6.38026875e-03  4.44e-15 1.21e-17  4.82e-08     3s
#    8   4.57895526e-04  1.89698151e-03  5.22e-15 2.83e-18  1.15e-08     3s
#    9   5.01840840e-04  1.43545375e-03  4.33e-15 1.70e-18  7.43e-09     3s
#   10   6.07709700e-04  9.41326877e-04  4.12e-13 4.19e-19  2.65e-09     3s
#   11   6.86028547e-04  8.02421952e-04  1.23e-13 1.42e-19  9.26e-10     3s
#   12   6.99476921e-04  7.64898896e-04  2.05e-13 7.69e-20  5.21e-10     3s
#   13   7.09659525e-04  7.23688453e-04  1.27e-12 1.15e-20  1.12e-10     3s
#   14   7.12493536e-04  7.13434631e-04  1.12e-11 1.82e-16  7.49e-12     3s
#   15   7.12703192e-04  7.12704454e-04  3.23e-11 3.39e-21  1.00e-14     3s
#
# Barrier solved model in 15 iterations and 3.28 seconds (2.98 work units)
# Optimal objective 7.12703192e-04
#
# Optimal objective value: 0.0007127031920810665
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 8452 rows, 244997 columns and 927336 nonzeros
# Model fingerprint: 0xfcb7fcb5
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.54s
# Presolved: 8452 rows, 244997 columns, 927336 nonzeros
# Ordering time: 1.00s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 5.915e+05
#  Factor NZ  : 2.348e+06 (roughly 120 MB of memory)
#  Factor Ops : 2.382e+09 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7.50381628e-03  6.47658835e-04  1.07e+02 1.87e-05  2.21e-02     2s
#    1   4.04826052e-05  2.86364238e+01  5.55e+01 2.68e-02  1.15e-02     2s
#    2   4.53641029e-03  3.78062385e+01  5.33e+01 3.07e-03  1.08e-02     2s
#    3   1.19493011e-03  3.54085131e+01  1.16e+01 0.00e+00  2.45e-03     2s
#    4   2.23249354e-04  2.57491193e+01  1.39e+00 0.00e+00  4.26e-04     2s
#    5   7.84469423e-05  1.78927599e+01  3.03e-01 0.00e+00  1.78e-04     2s
#    6   4.77554149e-05  9.04034081e+00  3.07e-04 0.00e+00  7.20e-05     2s
#    7   4.77831332e-05  5.32303541e-03  5.11e-15 0.00e+00  4.20e-08     3s
#    8   1.22413907e-04  2.88283147e-03  4.66e-15 0.00e+00  2.20e-08     3s
#    9   2.62036067e-04  2.39757931e-03  2.66e-15 0.00e+00  1.70e-08     3s
#   10   3.46831345e-04  1.98866229e-03  2.66e-15 0.00e+00  1.31e-08     3s
#   11   3.77172904e-04  1.80593417e-03  2.89e-15 0.00e+00  1.14e-08     3s
#   12   5.15207482e-04  1.17879724e-03  3.55e-15 0.00e+00  5.28e-09     3s
#   13   5.99774299e-04  1.00118871e-03  5.77e-15 0.00e+00  3.19e-09     3s
#   14   6.18393562e-04  8.52404769e-04  2.43e-14 0.00e+00  1.86e-09     3s
#   15   6.36959262e-04  8.07884525e-04  7.19e-14 0.00e+00  1.36e-09     3s
#   16   6.44618976e-04  7.86947236e-04  9.97e-14 0.00e+00  1.13e-09     4s
#   17   6.68877355e-04  7.56931675e-04  4.86e-13 0.00e+00  7.01e-10     4s
#   18   6.73655040e-04  7.48402922e-04  4.79e-13 0.00e+00  5.95e-10     4s
#   19   7.03902085e-04  7.32727247e-04  1.26e-12 0.00e+00  2.29e-10     4s
#   20   7.13977618e-04  7.22454056e-04  1.42e-12 0.00e+00  6.75e-11     4s
#   21   7.18898875e-04  7.19969408e-04  6.11e-12 0.00e+00  8.52e-12     4s
#   22   7.19216132e-04  7.19253783e-04  9.02e-12 0.00e+00  3.00e-13     4s
#   23   7.19222259e-04  7.19222737e-04  2.34e-10 5.69e-17  3.80e-15     4s
#
# Barrier solved model in 23 iterations and 4.18 seconds (3.41 work units)
# Optimal objective 7.19222259e-04
#
# Optimal objective value: 0.000719222259223122
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 8452 rows, 244997 columns and 927336 nonzeros
# Model fingerprint: 0x2923fdb7
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.55s
# Presolved: 8452 rows, 244997 columns, 927336 nonzeros
# Ordering time: 1.03s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 5.915e+05
#  Factor NZ  : 2.348e+06 (roughly 120 MB of memory)
#  Factor Ops : 2.382e+09 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7.49914687e-03  6.50456271e-04  1.07e+02 1.88e-05  2.21e-02     2s
#    1   4.06103228e-05  2.89128474e+01  5.55e+01 2.61e-02  1.15e-02     2s
#    2   5.01955714e-03  3.87849528e+01  5.30e+01 9.49e-04  1.07e-02     2s
#    3   1.70476711e-03  3.60481915e+01  1.55e+01 0.00e+00  3.24e-03     2s
#    4   2.04665071e-04  2.74290114e+01  1.26e+00 0.00e+00  4.28e-04     2s
#    5   3.41032887e-05  1.96528551e+01  8.33e-04 0.00e+00  1.57e-04     2s
#    6   3.40792072e-05  7.50562045e-03  8.55e-15 0.00e+00  5.95e-08     3s
#    7   1.14998077e-04  3.57501950e-03  3.44e-15 0.00e+00  2.75e-08     3s
#    8   1.89404107e-04  2.84750608e-03  2.89e-15 0.00e+00  2.12e-08     3s
#    9   3.22754945e-04  2.02792681e-03  2.66e-15 0.00e+00  1.36e-08     3s
#   10   4.15546638e-04  1.55718001e-03  2.89e-15 0.00e+00  9.09e-09     3s
#   11   5.42246938e-04  1.17606424e-03  2.33e-15 0.00e+00  5.04e-09     3s
#   12   6.24077742e-04  9.23855014e-04  3.44e-15 0.00e+00  2.39e-09     3s
#   13   6.48121269e-04  7.96279926e-04  2.07e-14 0.00e+00  1.18e-09     3s
#   14   6.67962098e-04  7.56493201e-04  6.65e-14 0.00e+00  7.05e-10     4s
#   15   6.91320402e-04  7.33492160e-04  2.66e-13 0.00e+00  3.36e-10     4s
#   16   7.11309274e-04  7.18306558e-04  1.48e-12 0.00e+00  5.57e-11     4s
#   17   7.13839686e-04  7.14877193e-04  4.87e-11 0.00e+00  8.26e-12     4s
#   18   7.14070971e-04  7.14081771e-04  3.98e-10 2.54e-21  8.60e-14     4s
#   19   7.14075221e-04  7.14075222e-04  2.41e-10 1.32e-16  9.41e-19     4s
#
# Barrier solved model in 19 iterations and 4.05 seconds (3.19 work units)
# Optimal objective 7.14075221e-04
#
# Optimal objective value: 0.000714075221451299
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 6966 rows, 187385 columns and 709158 nonzeros
# Model fingerprint: 0x7733fc27
# Coefficient statistics:
#   Matrix range     [6e-02, 7e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.41s
# Presolved: 6966 rows, 187385 columns, 709158 nonzeros
# Ordering time: 0.83s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 4.571e+05
#  Factor NZ  : 2.266e+06 (roughly 100 MB of memory)
#  Factor Ops : 2.272e+09 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.21968009e-03  6.73469866e-04  3.95e+01 1.17e-04  1.78e-02     2s
#    1   2.92085048e-05  5.69819762e+00  2.71e+01 5.01e-02  1.23e-02     2s
#    2   7.24239421e-03  1.02118229e+01  2.42e+01 3.50e-02  1.15e-02     2s
#    3   2.75968908e-04  1.33324607e+01  6.92e-01 5.19e-03  4.71e-04     2s
#    4   1.69192404e-04  8.88226446e+00  1.78e-01 1.91e-03  1.64e-04     2s
#    5   9.72657338e-05  6.78708817e+00  8.58e-03 1.27e-03  7.52e-05     2s
#    6   9.25369183e-05  2.20232936e-01  2.11e-15 1.96e-05  2.33e-06     2s
#    7   9.47860957e-05  3.40298034e-03  1.44e-15 3.08e-07  3.49e-08     2s
#    8   1.61927324e-04  2.53158824e-03  1.44e-15 2.02e-07  2.50e-08     2s
#    9   2.45638403e-04  1.91165014e-03  9.99e-16 1.33e-07  1.76e-08     2s
#   10   3.76664997e-04  1.20813062e-03  1.11e-15 6.38e-08  8.74e-09     2s
#   11   4.84386668e-04  9.56060243e-04  5.55e-16 4.04e-08  4.96e-09     2s
#   12   5.36699294e-04  8.16672904e-04  6.66e-16 2.24e-08  2.94e-09     3s
#   13   5.61368090e-04  7.50230355e-04  3.05e-15 1.49e-08  1.98e-09     3s
#   14   5.73640645e-04  7.07305954e-04  3.05e-15 1.02e-08  1.40e-09     3s
#   15   5.79851291e-04  6.64388913e-04  1.05e-15 5.31e-09  8.86e-10     3s
#   16   5.93445272e-04  6.26507235e-04  3.54e-15 1.79e-09  3.46e-10     3s
#   17   5.97675240e-04  6.04941887e-04  1.74e-14 2.27e-10  7.58e-11     3s
#   18   5.98798889e-04  6.00177094e-04  3.67e-14 1.80e-11  1.43e-11     3s
#   19   5.99223836e-04  5.99670974e-04  4.90e-14 2.03e-12  4.64e-12     3s
#   20   5.99358676e-04  5.99590022e-04  5.52e-14 5.19e-14  2.40e-12     3s
#   21   5.99395046e-04  5.99583278e-04  7.92e-14 2.21e-14  1.95e-12     3s
#   22   5.99552396e-04  5.99580080e-04  8.18e-14 2.97e-14  2.87e-13     3s
#   23   5.99577741e-04  5.99577809e-04  6.82e-14 1.28e-15  7.14e-16     3s
#
# Barrier solved model in 23 iterations and 3.35 seconds (2.38 work units)
# Optimal objective 5.99577741e-04
#
# Optimal objective value: 0.00059957774050932
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7036 rows, 189820 columns and 718459 nonzeros
# Model fingerprint: 0x23126469
# Coefficient statistics:
#   Matrix range     [1e-01, 7e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.41s
# Presolved: 7036 rows, 189820 columns, 718459 nonzeros
# Ordering time: 0.75s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 4.628e+05
#  Factor NZ  : 2.334e+06 (roughly 100 MB of memory)
#  Factor Ops : 2.391e+09 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.92575825e-03  7.25855493e-04  4.21e+01 1.07e-04  1.99e-02     1s
#    1   2.85931920e-05  6.14597377e+00  2.84e+01 5.56e-02  1.36e-02     2s
#    2   1.33246161e-04  1.21407174e+01  1.48e+01 4.16e-02  7.71e-03     2s
#    3   1.45284946e-05  1.70947622e+01  1.02e+00 3.70e-03  6.87e-04     2s
#    4   9.67964011e-06  1.13110807e+01  2.38e-01 1.34e-03  2.17e-04     2s
#    5   7.18748994e-06  8.30152433e+00  7.68e-02 8.15e-04  1.12e-04     2s
#    6   5.52782009e-06  2.03953444e+00  2.77e-04 1.04e-04  2.12e-05     2s
#    7   5.54387282e-06  4.22571688e-03  8.88e-16 2.15e-07  4.39e-08     2s
#    8   1.27499934e-04  3.35723638e-03  8.33e-16 1.63e-07  3.36e-08     2s
#    9   2.11967924e-04  2.23660788e-03  1.17e-15 1.07e-07  2.10e-08     2s
#   10   3.64977097e-04  1.60190989e-03  9.44e-16 5.66e-08  1.28e-08     2s
#   11   4.62202645e-04  1.17501394e-03  6.11e-16 4.60e-08  7.39e-09     2s
#   12   5.51025893e-04  9.55737435e-04  8.88e-16 2.51e-08  4.20e-09     2s
#   13   5.83847398e-04  8.31387940e-04  7.22e-16 1.39e-08  2.57e-09     3s
#   14   6.14253377e-04  7.56956350e-04  7.22e-16 6.81e-09  1.48e-09     3s
#   15   6.35869888e-04  7.13666297e-04  1.28e-15 3.28e-09  8.06e-10     3s
#   16   6.41475570e-04  6.90805884e-04  3.44e-15 1.99e-09  5.11e-10     3s
#   17   6.45289035e-04  6.73438968e-04  9.55e-15 1.04e-09  2.91e-10     3s
#   18   6.47728293e-04  6.57575532e-04  5.76e-14 2.78e-10  1.02e-10     3s
#   19   6.49073339e-04  6.52081151e-04  9.75e-14 6.67e-11  3.10e-11     3s
#   20   6.49456648e-04  6.50364684e-04  1.39e-13 1.04e-11  9.33e-12     3s
#   21   6.49613905e-04  6.50012240e-04  2.32e-13 9.75e-13  4.08e-12     3s
#   22   6.49840891e-04  6.49955672e-04  1.15e-12 1.18e-13  1.18e-12     3s
#   23   6.49945243e-04  6.49946860e-04  2.99e-12 3.99e-14  1.66e-14     3s
#
# Barrier solved model in 23 iterations and 3.41 seconds (2.38 work units)
# Optimal objective 6.49945243e-04
#
# Optimal objective value: 0.0006499452431367072
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7322 rows, 201737 columns and 763851 nonzeros
# Model fingerprint: 0xa4a2266b
# Coefficient statistics:
#   Matrix range     [6e-01, 7e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.42s
# Presolved: 7322 rows, 201737 columns, 763851 nonzeros
# Ordering time: 0.85s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 4.903e+05
#  Factor NZ  : 2.321e+06 (roughly 100 MB of memory)
#  Factor Ops : 2.421e+09 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.40402802e-03  7.12990345e-04  3.29e+01 5.49e-05  1.51e-02     2s
#    1   1.67786417e-05  5.76854920e+00  1.91e+01 5.49e-02  8.85e-03     2s
#    2   3.10345549e-04  1.27052908e+01  1.17e+01 4.76e-02  5.95e-03     2s
#    3   4.75802926e-05  1.75838822e+01  6.41e-01 4.48e-03  4.80e-04     2s
#    4   3.87580741e-05  9.78229532e+00  2.54e-01 1.32e-03  1.89e-04     2s
#    5   2.94442912e-05  7.27154832e+00  9.41e-02 8.05e-04  9.93e-05     2s
#    6   2.17897567e-05  3.74675128e+00  1.11e-15 3.14e-04  3.68e-05     2s
#    7   2.18245100e-05  3.00996494e-03  9.44e-16 2.51e-07  2.93e-08     2s
#    8   1.56417956e-04  2.42855947e-03  6.66e-16 1.93e-07  2.23e-08     2s
#    9   2.05538315e-04  1.70312223e-03  7.22e-16 1.13e-07  1.47e-08     2s
#   10   3.54420800e-04  1.22075421e-03  7.49e-16 5.89e-08  8.47e-09     2s
#   11   4.43881582e-04  1.01338602e-03  5.55e-16 3.89e-08  5.56e-09     2s
#   12   4.81566056e-04  8.88651659e-04  4.44e-16 2.24e-08  3.97e-09     2s
#   13   5.55429285e-04  8.23896199e-04  4.44e-16 1.62e-08  2.62e-09     3s
#   14   5.86726638e-04  7.53119431e-04  6.38e-16 8.93e-09  1.62e-09     3s
#   15   6.05794034e-04  7.07943858e-04  1.98e-15 4.72e-09  9.95e-10     3s
#   16   6.22276699e-04  6.61169848e-04  1.08e-14 1.16e-09  3.78e-10     3s
#   17   6.28301195e-04  6.45869822e-04  2.03e-14 4.68e-10  1.71e-10     3s
#   18   6.31477139e-04  6.34184520e-04  2.71e-14 4.04e-12  2.61e-11     3s
#   19   6.32471401e-04  6.33174781e-04  6.25e-14 1.63e-13  6.79e-12     3s
#   20   6.32896135e-04  6.33069075e-04  1.21e-13 6.23e-15  1.67e-12     3s
#   21   6.32942232e-04  6.33063370e-04  8.57e-14 5.05e-15  1.17e-12     3s
#   22   6.33039678e-04  6.33057952e-04  6.72e-14 4.45e-15  1.76e-13     3s
#   23   6.33056974e-04  6.33057280e-04  2.13e-14 1.75e-14  2.95e-15     3s
#
# Barrier solved model in 23 iterations and 3.29 seconds (2.64 work units)
# Optimal objective 6.33056974e-04
#
# Optimal objective value: 0.0006330569741304679
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7178 rows, 195146 columns and 738493 nonzeros
# Model fingerprint: 0x18aff3e3
# Coefficient statistics:
#   Matrix range     [4e-01, 7e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.42s
# Presolved: 7178 rows, 195146 columns, 738493 nonzeros
# Ordering time: 0.89s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 4.752e+05
#  Factor NZ  : 2.332e+06 (roughly 100 MB of memory)
#  Factor Ops : 2.497e+09 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.32532374e-03  6.98473785e-04  3.08e+01 6.20e-05  1.49e-02     2s
#    1   1.60811220e-05  5.79843013e+00  1.83e+01 6.11e-02  8.99e-03     2s
#    2   4.51703723e-04  1.37388752e+01  1.12e+01 5.16e-02  6.10e-03     2s
#    3   5.55165371e-05  1.92859286e+01  6.78e-01 7.99e-03  5.52e-04     2s
#    4   4.57193562e-05  1.12994694e+01  3.44e-01 2.37e-03  2.51e-04     2s
#    5   3.83586890e-05  8.30400195e+00  1.88e-01 1.34e-03  1.46e-04     2s
#    6   2.96361042e-05  6.76075498e+00  8.01e-02 9.79e-04  9.11e-05     2s
#    7   2.24932828e-05  2.56185140e+00  9.44e-16 2.81e-04  2.62e-05     2s
#    8   2.25702906e-05  2.99113560e-03  8.33e-16 0.00e+00  2.97e-08     2s
#    9   1.80728817e-04  2.32154015e-03  5.83e-16 2.18e-09  2.14e-08     2s
#   10   2.69945328e-04  1.61861032e-03  7.22e-16 9.83e-09  1.35e-08     2s
#   11   4.00400003e-04  1.30618199e-03  6.11e-16 0.00e+00  9.06e-09     3s
#   12   4.53722563e-04  9.78844816e-04  4.44e-16 5.33e-09  5.25e-09     3s
#   13   5.24775920e-04  8.82805551e-04  5.55e-16 3.84e-09  3.58e-09     3s
#   14   5.80230225e-04  7.56589064e-04  1.50e-15 1.49e-09  1.76e-09     3s
#   15   6.16512502e-04  6.98188946e-04  1.83e-15 4.82e-10  8.16e-10     3s
#   16   6.28887724e-04  6.72349931e-04  2.03e-15 2.05e-10  4.34e-10     3s
#   17   6.34997170e-04  6.55163238e-04  4.14e-15 7.93e-11  2.01e-10     3s
#   18   6.37914164e-04  6.45577334e-04  9.12e-15 1.82e-11  7.65e-11     3s
#   19   6.39689319e-04  6.42730766e-04  6.18e-14 4.31e-12  3.03e-11     3s
#   20   6.40415095e-04  6.41752413e-04  1.77e-13 1.03e-12  1.33e-11     3s
#   21   6.40960912e-04  6.41357833e-04  2.15e-12 0.00e+00  3.96e-12     3s
#   22   6.41160899e-04  6.41215371e-04  3.31e-11 0.00e+00  5.43e-13     3s
#   23   6.41168271e-04  6.41168400e-04  9.28e-11 2.60e-18  1.28e-15     3s
#
# Barrier solved model in 23 iterations and 3.41 seconds (2.49 work units)
# Optimal objective 6.41168271e-04
#
# Optimal objective value: 0.0006411682714168074
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7105 rows, 192843 columns and 729916 nonzeros
# Model fingerprint: 0xb88c7cd5
# Coefficient statistics:
#   Matrix range     [5e-01, 8e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.43s
# Presolved: 7105 rows, 192843 columns, 729916 nonzeros
# Ordering time: 0.80s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 4.700e+05
#  Factor NZ  : 2.267e+06 (roughly 100 MB of memory)
#  Factor Ops : 2.330e+09 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.73899970e-03  6.64307602e-04  3.52e+01 4.65e-05  1.63e-02     2s
#    1   1.71987692e-05  5.33642726e+00  1.98e+01 5.55e-02  9.30e-03     2s
#    2   2.78913482e-04  1.34668309e+01  1.21e+01 4.79e-02  6.30e-03     2s
#    3   2.84475201e-05  1.67797291e+01  6.58e-01 9.15e-03  5.07e-04     2s
#    4   2.20437765e-05  9.15336550e+00  5.12e-02 2.85e-03  1.18e-04     2s
#    5   2.05878622e-05  5.73177480e+00  7.18e-03 1.63e-03  6.29e-05     2s
#    6   1.95484506e-05  1.93383887e+00  1.21e-06 4.85e-04  2.05e-05     2s
#    7   1.96003697e-05  2.58875463e-03  1.11e-15 6.45e-07  2.72e-08     2s
#    8   1.65524721e-04  2.27261438e-03  6.66e-16 5.42e-07  2.23e-08     2s
#    9   2.21728913e-04  1.85284272e-03  5.55e-16 4.40e-07  1.73e-08     2s
#   10   3.15750627e-04  1.13223013e-03  2.21e-15 1.82e-07  8.58e-09     2s
#   11   4.28523453e-04  9.20460837e-04  1.86e-15 9.63e-08  5.14e-09     2s
#   12   5.32131160e-04  7.65750955e-04  8.88e-16 3.95e-08  2.43e-09     3s
#   13   5.71362993e-04  7.18760512e-04  1.36e-15 2.80e-08  1.54e-09     3s
#   14   5.84122112e-04  6.93497494e-04  3.50e-15 2.02e-08  1.14e-09     3s
#   15   5.91718277e-04  6.71993516e-04  3.26e-15 1.37e-08  8.36e-10     3s
#   16   5.97479708e-04  6.61149801e-04  2.65e-15 1.07e-08  6.62e-10     3s
#   17   6.04655937e-04  6.39284053e-04  2.19e-14 4.92e-09  3.59e-10     3s
#   18   6.08935413e-04  6.20468030e-04  5.83e-14 1.37e-09  1.19e-10     3s
#   19   6.10583747e-04  6.11637072e-04  2.84e-14 4.26e-11  1.07e-11     3s
#   20   6.10858499e-04  6.11130991e-04  2.55e-13 2.65e-12  2.75e-12     3s
#   21   6.11063225e-04  6.11083894e-04  2.00e-12 4.98e-13  2.09e-13     3s
#   22   6.11071319e-04  6.11071340e-04  1.20e-12 4.59e-16  2.11e-16     3s
#
# Barrier solved model in 22 iterations and 3.45 seconds (2.47 work units)
# Optimal objective 6.11071319e-04
#
# Optimal objective value: 0.0006110713190839774
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 4998 rows, 109526 columns and 414221 nonzeros
# Model fingerprint: 0x700722ec
# Coefficient statistics:
#   Matrix range     [5e-01, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.21s
# Presolved: 4998 rows, 109526 columns, 414221 nonzeros
# Ordering time: 0.33s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 2.744e+05
#  Factor NZ  : 1.938e+06 (roughly 60 MB of memory)
#  Factor Ops : 1.743e+09 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.27657649e-03  7.12807467e-04  2.79e+01 2.20e-04  1.65e-02     1s
#    1   1.14784085e-05  2.12721803e+00  1.78e+01 5.90e-02  1.06e-02     1s
#    2   2.48823503e-03  4.63377093e+00  1.53e+01 3.69e-02  9.57e-03     1s
#    3   2.96573883e-04  6.11045310e+00  7.70e-01 4.44e-03  6.86e-04     1s
#    4   1.65757057e-04  3.68738594e+00  1.84e-01 1.27e-03  2.20e-04     1s
#    5   9.75774122e-05  2.14940619e+00  2.83e-04 5.52e-04  7.75e-05     1s
#    6   9.76173579e-05  2.17278531e-03  7.49e-16 5.28e-07  7.48e-08     1s
#    7   1.39359580e-04  1.74108466e-03  6.11e-16 3.88e-07  5.77e-08     1s
#    8   2.24436245e-04  1.55555274e-03  3.89e-16 3.27e-07  4.79e-08     1s
#    9   2.89778285e-04  1.18810955e-03  3.89e-16 2.06e-07  3.23e-08     1s
#   10   3.81827243e-04  9.55697417e-04  3.33e-16 1.24e-07  2.06e-08     1s
#   11   4.59675880e-04  7.74763377e-04  7.49e-16 5.59e-08  1.13e-08     1s
#   12   5.09379680e-04  6.75977571e-04  1.10e-15 2.25e-08  5.96e-09     1s
#   13   5.11736030e-04  6.62758827e-04  1.10e-15 1.89e-08  5.40e-09     1s
#   14   5.32588184e-04  6.49913206e-04  1.22e-15 2.30e-08  4.20e-09     1s
#   15   5.41047115e-04  6.29654594e-04  1.61e-15 1.45e-08  3.17e-09     1s
#   16   5.43792771e-04  6.20652180e-04  1.79e-15 9.40e-09  2.75e-09     1s
#   17   5.52538797e-04  6.05151325e-04  4.27e-15 9.59e-09  1.88e-09     1s
#   18   5.54589291e-04  5.96641265e-04  4.59e-15 7.64e-09  1.50e-09     2s
#   19   5.59594212e-04  5.86688509e-04  6.41e-14 4.22e-09  9.69e-10     2s
#   20   5.61276486e-04  5.77297358e-04  5.63e-14 1.34e-09  5.72e-10     2s
#   21   5.63013887e-04  5.70104559e-04  2.86e-14 1.39e-10  2.53e-10     2s
#   22   5.64265449e-04  5.66284367e-04  3.73e-14 3.67e-11  7.16e-11     2s
#   23   5.65026699e-04  5.65309447e-04  3.40e-13 6.47e-12  1.00e-11     2s
#   24   5.65088043e-04  5.65089368e-04  6.63e-13 2.66e-14  4.68e-14     2s
#
# Barrier solved model in 24 iterations and 1.78 seconds (1.25 work units)
# Optimal objective 5.65088043e-04
#
# Optimal objective value: 0.0005650880430417676
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 5012 rows, 707825 columns and 2805996 nonzeros
# Model fingerprint: 0x3af08754
# Coefficient statistics:
#   Matrix range     [8e-01, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 1.77s
# Presolved: 5012 rows, 707825 columns, 2805996 nonzeros
# Ordering time: 0.23s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 1.431e+06
#  Factor NZ  : 3.185e+06 (roughly 300 MB of memory)
#  Factor Ops : 3.651e+09 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.87494358e-03  6.27662814e-04  1.09e+02 1.90e-04  1.44e-02     3s
#    1   8.97880338e-06  2.78936318e+00  6.58e+01 6.25e-02  8.86e-03     3s
#    2   5.03233648e-05  3.86013884e+00  3.16e+01 5.08e-02  4.36e-03     4s
#    3   7.35132186e-06  6.44991436e+00  3.31e+00 2.26e-02  5.09e-04     4s
#    4   4.33605046e-06  6.39971889e+00  5.00e-01 9.41e-03  1.08e-04     4s
#    5   5.24223727e-06  5.70156150e+00  1.57e-01 7.09e-03  5.57e-05     5s
#    6   5.70792586e-06  4.38117271e+00  1.67e-15 5.28e-03  2.80e-05     5s
#    7   5.73092287e-06  8.81005204e-03  1.67e-15 1.06e-05  5.63e-08     5s
#    8   7.02168794e-05  7.82314738e-03  1.17e-15 9.26e-06  4.95e-08     5s
#    9   1.23001870e-04  3.07017555e-03  1.05e-15 3.40e-06  1.88e-08     6s
#   10   1.80742419e-04  1.82154645e-03  1.05e-15 1.84e-06  1.04e-08     6s
#   11   2.06401460e-04  1.44517493e-03  8.88e-16 1.29e-06  7.80e-09     6s
#   12   2.74620372e-04  1.20220872e-03  9.44e-16 9.69e-07  5.83e-09     7s
#   13   2.85847422e-04  9.89502576e-04  1.05e-15 6.64e-07  4.39e-09     7s
#   14   3.25834570e-04  9.07149320e-04  8.33e-16 5.62e-07  3.63e-09     7s
#   15   3.65833243e-04  7.97339508e-04  1.11e-15 4.59e-07  2.69e-09     7s
#   16   3.98181746e-04  7.38457900e-04  1.17e-15 3.80e-07  2.12e-09     8s
#   17   4.42253370e-04  6.76506105e-04  2.48e-14 2.76e-07  1.47e-09     8s
#   18   4.89948661e-04  6.47292762e-04  2.30e-14 2.10e-07  1.00e-09     8s
#   19   5.13851919e-04  6.24247108e-04  7.94e-14 1.53e-07  7.06e-10     9s
#   20   5.25618565e-04  6.15315985e-04  5.08e-14 1.26e-07  5.75e-10     9s
#   21   5.37055633e-04  6.07754561e-04  7.79e-14 1.02e-07  4.55e-10     9s
#   22   5.51516968e-04  6.01351990e-04  1.79e-13 8.16e-08  3.27e-10     9s
#   23   5.59462160e-04  5.91080076e-04  1.42e-13 4.61e-08  2.04e-10    10s
#   24   5.65916855e-04  5.88203378e-04  6.77e-14 3.63e-08  1.46e-10    10s
#   25   5.68606303e-04  5.85200098e-04  1.54e-13 2.73e-08  1.09e-10    11s
#   26   5.71900450e-04  5.82874063e-04  2.12e-13 2.05e-08  7.36e-11    11s
#   27   5.73246787e-04  5.80651087e-04  1.60e-13 1.40e-08  4.98e-11    12s
#   28   5.74095927e-04  5.80036667e-04  1.76e-13 1.21e-08  4.05e-11    12s
#   29   5.74293725e-04  5.76873887e-04  2.00e-13 3.91e-09  1.68e-11    12s
#   30   5.74826381e-04  5.75023651e-04  7.96e-13 1.99e-10  1.23e-12    12s
#   31   5.74843393e-04  5.74843716e-04  1.63e-12 5.92e-14  1.85e-15    13s
#
# Barrier solved model in 31 iterations and 12.76 seconds (6.72 work units)
# Optimal objective 5.74843393e-04
#
# Optimal objective value: 0.0005748433934384397
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 5173 rows, 746579 columns and 2960150 nonzeros
# Model fingerprint: 0x318bd9d7
# Coefficient statistics:
#   Matrix range     [1e-01, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 2.14s
# Presolved: 5173 rows, 746579 columns, 2960150 nonzeros
# Ordering time: 0.31s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 1.501e+06
#  Factor NZ  : 3.256e+06 (roughly 300 MB of memory)
#  Factor Ops : 3.718e+09 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.66177994e-03  5.95292726e-04  9.32e+01 8.02e-05  1.30e-02     3s
#    1   1.13990519e-05  4.09898812e+00  5.05e+01 6.32e-02  7.16e-03     4s
#    2   3.54519300e-04  5.93909793e+00  2.56e+01 5.71e-02  3.71e-03     4s
#    3   3.58379880e-05  1.09056943e+01  2.12e+00 1.76e-02  3.47e-04     4s
#    4   2.31151147e-05  1.01109655e+01  2.94e-01 4.83e-03  6.87e-05     5s
#    5   2.48480191e-05  9.08753278e+00  5.65e-02 4.06e-03  3.30e-05     5s
#    6   2.50283238e-05  6.93321584e+00  2.40e-04 2.86e-03  1.98e-05     5s
#    7   2.50756766e-05  6.94439790e-03  1.78e-15 2.75e-06  1.97e-08     5s
#    8   1.04298877e-04  4.88847833e-03  1.17e-15 1.87e-06  1.36e-08     6s
#    9   1.70401055e-04  2.05395334e-03  9.71e-16 6.87e-07  5.33e-09     6s
#   10   2.07562170e-04  1.54124139e-03  9.99e-16 4.70e-07  3.76e-09     6s
#   11   2.72707018e-04  1.22319085e-03  8.88e-16 3.34e-07  2.68e-09     7s
#   12   3.10546877e-04  1.11682282e-03  7.77e-16 2.91e-07  2.27e-09     7s
#   13   3.39265479e-04  9.28328648e-04  7.77e-16 2.01e-07  1.66e-09     7s
#   14   3.54197056e-04  8.10355667e-04  8.88e-16 1.48e-07  1.28e-09     7s
#   15   4.13824058e-04  7.47304977e-04  8.88e-16 1.23e-07  9.40e-10     8s
#   16   4.58629441e-04  6.78888005e-04  2.60e-15 8.07e-08  6.22e-10     8s
#   17   5.04985535e-04  6.47072803e-04  1.48e-15 5.70e-08  4.04e-10     9s
#   18   5.44366670e-04  6.28263497e-04  8.55e-15 3.97e-08  2.41e-10     9s
#   19   5.59873974e-04  6.15365309e-04  5.16e-15 2.76e-08  1.61e-10     9s
#   20   5.68350779e-04  6.05901571e-04  1.17e-14 1.96e-08  1.09e-10    10s
#   21   5.71174266e-04  6.00335795e-04  5.87e-15 1.35e-08  8.42e-11    10s
#   22   5.74831053e-04  5.96776097e-04  1.49e-14 1.05e-08  6.35e-11    10s
#   23   5.78154271e-04  5.90923315e-04  5.15e-14 5.78e-09  3.68e-11    11s
#   24   5.80229951e-04  5.86339841e-04  2.50e-14 2.24e-09  1.74e-11    11s
#   25   5.81430752e-04  5.84289270e-04  1.15e-13 9.24e-10  8.07e-12    11s
#   26   5.82468493e-04  5.82817889e-04  2.09e-13 5.98e-11  9.58e-13    12s
#   27   5.82597318e-04  5.82645784e-04  9.66e-13 5.26e-12  1.32e-13    12s
#   28   5.82614254e-04  5.82622013e-04  1.36e-10 3.72e-13  2.09e-14    12s
#
# Barrier solved model in 28 iterations and 12.29 seconds (6.31 work units)
# Optimal objective 5.82614254e-04
#
# Optimal objective value: 0.0005826142537765985
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 5279 rows, 121735 columns and 460756 nonzeros
# Model fingerprint: 0xf9ecc355
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.27s
# Presolved: 5279 rows, 121735 columns, 460756 nonzeros
# Ordering time: 0.38s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 3.026e+05
#  Factor NZ  : 2.287e+06 (roughly 70 MB of memory)
#  Factor Ops : 2.252e+09 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.30411145e-03  6.54106492e-04  2.90e+01 1.40e-04  1.70e-02     1s
#    1   1.06664294e-05  2.27158575e+00  1.73e+01 5.55e-02  1.02e-02     1s
#    2   4.72879866e-05  4.86508641e+00  9.66e+00 4.37e-02  6.21e-03     1s
#    3   6.63671724e-06  6.25695999e+00  7.32e-01 5.74e-03  6.47e-04     1s
#    4   5.19590734e-06  3.67774255e+00  1.28e-01 1.70e-03  1.82e-04     1s
#    5   3.84143005e-06  2.52103335e+00  1.24e-04 1.04e-03  8.33e-05     1s
#    6   3.84865668e-06  2.82219781e-03  8.88e-16 1.16e-06  9.31e-08     1s
#    7   3.62413723e-05  2.67641885e-03  6.66e-16 1.08e-06  8.71e-08     1s
#    8   8.62893404e-05  1.81901100e-03  5.27e-16 6.64e-07  5.71e-08     1s
#    9   1.40560562e-04  1.53693228e-03  3.61e-16 5.47e-07  4.60e-08     1s
#   10   2.69719301e-04  1.12357318e-03  3.89e-16 3.72e-07  2.81e-08     1s
#   11   3.66477461e-04  7.98853198e-04  3.33e-16 1.20e-07  1.41e-08     2s
#   12   4.65476557e-04  7.01196633e-04  6.11e-16 7.91e-08  7.69e-09     2s
#   13   4.88770914e-04  6.70527927e-04  6.80e-16 5.23e-08  5.93e-09     2s
#   14   4.94750302e-04  6.66355895e-04  5.83e-16 6.10e-08  5.60e-09     2s
#   15   5.14316189e-04  6.34662380e-04  1.67e-15 3.10e-08  3.92e-09     2s
#   16   5.34599734e-04  6.12602958e-04  2.01e-15 2.68e-08  2.55e-09     2s
#   17   5.42137029e-04  5.77133202e-04  6.91e-15 9.25e-09  1.14e-09     2s
#   18   5.44886866e-04  5.48912679e-04  1.13e-14 3.10e-10  1.29e-10     2s
#   19   5.46390764e-04  5.46643427e-04  6.74e-14 0.00e+00  8.03e-12     2s
#   20   5.46513083e-04  5.46513864e-04  1.27e-13 0.00e+00  2.48e-14     2s
#
# Barrier solved model in 20 iterations and 2.01 seconds (1.25 work units)
# Optimal objective 5.46513083e-04
#
# Optimal objective value: 0.000546513082767647
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 5225 rows, 763942 columns and 3028882 nonzeros
# Model fingerprint: 0x6d7e030e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 1.93s
# Presolved: 5225 rows, 763942 columns, 3028882 nonzeros
# Ordering time: 0.22s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 1.529e+06
#  Factor NZ  : 3.301e+06 (roughly 340 MB of memory)
#  Factor Ops : 3.771e+09 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.65937656e-03  5.33850265e-04  1.07e+02 1.66e-04  1.36e-02     3s
#    1   8.40778772e-06  2.63175585e+00  6.38e+01 6.10e-02  8.30e-03     3s
#    2   4.05424510e-05  4.26113522e+00  2.92e+01 4.81e-02  3.91e-03     4s
#    3   5.01616010e-06  6.97036051e+00  3.00e+00 8.57e-03  4.38e-04     4s
#    4   3.05096072e-06  6.41607022e+00  7.42e-01 4.21e-03  1.29e-04     5s
#    5   2.93307686e-06  5.19708449e+00  1.51e-01 2.67e-03  4.51e-05     5s
#    6   3.17383848e-06  3.87636197e+00  1.23e-04 1.83e-03  2.11e-05     5s
#    7   3.18362712e-06  5.93223747e-03  1.47e-15 2.79e-06  3.23e-08     5s
#    8   3.24700727e-05  4.55214526e-03  1.44e-15 2.07e-06  2.46e-08     6s
#    9   4.27240138e-05  2.84617854e-03  9.99e-16 1.23e-06  1.52e-08     6s
#   10   6.93885799e-05  1.97542601e-03  8.88e-16 7.98e-07  1.03e-08     6s
#   11   1.70932125e-04  1.40320994e-03  8.88e-16 4.87e-07  6.66e-09     7s
#   12   2.35684299e-04  1.04609404e-03  1.11e-15 3.00e-07  4.37e-09     7s
#   13   2.98278564e-04  9.03129236e-04  1.05e-15 2.25e-07  3.26e-09     7s
#   14   3.02840022e-04  7.82952956e-04  9.44e-16 1.69e-07  2.58e-09     8s
#   15   3.23384600e-04  7.31224171e-04  1.22e-15 1.49e-07  2.19e-09     8s
#   16   3.54099492e-04  6.82862453e-04  1.05e-15 1.28e-07  1.77e-09     8s
#   17   3.79642360e-04  6.39610373e-04  5.83e-15 9.89e-08  1.40e-09     9s
#   18   4.03898174e-04  6.08648268e-04  6.33e-15 8.12e-08  1.10e-09     9s
#   19   4.46860317e-04  5.77976632e-04  2.64e-14 5.84e-08  7.09e-10     9s
#   20   4.71585280e-04  5.56787989e-04  6.60e-14 4.08e-08  4.63e-10    10s
#   21   4.85116125e-04  5.44749456e-04  8.63e-15 3.01e-08  3.25e-10    10s
#   22   4.89805414e-04  5.37209797e-04  1.44e-14 2.37e-08  2.58e-10    11s
#   23   4.92792614e-04  5.28694750e-04  1.18e-14 1.69e-08  1.95e-10    11s
#   24   4.99475532e-04  5.22904213e-04  1.85e-13 1.29e-08  1.28e-10    11s
#   25   5.01726438e-04  5.04835558e-04  2.05e-13 1.34e-09  1.69e-11    12s
#   26   5.01956994e-04  5.01961120e-04  2.75e-13 1.69e-20  2.15e-14    12s
#
# Barrier solved model in 26 iterations and 11.97 seconds (6.12 work units)
# Optimal objective 5.01956994e-04
#
# Optimal objective value: 0.0005019569938597962
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 3075 rows, 235024 columns and 931640 nonzeros
# Model fingerprint: 0x32ade504
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.50s
# Presolved: 3075 rows, 235024 columns, 931640 nonzeros
# Ordering time: 0.12s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 3.043e+05
#  Factor NZ  : 8.713e+05 (roughly 70 MB of memory)
#  Factor Ops : 5.328e+08 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.72221347e-03  4.76060813e-04  1.01e+02 3.23e-04  2.72e-02     1s
#    1   1.58196698e-05  9.54160352e-01  6.01e+01 5.82e-02  1.65e-02     1s
#    2   3.83512785e-03  1.74569542e+00  4.98e+01 3.47e-02  1.39e-02     1s
#    3   2.43123842e-04  2.31821216e+00  3.55e+00 5.69e-03  1.06e-03     2s
#    4   1.29381062e-04  1.92198751e+00  8.61e-01 2.44e-03  2.91e-04     2s
#    5   1.01745456e-04  1.58879665e+00  2.50e-01 1.74e-03  1.10e-04     2s
#    6   8.75763091e-05  1.28134915e+00  7.02e-02 1.13e-03  5.26e-05     2s
#    7   7.68597441e-05  4.41027964e-01  9.59e-06 2.36e-04  1.25e-05     2s
#    8   7.76772289e-05  6.30091793e-03  5.55e-16 3.58e-06  1.77e-07     2s
#    9   9.94281106e-05  3.09860150e-03  3.47e-16 1.62e-06  8.50e-08     2s
#   10   1.38706673e-04  1.53700162e-03  3.75e-16 6.45e-07  3.96e-08     2s
#   11   1.79647278e-04  8.39488127e-04  2.78e-16 3.33e-07  1.87e-08     2s
#   12   2.17798305e-04  6.55799118e-04  3.05e-16 1.81e-07  1.24e-08     2s
#   13   2.38392803e-04  5.54820984e-04  3.05e-16 1.41e-07  8.93e-09     2s
#   14   2.48132914e-04  5.02755111e-04  2.50e-16 1.01e-07  7.19e-09     2s
#   15   2.60166919e-04  4.72541475e-04  2.50e-16 8.42e-08  5.99e-09     2s
#   16   2.82796494e-04  4.36942152e-04  2.78e-16 7.23e-08  4.35e-09     2s
#   17   3.08137580e-04  4.11651826e-04  3.47e-16 5.59e-08  2.93e-09     2s
#   18   3.20936860e-04  3.89766180e-04  8.47e-16 3.51e-08  1.95e-09     2s
#   19   3.33686845e-04  3.77624736e-04  1.47e-15 2.33e-08  1.24e-09     2s
#   20   3.39345210e-04  3.62922379e-04  5.79e-15 1.07e-08  6.66e-10     2s
#   21   3.41339398e-04  3.53031862e-04  4.83e-15 3.84e-09  3.29e-10     2s
#   22   3.43994149e-04  3.50888196e-04  2.29e-14 2.61e-09  1.94e-10     2s
#   23   3.45346978e-04  3.46495035e-04  5.25e-14 3.14e-10  3.22e-11     2s
#   24   3.45557230e-04  3.45589103e-04  1.07e-13 2.63e-12  8.88e-13     3s
#   25   3.45570006e-04  3.45570561e-04  3.51e-11 4.14e-14  1.55e-14     3s
#
# Barrier solved model in 25 iterations and 2.56 seconds (1.54 work units)
# Optimal objective 3.45570006e-04
#
# Optimal objective value: 0.0003455700061545086
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 3019 rows, 217637 columns and 862621 nonzeros
# Model fingerprint: 0x7ad80727
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.46s
# Presolved: 3019 rows, 217637 columns, 862621 nonzeros
# Ordering time: 0.12s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 2.744e+05
#  Factor NZ  : 9.422e+05 (roughly 60 MB of memory)
#  Factor Ops : 6.227e+08 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6.62385409e-03  5.24234121e-04  1.45e+02 5.25e-04  3.90e-02     1s
#    1   2.45700661e-05  7.96849931e-01  9.46e+01 5.98e-02  2.59e-02     1s
#    2   6.04822907e-03  1.73584067e+00  6.28e+01 2.92e-02  1.77e-02     1s
#    3   3.52883883e-04  2.06204163e+00  3.63e+00 7.54e-03  1.10e-03     1s
#    4   1.55848208e-04  1.62712448e+00  5.73e-01 3.05e-03  2.12e-04     1s
#    5   1.29304867e-04  1.24071892e+00  1.49e-01 1.81e-03  7.87e-05     1s
#    6   1.07534461e-04  7.70674454e-01  2.09e-02 9.50e-04  2.89e-05     2s
#    7   1.00784702e-04  1.09677979e-01  2.57e-16 8.63e-05  3.50e-06     2s
#    8   1.04569310e-04  5.47177248e-03  2.08e-16 4.21e-06  1.72e-07     2s
# ...
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 3036 rows, 218414 columns and 866138 nonzeros
# Model fingerprint: 0xbc777c19
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.47s
# Presolved: 3036 rows, 218414 columns, 866138 nonzeros
# Ordering time: 0.15s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 2.488e+05
#  Factor NZ  : 8.159e+05 (roughly 50 MB of memory)
#  Factor Ops : 4.766e+08 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.67874021e-03  4.49232023e-04  8.45e+01 8.64e-04  2.85e-02     1s
#    1   1.05148392e-05  4.02142972e-01  5.64e+01 5.70e-02  1.94e-02     1s
#    2   1.89950347e-03  8.70105987e-01  3.01e+01 2.29e-02  1.07e-02     1s
#    3   2.19050312e-04  9.23259056e-01  2.55e+00 7.30e-03  9.66e-04     1s
#    4   1.24952343e-04  7.27533795e-01  5.67e-01 3.03e-03  2.47e-04     1s
#    5   1.00810260e-04  5.54276472e-01  1.49e-01 2.00e-03  8.76e-05     1s
#    6   9.13558566e-05  4.06222812e-01  5.97e-02 1.19e-03  4.54e-05     1s
#    7   8.15805173e-05  1.79384800e-01  5.55e-03 3.30e-04  1.35e-05     2s
#    8   8.21148419e-05  9.65598558e-03  2.29e-16 1.15e-05  6.71e-07     2s
#    9   1.04849822e-04  3.35846453e-03  1.67e-16 3.46e-06  2.27e-07     2s
#   10   1.40767142e-04  1.89792182e-03  1.53e-16 2.03e-06  1.23e-07     2s
#   11   1.82712359e-04  1.16071070e-03  1.73e-16 9.31e-07  6.83e-08     2s
#   12   2.12562454e-04  7.58991228e-04  1.53e-16 5.82e-07  3.81e-08     2s
#   13   2.50002583e-04  5.88832648e-04  1.87e-16 3.00e-07  2.36e-08     2s
#   14   2.64616723e-04  5.08097356e-04  1.46e-16 2.03e-07  1.70e-08     2s
#   15   2.84646995e-04  4.55737541e-04  1.39e-16 1.44e-07  1.19e-08     2s
#   16   2.95517374e-04  4.26727322e-04  1.25e-16 1.07e-07  9.12e-09     2s
#   17   3.17180815e-04  4.08462899e-04  3.75e-16 6.39e-08  6.35e-09     2s
#   18   3.34162933e-04  3.88320006e-04  5.41e-16 4.91e-08  3.77e-09     2s
#   19   3.41643307e-04  3.67718306e-04  2.45e-15 2.11e-08  1.82e-09     2s
#   20   3.44037687e-04  3.47330322e-04  5.17e-15 1.57e-09  2.28e-10     2s
#   21   3.44644468e-04  3.44655384e-04  3.79e-15 3.57e-12  7.55e-13     2s
#   22   3.44646490e-04  3.44646490e-04  2.13e-13 3.96e-18  8.30e-19     2s
#
# Barrier solved model in 22 iterations and 2.17 seconds (1.26 work units)
# Optimal objective 3.44646490e-04
#
# Optimal objective value: 0.00034464648975421255
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 3171 rows, 254345 columns and 1008234 nonzeros
# Model fingerprint: 0xed0733c9
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.56s
# Presolved: 3171 rows, 254345 columns, 1008234 nonzeros
# Ordering time: 0.17s
#
# Barrier statistics:
#  Dense cols : 1
#  AA' NZ     : 2.995e+05
#  Factor NZ  : 8.357e+05 (roughly 60 MB of memory)
#  Factor Ops : 4.828e+08 (less than 1 second per iteration)
#  Threads    : 20
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   2.89213223e-03  4.71234987e-04  9.86e+01 7.58e-04  3.10e-02     1s
#    1   1.10995310e-05  4.22174155e-01  6.59e+01 6.16e-02  2.11e-02     1s
#    2   2.62651817e-03  9.24986738e-01  4.17e+01 3.21e-02  1.37e-02     2s
#    3   1.66865765e-04  1.15145129e+00  2.69e+00 6.64e-03  9.52e-04     2s
#    4   9.79954697e-05  9.31869137e-01  5.54e-01 3.39e-03  2.33e-04     2s
#    5   8.70117729e-05  7.14054031e-01  1.35e-01 2.00e-03  8.27e-05     2s
#    6   7.73229140e-05  5.13926528e-01  8.82e-03 1.21e-03  3.27e-05     2s
#    7   7.63443508e-05  2.84286645e-02  2.22e-16 4.68e-05  1.66e-06     2s
#    8   8.65679477e-05  4.72224407e-03  2.78e-16 7.26e-06  2.71e-07     2s
#    9   1.00775936e-04  2.34863460e-03  1.53e-16 2.95e-06  1.31e-07     2s
#   10   1.44899877e-04  1.41861193e-03  2.29e-16 1.49e-06  7.41e-08     2s
#   11   1.81153093e-04  9.31802402e-04  1.53e-16 8.12e-07  4.36e-08     2s
#   12   2.20996789e-04  6.94953708e-04  1.53e-16 4.70e-07  2.75e-08     2s
#   13   2.54984122e-04  5.64629229e-04  1.80e-16 2.96e-07  1.79e-08     2s
#   14   2.72600097e-04  4.97106414e-04  1.46e-16 2.13e-07  1.30e-08     2s
#   15   2.83131690e-04  4.69493513e-04  1.46e-16 1.61e-07  1.08e-08     2s
#   16   2.98014214e-04  4.46538676e-04  1.53e-16 1.24e-07  8.58e-09     2s
#   17   3.06899131e-04  4.32283283e-04  1.53e-16 1.02e-07  7.24e-09     2s
#   18   3.21409046e-04  4.09865505e-04  1.46e-16 7.24e-08  5.11e-09     2s
#   19   3.42853933e-04  3.94162725e-04  3.96e-16 4.67e-08  2.97e-09     2s
#   20   3.52509894e-04  3.67806836e-04  4.86e-15 1.02e-08  8.81e-10     2s
#   21   3.54136971e-04  3.55736648e-04  8.28e-14 3.31e-10  9.13e-11     2s
#   22   3.54290309e-04  3.54357926e-04  3.39e-12 5.59e-12  3.85e-12     2s
#   23   3.54309077e-04  3.54309216e-04  4.29e-11 1.02e-15  7.90e-15     2s
#
# Barrier solved model in 23 iterations and 2.41 seconds (1.56 work units)
# Optimal objective 3.54309077e-04
#
# Optimal objective value: 0.00035430907743037106
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 616 rows, 2041 columns and 7555 nonzeros
# Model fingerprint: 0xb0fd5643
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 28 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 588 rows, 2041 columns, 7527 nonzeros
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.542e+03
#  Factor NZ  : 7.453e+03
#  Factor Ops : 4.311e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.49405881e-02  3.57642354e-04  9.90e+01 2.05e-03  3.74e-01     0s
#    1   6.52655758e-05  3.88689273e-01  5.24e+01 3.32e-03  1.83e-01     0s
#    2   9.97463259e-06  3.27401607e-01  2.61e+00 2.99e-04  1.58e-02     0s
#    3   3.68605118e-06  9.67222801e-02  4.67e-01 0.00e+00  3.51e-03     0s
#    4   1.28727438e-06  1.58785560e-02  4.44e-16 0.00e+00  3.53e-04     0s
#    5   2.15119364e-06  2.38160044e-03  6.66e-16 0.00e+00  5.30e-05     0s
#    6   2.49613704e-07  1.02117530e-03  4.44e-16 0.00e+00  2.27e-05     0s
#    7   2.25195288e-06  6.72728510e-04  4.44e-16 0.00e+00  1.49e-05     0s
#    8   2.67633314e-05  4.71829872e-04  1.11e-16 0.00e+00  9.91e-06     0s
#    9   4.74385222e-05  2.01192014e-04  3.33e-16 0.00e+00  3.42e-06     0s
#   10   5.86499938e-05  1.14565423e-04  3.33e-16 0.00e+00  1.24e-06     0s
#   11   6.35526938e-05  7.28740094e-05  1.11e-15 0.00e+00  2.07e-07     0s
#   12   6.40668054e-05  6.41376536e-05  1.71e-14 0.00e+00  1.58e-09     0s
#   13   6.40931658e-05  6.40932366e-05  1.33e-15 8.41e-20  1.58e-12     0s
#
# Barrier solved model in 13 iterations and 0.04 seconds (0.01 work units)
# Optimal objective 6.40931658e-05
#
# Optimal objective value: 6.409316579264315e-05
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 614 rows, 2609 columns and 10084 nonzeros
# Model fingerprint: 0x263af534
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 20 rows and 20 columns
# Presolve time: 0.01s
# Presolved: 594 rows, 2589 columns, 10044 nonzeros
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.289e+03
#  Factor NZ  : 2.118e+03
#  Factor Ops : 5.860e+04 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.39920003e-02  2.92582085e-04  1.00e+02 2.80e-03  6.85e-01     0s
#    1   1.19102479e-05  8.12086793e-02  4.99e+01 5.55e-17  2.84e-01     0s
#    2   1.92188833e-06  6.19689772e-02  5.64e-01 2.78e-17  1.18e-02     0s
#    3   9.46628201e-07  2.94598513e-03  1.11e-16 4.38e-17  4.30e-04     0s
#    4   2.55261640e-06  8.12298870e-04  5.55e-17 1.18e-17  1.18e-04     0s
#    5   1.03228667e-05  2.49145812e-04  1.11e-16 1.80e-17  3.49e-05     0s
#    6   5.53070583e-05  1.31604010e-04  2.22e-16 2.60e-18  1.11e-05     0s
#    7   7.25436423e-05  9.36725771e-05  5.55e-16 2.17e-19  3.09e-06     0s
#    8   7.29796353e-05  7.36269646e-05  3.55e-15 1.25e-17  9.46e-08     0s
#    9   7.34063104e-05  7.34073917e-05  4.15e-14 1.07e-19  1.58e-10     0s
#
# Barrier solved model in 9 iterations and 0.02 seconds (0.01 work units)
# Optimal objective 7.34063104e-05
#
# Optimal objective value: 7.340631035853657e-05
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 432 rows, 1121 columns and 3908 nonzeros
# Model fingerprint: 0x77ef14ef
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 432 rows, 1121 columns, 3908 nonzeros
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.940e+03
#  Factor NZ  : 5.105e+03
#  Factor Ops : 1.876e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.73313684e-03  1.26662955e-04  1.05e+01 2.03e-03  8.93e-02     0s
#    1   6.61407628e-06  1.22730853e-01  5.37e+00 8.79e-05  3.56e-02     0s
#    2   2.02690870e-06  6.23512302e-02  6.37e-01 0.00e+00  6.35e-03     0s
#    3   1.23735087e-06  7.54986255e-03  2.97e-01 0.00e+00  7.37e-04     0s
#    4   5.79584898e-07  1.02710961e-03  9.99e-16 0.00e+00  6.53e-05     0s
#    5   4.21152844e-06  3.83330148e-04  5.55e-16 0.00e+00  2.41e-05     0s
#    6   3.09207151e-05  1.68957466e-04  4.44e-16 0.00e+00  8.78e-06     0s
#    7   5.11688447e-05  1.02377489e-04  2.22e-16 0.00e+00  3.26e-06     0s
#    8   5.63077802e-05  7.29972797e-05  6.00e-15 0.00e+00  1.06e-06     0s
#    9   5.64007747e-05  6.08871330e-05  3.33e-15 0.00e+00  2.85e-07     0s
#   10   5.81722265e-05  5.84431269e-05  3.55e-15 0.00e+00  1.72e-08     0s
#   11   5.81835189e-05  5.81837973e-05  8.44e-15 8.13e-20  1.77e-11     0s
#
# Barrier solved model in 11 iterations and 0.03 seconds (0.00 work units)
# Optimal objective 5.81835189e-05
#
# Optimal objective value: 5.818351892807863e-05
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 2020 rows, 23075 columns and 91361 nonzeros
# Model fingerprint: 0xb4d4d36d
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.05s
# Presolved: 2020 rows, 23075 columns, 91361 nonzeros
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 1.117e+04
#  Factor NZ  : 2.060e+04 (roughly 1 MB of memory)
#  Factor Ops : 2.061e+06 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   9.44986385e-03  3.53303324e-04  3.95e+02 1.63e-03  4.64e-01     0s
#    1   4.05585071e-05  2.67061753e-01  2.12e+02 7.31e-03  2.43e-01     0s
#    2   6.32880101e-06  2.34763807e-01  1.10e+01 5.88e-04  1.48e-02     0s
#    3   1.94692361e-06  1.19189148e-01  7.36e-01 0.00e+00  1.96e-03     0s
#    4   1.71534359e-06  3.92462705e-02  1.26e-01 0.00e+00  5.26e-04     0s
#    5   2.84512046e-06  1.00969388e-02  3.18e-04 0.00e+00  1.01e-04     0s
#    6   7.81149505e-06  3.74144430e-03  2.34e-07 0.00e+00  3.74e-05     0s
#    7   2.64543997e-05  1.53254659e-03  2.50e-09 0.00e+00  1.51e-05     0s
#    8   4.20227060e-05  6.45305728e-04  1.45e-09 0.00e+00  6.04e-06     0s
#    9   6.30992895e-05  3.84074555e-04  8.25e-10 0.00e+00  3.22e-06     0s
#   10   7.57765781e-05  1.99593922e-04  5.04e-10 0.00e+00  1.24e-06     0s
#   11   8.45120873e-05  1.64708199e-04  1.08e-10 0.00e+00  8.03e-07     0s
#   12   8.96015111e-05  1.13797015e-04  3.63e-11 0.00e+00  2.42e-07     0s
#   13   8.96627364e-05  9.10234292e-05  1.50e-15 0.00e+00  1.36e-08     0s
#   14   9.03322042e-05  9.03347944e-05  2.39e-15 0.00e+00  2.59e-11     0s
#
# Barrier solved model in 14 iterations and 0.11 seconds (0.06 work units)
# Optimal objective 9.03322042e-05
#
# Optimal objective value: 9.033220423843233e-05
# Set parameter Method to value 2
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 901 rows, 2519 columns and 9410 nonzeros
# Model fingerprint: 0x63bb1c73
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 901 rows, 2519 columns, 9410 nonzeros
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.802e+03
#  Factor NZ  : 9.211e+03
#  Factor Ops : 4.921e+05 (less than 1 second per iteration)
#  Threads    : 1
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1.41686806e-02  2.76677842e-04  6.25e+01 1.52e-03  3.62e-01     0s
#    1   6.54413937e-05  5.04459186e-01  3.38e+01 5.88e-03  1.78e-01     0s
#    2   1.62353979e-05  4.56963429e-01  2.02e+00 1.63e-04  1.86e-02     0s
#    3   3.70230440e-06  1.56685665e-01  1.55e-01 0.00e+00  3.75e-03     0s
#    4   3.99930207e-08  2.41880606e-02  8.18e-03 0.00e+00  5.03e-04     0s
#    5   5.20313297e-08  4.05337500e-03  6.20e-04 0.00e+00  8.22e-05     0s
#    6   1.61000324e-06  2.46357164e-03  1.94e-05 0.00e+00  4.98e-05     0s
#    7   1.43138266e-05  1.86569762e-03  1.33e-05 0.00e+00  3.75e-05     0s
#    8   3.41471096e-05  6.12778191e-04  3.33e-16 0.00e+00  1.17e-05     0s
#    9   6.35350776e-05  2.20155157e-04  3.33e-16 0.00e+00  3.17e-06     0s
#   10   8.41280957e-05  1.26132915e-04  4.44e-16 0.00e+00  8.50e-07     0s
#   11   9.76677308e-05  1.08729085e-04  4.44e-16 0.00e+00  2.24e-07     0s
#   12   9.83211797e-05  9.87707271e-05  1.32e-14 0.00e+00  9.09e-09     0s
#   13   9.84214144e-05  9.84229343e-05  5.15e-14 0.00e+00  3.07e-11     0s
#
# Barrier solved model in 13 iterations and 0.05 seconds (0.01 work units)
# Optimal objective 9.84214144e-05
#
# Optimal objective value: 9.842141436014492e-05
