# %%
cluster = "c"
topology = "rrg"

# %%
for i in range(0,10):
    print(f"tar -xvf pathweightfiles/{topology}/su3/cluster{cluster}/{topology}_su3_cluster{cluster}_dbr{i}.tar.gz")
# Out:
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr0.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr1.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr2.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr3.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr4.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr5.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr6.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr7.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr8.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr9.tar.gz

# %%
# %%sh
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr0.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr1_0.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr1_1.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr2_0.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr2_1.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr3.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr4.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr5_0.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr5_1.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr6_0.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr6_1.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr7_0.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr7_1.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr8.tar.gz
# tar -xvf pathweightfiles/rrg/su3/clusterc/rrg_su3_clusterc_dbr9.tar.gz
# Out:
# pathweight_pbr1_rrg_su3_clusterc_lp1_barriernocrossover_0_1800_64.txt
# pathweight_pbr1_rrg_su3_clusterc_lp1_barriernocrossover_0_3600_64.txt
# pathweight_pbr1_rrg_su3_clusterc_lp1_barriernocrossover_0_7200_64.txt
# pathweight_pbr1_rrg_su3_clusterc_lp1_barriernocrossover_0_900_64.txt
# pathweight_pbr1_rrg_su3_clusterc_lp1_barriernocrossover_10800_11700_64.txt
# pathweight_pbr1_rrg_su3_clusterc_lp1_barriernocrossover_10800_12600_64.txt
# pathweight_pbr1_rrg_su3_clusterc_lp1_barriernocrossover_10800_14400_64.txt
# pathweight_pbr1_rrg_su3_clusterc_lp1_barriernocrossover_11700_12600_64.txt
# pathweight_pbr1_rrg_su3_clusterc_lp1_barriernocrossover_12600_13500_64.txt
# pathweight_pbr1_rrg_su3_clusterc_lp1_barriernocrossover_12600_14400_64.txt
# pathweight_pbr1_rrg_su3_clusterc_lp1_barriernocrossover_13500_14400_64.txt
# pathweight_pbr1_rrg_su3_clusterc_lp1_barriernocrossover_14400_15300_64.txt
# pathweight_pbr1_rrg_su3_clusterc_lp1_barriernocrossover_14400_16200_64.txt
# ...

# %%
print(f"mv pathweight_pbr1_{topology}_su3_cluster{cluster}* pathweightfiles/{topology}/su3/cluster{cluster}/")
# Out:
# mv pathweight_pbr1_rrg_su3_clusterc* pathweightfiles/rrg/su3/clusterc/

# %%
# %%sh
# mv pathweight_pbr1_rrg_su3_clusterc* pathweightfiles/rrg/su3/clusterc/
