# %%
trafficfilename = "cluster_a"
trafficfilesuffixlist = ["0_273"]
step_s = 1800
homedir = "/home/annzhou"

numserver = 2988
numsw = 80
numport = 64
numinterval = 86400//step_s

# no H yet, just test throughout and see how the spatial pattern changes

# %%
# read dring serverfile
serverfile = f"{homedir}/DRing/src/emp/datacentre/serverfiles/dring_{numserver}_{numsw}_{numport}"
serverdict = dict()
with open(serverfile,'r') as f:
    lines = f.readlines()
    for line in lines:
        tokens = line.split(',')
        serverdict[int(tokens[0])] = int(tokens[1])

# %%
traffic = list()
for k in range(numinterval):
    traffic.append(list())
    for i in range(numsw):
        traffic[k].append(list())
        for j in range(numsw):
            traffic[k][i].append(0)
for suffix in trafficfilesuffixlist:
    trafficfile = f"{homedir}/DRing/src/emp/datacentre/trafficfiles/{trafficfilename}/traffic_64racks_{suffix}"
    with open(trafficfile,'r') as f:
        lines = f.readlines()
        for line in lines:
            tokens = line.split()
            time_s = int(tokens[0])
            interval = time_s//step_s
            fromsvr = int(tokens[1])
            tosvr = int(tokens[2])
            if fromsvr>=numserver or tosvr>=numserver: continue
            fromsw = serverdict[fromsvr]
            tosw = serverdict[tosvr]
            if fromsw == tosw: continue
            flowbytes = int(tokens[3])
            traffic[interval][fromsw][tosw] += flowbytes
for k in range(numinterval):
    for i in range(numsw):
        for j in range(numsw):
            traffic[k][i][j] /= 100000

# %%
# solve gurobi
# copy from makepathweightfiles/makepathweightfiles.ipynb

# set parameters
graphname = "dring"
numfaillink = 0
numlink = 2132
fseed = 0

# c=64
# s=4
# multstr="2_7_8"
# tseed = 0
# trafficname = f"c2s_{c}_{s}_{tseed}_{multstr}"
trafficname = trafficfilename

method = -1
crossover = 0
factor = 64


# flowfile = f"{homedir}/DRing/src/emp/datacentre/flowfiles/c2s_{c}_{s}_{multstr}_{tseed}"

if graphname=="dring":
    graphfile = f"{homedir}/DRing/src/emp/datacentre/graphfiles/ring_supergraph/double_ring/instance1_{numsw}_{numport}.edgelist"
elif graphname=="rrg":
    graphfile = f"{homedir}/DRing/src/emp/datacentre/graphfiles/ring_supergraph/rrg/instance1_{numsw}_{numport}.edgelist"
else:
    print("ERROR: leafspine does not need to compute path weight")

# tag = f"{graphname}_{numfaillink}_{fseed}_{routingname}_{trafficname}_{method}_{crossover}_{factor}"
tag = f"{graphname}_{trafficname}_{method}_{crossover}_{factor}"
# varfile = f"{homedir}/DRing/src/emp/datacentre/qvarfiles/var_{tag}"
# qvarfile = f"{homedir}/DRing/src/emp/datacentre/qvarfiles/qvar_{tag}"
resultfile = f"{homedir}/DRing/src/emp/datacentre/computerouting/output/spatial_{tag}"
modelfile = f"{homedir}/DRing/src/emp/datacentre/makepathweightfiles/model.lp"




for routingname in ["ecmp","su2","su3","32disjoint"]:
    for interval in range(numinterval):

    
        if graphname=="dring" or graphname=="rrg":
            netpathfile = f"{homedir}/DRing/src/emp/datacentre/netpathfiles/netpath_{routingname}_{graphname}.txt"
        else:
            print("ERROR: leafspine does not need to compute path weight")


        # linkfailurefile = f"{homedir}/DRing/src/emp/datacentre/linkfailurefiles/{graphname}_{numlink}_{numfaillink}_{fseed}"

        # serverfile = f"{homedir}/DRing/src/emp/datacentre/serverfiles/{graphname}_{numserver}_{numsw}_{numport}"





        # read netpathfile
        netpath = list()
        for i in range(numsw):
            netpath.append(list())
            for j in range(numsw):
                netpath[i].append(list())
        with open(netpathfile,'r') as f:
            lines = f.readlines()
            # produce
            fromsw = 0
            tosw = 0
            for line in lines:
                if "->" not in line:
                    tokens = line.split()
                    fromsw = int(tokens[0])
                    tosw = int(tokens[1])
                else:
                    path = [fromsw]
                    tokens = line.split()
                    for token in tokens:
                        hops = token.split("->")
                        path.append(int(hops[1]))
                    netpath[fromsw][tosw].append(path)

            # check
            for line in lines:
                if "->" not in line:
                    tokens = line.split()
                    fromsw = int(tokens[0])
                    tosw = int(tokens[1])
                    numpaths = int(tokens[2])
                    if len(netpath[fromsw][tosw])!=numpaths:
                        print(f"ERROR: netpath is wrong, fromsw={fromsw}, tosw={tosw}, numpaths from file={numpaths}, numpaths from array={len(netpath[fromsw][tosw])}")

        # read graphfile
        link = list()
        for i in range(numsw):
            link.append(list())
            for j in range(numsw):
                link[i].append(0)
        with open(graphfile,'r') as f:
            lines = f.readlines()
            for line in lines:
                tokens = line.split("->")
                fromsw = int(tokens[0])
                tosw = int(tokens[1])
                link[fromsw][tosw] = 1
                link[tosw][fromsw] = 1

        # read linkfailurefile (if needed)
        # if numfaillink > 0:
        #     with open(linkfailurefile,'r') as f:
        #         lines = f.readlines()
        #         for line in lines:
        #             tokens = line.split()
        #             fromsw = int(tokens[0])
        #             tosw = int(tokens[1])
        #             if link[fromsw][tosw] != 1:
        #                 print(f"ERROR: should have a link from {fromsw} to {tosw} but not")
        #             else:
        #                 link[fromsw][tosw] /= 2

        # read serverfile
        # serverdict = dict()
        # with open(serverfile,'r') as f:
        #     lines = f.readlines()
        #     for line in lines:
        #         tokens = line.split(',')
        #         serverdict[int(tokens[0])] = int(tokens[1])

        # read flowfile
        # traffic = list()
        # for i in range(numsw):
        #     traffic.append(list())
        #     for j in range(numsw):
        #         traffic[i].append(0)
        # with open(flowfile,'r') as f:
        #     lines = f.readlines()
        #     for line in lines:
        #         tokens = line.split(",")
        #         fromsvr = int(tokens[0])
        #         tosvr = int(tokens[1])
        #         if fromsvr>=numserver or tosvr>=numserver: continue
        #         fromsw = serverdict[fromsvr]
        #         tosw = serverdict[tosvr]
        #         if fromsw == tosw: continue
        #         flowbytes = int(tokens[2])
        #         traffic[fromsw][tosw] += flowbytes




        # precompute
        flowsvialink = list()
        for i in range(numsw):
            flowsvialink.append(list())
            for j in range(numsw):
                flowsvialink[i].append(list())
        for fromsw in range(numsw):
            for tosw in range(numsw):
                if traffic[interval][fromsw][tosw] > 0:
                    for pid,path in enumerate(netpath[fromsw][tosw]):
                        fidpidstr = f"{fromsw},{tosw},{pid}"
                        prevhop = fromsw
                        for hop in path[1:]:
                            flowsvialink[prevhop][hop].append(fidpidstr)
                            prevhop = hop

        # for fromsw in range(numsw):
        #     for tosw in range(numsw):
        #         traffic[interval][fromsw][tosw] /= 100000







        import gurobipy as gp
        from gurobipy import GRB

        # Create a new model
        model = gp.Model("mcf")

        # Add variables
        maxpid = 0
        for fromsw in range(numsw):
            for tosw in range(numsw):
                maxpid = max(maxpid,len(netpath[fromsw][tosw]))
        vararr = list()
        for fromsw in range(numsw):
            vararr.append(list())
            for tosw in range(numsw):
                vararr[fromsw].append(list())
                for pid in range(maxpid):
                    vararr[fromsw][tosw].append(None)
        for fromsw in range(numsw):
            for tosw in range(numsw):
                if traffic[interval][fromsw][tosw] > 0:
                    for pid in range(len(netpath[fromsw][tosw])):
                        var = model.addVar(name=f"{fromsw}_{tosw}_{pid}")
                        vararr[fromsw][tosw][pid] = var
        k = model.addVar(name="k")

        # Set objective function
        model.setObjective(k, GRB.MAXIMIZE)

        # Add constraints
        # Constraint 0: for each fid: sum(pid) >= k * traffic[fid.from][fid.to]
        for fromsw in range(numsw):
            for tosw in range(numsw):
                if traffic[interval][fromsw][tosw] > 0:
                    varlist = list()
                    for pid in range(len(netpath[fromsw][tosw])):
                        varlist.append(vararr[fromsw][tosw][pid])
                    model.addConstr(sum(varlist)>=k*traffic[interval][fromsw][tosw],f"c0_{fromsw}_{tosw}")

        # Constraint 1: for each link: sum(fid_pid) <= link[link.from][link.to]
        for linkfrom in range(numsw):
            for linkto in range(numsw):
                flowstrlist = flowsvialink[linkfrom][linkto]
                if len(flowstrlist) > 0:
                    varlist = list()
                    for flowstr in flowstrlist:
                        tokens = flowstr.split(',')
                        flowfrom = int(tokens[0])
                        flowto = int(tokens[1])
                        pid = int(tokens[2])
                        varlist.append(vararr[flowfrom][flowto][pid])
                    model.addConstr(sum(varlist)<=link[linkfrom][linkto],f"c1_{linkfrom}_{linkto}")

        # Optimize model
        model.setParam('Method',method)
        model.setParam('Crossover',crossover)
        model.optimize()
        # model.write(modelfile)

        # Print results
        if model.status == GRB.OPTIMAL:
            print(f"Optimal objective value: {model.objVal}")
            with open(resultfile,'a') as f:
                f.write(f"{routingname},{interval},{k.x}\n")
                # for fromsw in range(numsw):
                #     for tosw in range(numsw):
                #         if traffic[fromsw][tosw] > 0:
                #             for pid in range(len(netpath[fromsw][tosw])):
                #                 var = vararr[fromsw][tosw][pid]
                #                 f.write(f"{var.varName},{var.x}\n")
        else:
            print("No optimal solution found")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-01-09
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7259 rows, 198863 columns and 752391 nonzeros
# Model fingerprint: 0x105e4773
# Coefficient statistics:
#   Matrix range     [2e-05, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.48s
# Presolved: 7259 rows, 198863 columns, 752391 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.84s
#
# Barrier performed 0 iterations in 1.54 seconds (1.54 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6934    2.9046070e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 6934 iterations and 1.55 seconds (1.82 work units)
# Optimal objective  2.904606994e-02
# Optimal objective value: 0.029046069939257246
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7300 rows, 199309 columns and 753700 nonzeros
# Model fingerprint: 0x6414cc4e
# Coefficient statistics:
#   Matrix range     [1e-03, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.53s
# Presolved: 7300 rows, 199309 columns, 753700 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.90s
#
# Barrier performed 0 iterations in 1.59 seconds (1.65 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7015    2.6374866e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 7015 iterations and 1.60 seconds (1.77 work units)
# Optimal objective  2.637486635e-02
# Optimal objective value: 0.02637486634658585
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7334 rows, 202304 columns and 765481 nonzeros
# Model fingerprint: 0x65e2e9ed
# Coefficient statistics:
#   Matrix range     [2e-04, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.53s
# Presolved: 7334 rows, 202304 columns, 765481 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.73s
#
# Barrier performed 0 iterations in 1.43 seconds (1.43 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6777    2.6439179e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6777 iterations and 1.44 seconds (1.61 work units)
# Optimal objective  2.643917901e-02
# Optimal objective value: 0.026439179009046646
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7335 rows, 201109 columns and 760692 nonzeros
# Model fingerprint: 0x801ca5ae
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.51s
# Presolved: 7335 rows, 201109 columns, 760692 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.83s
#
# Barrier performed 0 iterations in 1.50 seconds (1.50 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6602    2.6420292e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 6602 iterations and 1.50 seconds (1.66 work units)
# Optimal objective  2.642029151e-02
# Optimal objective value: 0.026420291511906953
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7347 rows, 200901 columns and 759757 nonzeros
# Model fingerprint: 0xd72c65d5
# Coefficient statistics:
#   Matrix range     [3e-04, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.50s
# Presolved: 7347 rows, 200901 columns, 759757 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.87s
#
# Barrier performed 0 iterations in 1.53 seconds (1.44 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6630    2.6257602e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 6630 iterations and 1.54 seconds (1.67 work units)
# Optimal objective  2.625760227e-02
# Optimal objective value: 0.026257602268765758
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7342 rows, 202365 columns and 765690 nonzeros
# Model fingerprint: 0xe018a64a
# Coefficient statistics:
#   Matrix range     [7e-04, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.53s
# Presolved: 7342 rows, 202365 columns, 765690 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.83s
#
# Barrier performed 0 iterations in 1.52 seconds (1.61 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7141    2.6007938e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 7141 iterations and 1.53 seconds (1.68 work units)
# Optimal objective  2.600793812e-02
# Optimal objective value: 0.026007938123608947
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7337 rows, 200843 columns and 759389 nonzeros
# Model fingerprint: 0x2f808569
# Coefficient statistics:
#   Matrix range     [1e-03, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.48s
# Presolved: 7337 rows, 200843 columns, 759389 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.81s
#
# Barrier performed 0 iterations in 1.44 seconds (1.55 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6548    2.5738712e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6548 iterations and 1.45 seconds (1.67 work units)
# Optimal objective  2.573871224e-02
# Optimal objective value: 0.025738712242464996
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7390 rows, 203360 columns and 769134 nonzeros
# Model fingerprint: 0xdb06e0f2
# Coefficient statistics:
#   Matrix range     [3e-04, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.51s
# Presolved: 7390 rows, 203360 columns, 769134 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.87s
#
# Barrier performed 0 iterations in 1.55 seconds (1.61 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6732    2.5327308e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 6732 iterations and 1.56 seconds (1.71 work units)
# Optimal objective  2.532730809e-02
# Optimal objective value: 0.025327308085559247
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7423 rows, 205500 columns and 777700 nonzeros
# Model fingerprint: 0x76d090f9
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.53s
# Presolved: 7423 rows, 205500 columns, 777700 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.81s
#
# Barrier performed 0 iterations in 1.51 seconds (1.54 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6549    2.4972121e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 6549 iterations and 1.52 seconds (1.68 work units)
# Optimal objective  2.497212071e-02
# Optimal objective value: 0.024972120708239304
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7460 rows, 205602 columns and 777548 nonzeros
# Model fingerprint: 0xdbf3a576
# Coefficient statistics:
#   Matrix range     [7e-04, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.54s
# Presolved: 7460 rows, 205602 columns, 777548 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.80s
#
# Barrier performed 0 iterations in 1.54 seconds (1.52 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6913    2.4540712e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 6913 iterations and 1.55 seconds (1.80 work units)
# Optimal objective  2.454071194e-02
# Optimal objective value: 0.024540711941323193
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7488 rows, 207779 columns and 786226 nonzeros
# Model fingerprint: 0x71530a10
# Coefficient statistics:
#   Matrix range     [8e-04, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.57s
# Presolved: 7488 rows, 207779 columns, 786226 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.85s
#
# Barrier performed 0 iterations in 1.61 seconds (1.60 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6841    2.4296936e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 6841 iterations and 1.62 seconds (1.75 work units)
# Optimal objective  2.429693642e-02
# Optimal objective value: 0.024296936423583288
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7484 rows, 207020 columns and 783090 nonzeros
# Model fingerprint: 0x4f166743
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.54s
# Presolved: 7484 rows, 207020 columns, 783090 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.74s
#
# Barrier performed 0 iterations in 1.46 seconds (1.38 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6539    2.3951291e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6539 iterations and 1.46 seconds (1.70 work units)
# Optimal objective  2.395129053e-02
# Optimal objective value: 0.02395129052658154
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7517 rows, 206780 columns and 781698 nonzeros
# Model fingerprint: 0x95d39799
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.54s
# Presolved: 7517 rows, 206780 columns, 781698 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.88s
#
# Barrier performed 0 iterations in 1.59 seconds (1.63 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7179    2.3584795e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 7179 iterations and 1.60 seconds (1.83 work units)
# Optimal objective  2.358479462e-02
# Optimal objective value: 0.023584794617362865
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7531 rows, 208386 columns and 788201 nonzeros
# Model fingerprint: 0x67d3681e
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.54s
# Presolved: 7531 rows, 208386 columns, 788201 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.90s
#
# Barrier performed 0 iterations in 1.61 seconds (1.68 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6940    2.3593529e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 6940 iterations and 1.62 seconds (1.83 work units)
# Optimal objective  2.359352900e-02
# Optimal objective value: 0.023593529004547587
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7518 rows, 209780 columns and 794183 nonzeros
# Model fingerprint: 0x0410608f
# Coefficient statistics:
#   Matrix range     [6e-04, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.54s
# Presolved: 7518 rows, 209780 columns, 794183 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.78s
#
# Barrier performed 0 iterations in 1.49 seconds (1.44 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6596    2.3496520e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6596 iterations and 1.50 seconds (1.70 work units)
# Optimal objective  2.349651971e-02
# Optimal objective value: 0.023496519708554396
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7518 rows, 208021 columns and 786891 nonzeros
# Model fingerprint: 0xaf4a352d
# Coefficient statistics:
#   Matrix range     [9e-04, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.50s
# Presolved: 7518 rows, 208021 columns, 786891 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.88s
#
# Barrier performed 0 iterations in 1.54 seconds (1.54 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7019    2.3485908e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 7019 iterations and 1.55 seconds (1.64 work units)
# Optimal objective  2.348590788e-02
# Optimal objective value: 0.023485907881171327
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7526 rows, 208868 columns and 790352 nonzeros
# Model fingerprint: 0x63c30f6e
# Coefficient statistics:
#   Matrix range     [6e-04, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.51s
# Presolved: 7526 rows, 208868 columns, 790352 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.77s
#
# Barrier performed 0 iterations in 1.45 seconds (1.44 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6490    2.3412696e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6490 iterations and 1.46 seconds (1.60 work units)
# Optimal objective  2.341269636e-02
# Optimal objective value: 0.023412696361850817
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7515 rows, 208908 columns and 790828 nonzeros
# Model fingerprint: 0x37e1a4a4
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.53s
# Presolved: 7515 rows, 208908 columns, 790828 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.96s
#
# Barrier performed 0 iterations in 1.66 seconds (1.76 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7115    2.3395335e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 7115 iterations and 1.67 seconds (1.81 work units)
# Optimal objective  2.339533478e-02
# Optimal objective value: 0.02339533478308158
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7494 rows, 209139 columns and 791605 nonzeros
# Model fingerprint: 0x2e0d0260
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.50s
# Presolved: 7494 rows, 209139 columns, 791605 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.89s
#
# Barrier performed 0 iterations in 1.56 seconds (1.71 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7109    2.3535518e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 7109 iterations and 1.57 seconds (1.77 work units)
# Optimal objective  2.353551767e-02
# Optimal objective value: 0.02353551766763369
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7492 rows, 208957 columns and 791183 nonzeros
# Model fingerprint: 0x06ad0a6f
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.50s
# Presolved: 7492 rows, 208957 columns, 791183 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.81s
#
# Barrier performed 0 iterations in 1.46 seconds (1.47 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6557    2.3690051e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6557 iterations and 1.47 seconds (1.67 work units)
# Optimal objective  2.369005137e-02
# Optimal objective value: 0.023690051370823507
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7469 rows, 205948 columns and 778922 nonzeros
# Model fingerprint: 0x0fd6aa49
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.52s
# Presolved: 7469 rows, 205948 columns, 778922 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.81s
#
# Barrier performed 0 iterations in 1.50 seconds (1.51 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6892    2.3848119e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 6892 iterations and 1.51 seconds (1.72 work units)
# Optimal objective  2.384811949e-02
# Optimal objective value: 0.02384811948833524
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7456 rows, 206214 columns and 780185 nonzeros
# Model fingerprint: 0x54ab683e
# Coefficient statistics:
#   Matrix range     [5e-04, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.50s
# Presolved: 7456 rows, 206214 columns, 780185 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.86s
#
# Barrier performed 0 iterations in 1.53 seconds (1.67 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7119    2.3957526e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 7119 iterations and 1.54 seconds (1.74 work units)
# Optimal objective  2.395752576e-02
# Optimal objective value: 0.023957525755826443
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7451 rows, 206045 columns and 779517 nonzeros
# Model fingerprint: 0xb9aaa244
# Coefficient statistics:
#   Matrix range     [4e-04, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.50s
# Presolved: 7451 rows, 206045 columns, 779517 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.81s
#
# Barrier performed 0 iterations in 1.47 seconds (1.44 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6677    2.4098986e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6677 iterations and 1.48 seconds (1.64 work units)
# Optimal objective  2.409898578e-02
# Optimal objective value: 0.02409898578079509
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7411 rows, 205511 columns and 777781 nonzeros
# Model fingerprint: 0x0ab43967
# Coefficient statistics:
#   Matrix range     [2e-04, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.52s
# Presolved: 7411 rows, 205511 columns, 777781 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.75s
#
# Barrier performed 0 iterations in 1.44 seconds (1.44 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6656    2.4155829e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6656 iterations and 1.45 seconds (1.66 work units)
# Optimal objective  2.415582936e-02
# Optimal objective value: 0.024155829362577236
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7421 rows, 204461 columns and 773439 nonzeros
# Model fingerprint: 0x1c2b3c04
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.44s
# Presolved: 7421 rows, 204461 columns, 773439 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.86s
#
# Barrier performed 0 iterations in 1.47 seconds (1.59 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6970    2.4352609e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6970 iterations and 1.48 seconds (1.73 work units)
# Optimal objective  2.435260933e-02
# Optimal objective value: 0.024352609331580764
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7415 rows, 205194 columns and 776387 nonzeros
# Model fingerprint: 0x6a799feb
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.54s
# Presolved: 7415 rows, 205194 columns, 776387 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.71s
#
# Barrier performed 0 iterations in 1.40 seconds (1.29 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6405    2.4326949e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6405 iterations and 1.41 seconds (1.53 work units)
# Optimal objective  2.432694922e-02
# Optimal objective value: 0.024326949224061773
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7395 rows, 204247 columns and 772689 nonzeros
# Model fingerprint: 0xaef7bf93
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.49s
# Presolved: 7395 rows, 204247 columns, 772689 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.87s
#
# Barrier performed 0 iterations in 1.52 seconds (1.66 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7085    2.4709192e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 7085 iterations and 1.52 seconds (1.81 work units)
# Optimal objective  2.470919158e-02
# Optimal objective value: 0.024709191575834916
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7389 rows, 202913 columns and 767366 nonzeros
# Model fingerprint: 0x61d9819f
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.57s
# Presolved: 7389 rows, 202913 columns, 767366 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.88s
#
# Barrier performed 0 iterations in 1.62 seconds (1.62 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6971    2.4835724e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 6971 iterations and 1.62 seconds (1.70 work units)
# Optimal objective  2.483572410e-02
# Optimal objective value: 0.024835724102921227
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7401 rows, 204299 columns and 773047 nonzeros
# Model fingerprint: 0x6d019906
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.52s
# Presolved: 7401 rows, 204299 columns, 773047 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.73s
#
# Barrier performed 0 iterations in 1.43 seconds (1.37 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6422    2.5041611e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6422 iterations and 1.44 seconds (1.61 work units)
# Optimal objective  2.504161081e-02
# Optimal objective value: 0.025041610809962558
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7346 rows, 201648 columns and 762677 nonzeros
# Model fingerprint: 0x6c9f9fb4
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.44s
# Presolved: 7346 rows, 201648 columns, 762677 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.79s
#
# Barrier performed 0 iterations in 1.39 seconds (1.53 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6848    2.5323398e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6848 iterations and 1.40 seconds (1.57 work units)
# Optimal objective  2.532339785e-02
# Optimal objective value: 0.025323397845127035
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7309 rows, 201944 columns and 764490 nonzeros
# Model fingerprint: 0x0410be95
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.50s
# Presolved: 7309 rows, 201944 columns, 764490 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.85s
#
# Barrier performed 0 iterations in 1.52 seconds (1.50 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6607    2.5480060e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 6607 iterations and 1.53 seconds (1.64 work units)
# Optimal objective  2.548006014e-02
# Optimal objective value: 0.025480060140114096
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7300 rows, 200962 columns and 760267 nonzeros
# Model fingerprint: 0x1eb0dcf0
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.45s
# Presolved: 7300 rows, 200962 columns, 760267 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.77s
#
# Barrier performed 0 iterations in 1.39 seconds (1.43 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6530    2.5631184e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6530 iterations and 1.40 seconds (1.67 work units)
# Optimal objective  2.563118405e-02
# Optimal objective value: 0.025631184045267635
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7308 rows, 200611 columns and 758942 nonzeros
# Model fingerprint: 0xe0fbbcec
# Coefficient statistics:
#   Matrix range     [5e-04, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.49s
# Presolved: 7308 rows, 200611 columns, 758942 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.72s
#
# Barrier performed 0 iterations in 1.40 seconds (1.30 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6293    2.5790430e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6293 iterations and 1.40 seconds (1.56 work units)
# Optimal objective  2.579042987e-02
# Optimal objective value: 0.0257904298706822
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7304 rows, 199649 columns and 755091 nonzeros
# Model fingerprint: 0x017af9e2
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.49s
# Presolved: 7304 rows, 199649 columns, 755091 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.75s
#
# Barrier performed 0 iterations in 1.39 seconds (1.41 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6763    2.5569923e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6763 iterations and 1.40 seconds (1.54 work units)
# Optimal objective  2.556992304e-02
# Optimal objective value: 0.02556992304277084
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7331 rows, 201795 columns and 763484 nonzeros
# Model fingerprint: 0x67266529
# Coefficient statistics:
#   Matrix range     [5e-04, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.51s
# Presolved: 7331 rows, 201795 columns, 763484 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.75s
#
# Barrier performed 0 iterations in 1.43 seconds (1.43 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6576    2.5951181e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6576 iterations and 1.43 seconds (1.64 work units)
# Optimal objective  2.595118120e-02
# Optimal objective value: 0.025951181195405026
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7319 rows, 200224 columns and 757048 nonzeros
# Model fingerprint: 0xbc54155b
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.45s
# Presolved: 7319 rows, 200224 columns, 757048 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.91s
#
# Barrier performed 0 iterations in 1.52 seconds (1.66 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7125    2.5496812e-02   0.000000e+00   0.000000e+00      2s
#
# Solved in 7125 iterations and 1.53 seconds (1.76 work units)
# Optimal objective  2.549681223e-02
# Optimal objective value: 0.02549681223272081
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7341 rows, 200837 columns and 759442 nonzeros
# Model fingerprint: 0xd92aefdb
# Coefficient statistics:
#   Matrix range     [1e-03, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.47s
# Presolved: 7341 rows, 200837 columns, 759442 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.81s
#
# Barrier performed 0 iterations in 1.44 seconds (1.52 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6703    2.5852786e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6703 iterations and 1.45 seconds (1.64 work units)
# Optimal objective  2.585278598e-02
# Optimal objective value: 0.025852785982872228
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7306 rows, 200243 columns and 757285 nonzeros
# Model fingerprint: 0x2d578d39
# Coefficient statistics:
#   Matrix range     [4e-04, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.48s
# Presolved: 7306 rows, 200243 columns, 757285 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.71s
#
# Barrier performed 0 iterations in 1.36 seconds (1.28 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6647    2.5775980e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6647 iterations and 1.37 seconds (1.56 work units)
# Optimal objective  2.577598015e-02
# Optimal objective value: 0.025775980154557357
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7277 rows, 198694 columns and 751764 nonzeros
# Model fingerprint: 0xdb4850b4
# Coefficient statistics:
#   Matrix range     [3e-04, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.46s
# Presolved: 7277 rows, 198694 columns, 751764 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.85s
#
# Barrier performed 0 iterations in 1.49 seconds (1.55 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6797    2.5863572e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6797 iterations and 1.50 seconds (1.68 work units)
# Optimal objective  2.586357222e-02
# Optimal objective value: 0.025863572223718906
# ...
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7319 rows, 137327 columns and 573130 nonzeros
# Model fingerprint: 0xc3b1c853
# Coefficient statistics:
#   Matrix range     [1e-03, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.39s
# Presolved: 7319 rows, 137327 columns, 573130 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.54s
#
# Barrier performed 0 iterations in 1.08 seconds (1.17 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6653    2.5496812e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6653 iterations and 1.09 seconds (1.14 work units)
# Optimal objective  2.549681223e-02
# Optimal objective value: 0.02549681223272081
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7341 rows, 137899 columns and 576069 nonzeros
# Model fingerprint: 0x1f8fc595
# Coefficient statistics:
#   Matrix range     [1e-03, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.36s
# Presolved: 7341 rows, 137899 columns, 576069 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.78s
#
# Barrier performed 0 iterations in 1.29 seconds (1.31 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6805    2.5852786e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6805 iterations and 1.29 seconds (1.20 work units)
# Optimal objective  2.585278598e-02
# Optimal objective value: 0.02585278598287222
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7306 rows, 136985 columns and 571775 nonzeros
# Model fingerprint: 0x5cff68d1
# Coefficient statistics:
#   Matrix range     [4e-04, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.38s
# Presolved: 7306 rows, 136985 columns, 571775 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.77s
#
# Barrier performed 0 iterations in 1.32 seconds (1.27 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6999    2.5775980e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6999 iterations and 1.33 seconds (1.27 work units)
# Optimal objective  2.577598015e-02
# Optimal objective value: 0.02577598015455736
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7277 rows, 136224 columns and 569486 nonzeros
# Model fingerprint: 0xb0afc275
# Coefficient statistics:
#   Matrix range     [3e-04, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.40s
# Presolved: 7277 rows, 136224 columns, 569486 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.69s
#
# Barrier performed 0 iterations in 1.24 seconds (1.26 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6539    2.5863572e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6539 iterations and 1.25 seconds (1.10 work units)
# Optimal objective  2.586357222e-02
# Optimal objective value: 0.025863572223718906
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7339 rows, 137846 columns and 576041 nonzeros
# Model fingerprint: 0x5df5d106
# Coefficient statistics:
#   Matrix range     [1e-03, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.36s
# Presolved: 7339 rows, 137846 columns, 576041 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.79s
#
# Barrier performed 0 iterations in 1.30 seconds (1.32 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7159    2.5891800e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 7159 iterations and 1.31 seconds (1.32 work units)
# Optimal objective  2.589180014e-02
# Optimal objective value: 0.025891800142652313
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7316 rows, 137238 columns and 572869 nonzeros
# Model fingerprint: 0xef609e04
# Coefficient statistics:
#   Matrix range     [1e-03, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.38s
# Presolved: 7316 rows, 137238 columns, 572869 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.76s
#
# Barrier performed 0 iterations in 1.30 seconds (1.32 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6779    2.6021095e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6779 iterations and 1.30 seconds (1.18 work units)
# Optimal objective  2.602109474e-02
# Optimal objective value: 0.026021094742536107
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7319 rows, 137318 columns and 573849 nonzeros
# Model fingerprint: 0x73a5af46
# Coefficient statistics:
#   Matrix range     [7e-04, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.37s
# Presolved: 7319 rows, 137318 columns, 573849 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.78s
#
# Barrier performed 0 iterations in 1.30 seconds (1.35 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7142    2.5865964e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 7142 iterations and 1.30 seconds (1.25 work units)
# Optimal objective  2.586596422e-02
# Optimal objective value: 0.025865964221163648
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7290 rows, 136578 columns and 570562 nonzeros
# Model fingerprint: 0x2b33eb5d
# Coefficient statistics:
#   Matrix range     [7e-04, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.37s
# Presolved: 7290 rows, 136578 columns, 570562 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.72s
#
# Barrier performed 0 iterations in 1.24 seconds (1.30 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6742    2.5855374e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6742 iterations and 1.25 seconds (1.20 work units)
# Optimal objective  2.585537356e-02
# Optimal objective value: 0.025855373562985864
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7265 rows, 135911 columns and 567743 nonzeros
# Model fingerprint: 0x0d0a6071
# Coefficient statistics:
#   Matrix range     [1e-03, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.35s
# Presolved: 7265 rows, 135911 columns, 567743 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.81s
#
# Barrier performed 0 iterations in 1.32 seconds (1.28 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6679    2.6499081e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6679 iterations and 1.33 seconds (1.22 work units)
# Optimal objective  2.649908124e-02
# Optimal objective value: 0.02649908124250266
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7238 rows, 135203 columns and 565096 nonzeros
# Model fingerprint: 0xb8252f61
# Coefficient statistics:
#   Matrix range     [7e-04, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.37s
# Presolved: 7238 rows, 135203 columns, 565096 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.49s
#
# Barrier performed 0 iterations in 1.01 seconds (1.05 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6263    2.6555939e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6263 iterations and 1.02 seconds (1.05 work units)
# Optimal objective  2.655593902e-02
# Optimal objective value: 0.026555939023315052
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7221 rows, 134762 columns and 563146 nonzeros
# Model fingerprint: 0xc336a88d
# Coefficient statistics:
#   Matrix range     [1e-03, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.36s
# Presolved: 7221 rows, 134762 columns, 563146 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.55s
#
# Barrier performed 0 iterations in 1.05 seconds (1.22 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6502    2.6755121e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6502 iterations and 1.05 seconds (1.18 work units)
# Optimal objective  2.675512081e-02
# Optimal objective value: 0.026755120813689418
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7279 rows, 136286 columns and 569315 nonzeros
# Model fingerprint: 0x7f2c19ac
# Coefficient statistics:
#   Matrix range     [1e-03, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.37s
# Presolved: 7279 rows, 136286 columns, 569315 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.54s
#
# Barrier performed 0 iterations in 1.05 seconds (1.19 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6504    2.6350663e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6504 iterations and 1.06 seconds (1.13 work units)
# Optimal objective  2.635066275e-02
# Optimal objective value: 0.02635066275235054
# Set parameter Crossover to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 20.04.6 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU E5-2630 v4 @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 20 physical cores, 40 logical processors, using up to 20 threads
#
# Optimize a model with 7199 rows, 134199 columns and 560475 nonzeros
# Model fingerprint: 0xcfe6c370
# Coefficient statistics:
#   Matrix range     [2e-04, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.35s
# Presolved: 7199 rows, 134199 columns, 560475 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Warning: Concurrent optimizer requires crossover - forcing it on
# Ordering time: 0.75s
#
# Barrier performed 0 iterations in 1.24 seconds (1.28 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6774    2.6331675e-02   0.000000e+00   0.000000e+00      1s
#
# Solved in 6774 iterations and 1.25 seconds (1.23 work units)
# Optimal objective  2.633167522e-02
# Optimal objective value: 0.026331675224493624
